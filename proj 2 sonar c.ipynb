# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
#loading dataset

df=pd.read_csv('Sonar.csv')
df.head()
# Out:
#        V1      V2      V3      V4      V5      V6      V7      V8      V9  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#       V10  ...     V52     V53     V54     V55     V56     V57     V58  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#       V59     V60  Class
# 0  0.0090  0.0032      R
# 1  0.0052  0.0044      R
# ...

# %%
df.shape
# Out:
# (208, 61)

# %%
df.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'V29', 'V30', 'V31',
#        'V32', 'V33', 'V34', 'V35', 'V36', 'V37', 'V38', 'V39', 'V40', 'V41',
#        'V42', 'V43', 'V44', 'V45', 'V46', 'V47', 'V48', 'V49', 'V50', 'V51',
#        'V52', 'V53', 'V54', 'V55', 'V56', 'V57', 'V58', 'V59', 'V60', 'Class'],
#       dtype='object')

# %%
df.describe()
# Out:
#                V1          V2          V3          V4          V5          V6  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                V7          V8          V9         V10  ...         V51  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
df.isnull()
# Out:
#         V1     V2     V3     V4     V5     V6     V7     V8     V9    V10  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 203  False  False  False  False  False  False  False  False  False  False
# 204  False  False  False  False  False  False  False  False  False  False
# 205  False  False  False  False  False  False  False  False  False  False
# 206  False  False  False  False  False  False  False  False  False  False
# 207  False  False  False  False  False  False  False  False  False  False
#
#      ...    V52    V53    V54    V55    V56    V57    V58    V59    V60  Class
# ...

# %%
df.isnull().sum()
# Out:
# V1       0
# V2       0
# V3       0
# V4       0
# V5       0
#         ..
# V57      0
# V58      0
# V59      0
# V60      0
# Class    0
# Length: 61, dtype: int64

# %%
import seaborn as sns 
sns.heatmap(df.isnull())
plt.title('null value')
plt.show()

# %% [markdown]
# there are no null values

# %%
df['Class'].hist(grid=False)
plt.title('rock vs mine')
plt.show()

# %% [markdown]
# there is no class imbalance

# %% [markdown]
# # label encoding

# %% [markdown]
# label encoding converts str data to numerical form: 0 and 1
#     0 rock
#     1 mine

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df['Class']=LE.fit_transform(df['Class'])
df['Class'].value_counts()
# Out:
# 0    111
# 1     97
# Name: Class, dtype: int64

# %%
corr_mat=df.corr()

plt.figure(figsize=[22,12])
sns.heatmap(corr_mat,annot=True)
plt.title('correlation matrix')
plt.show()

# %% [raw]
# not able to visulaize in the heatmap so store value and view

# %%
corr_matrix=df.corr()
corr_matrix
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# V1     1.000000  0.735896  0.571537  0.491438  0.344797  0.238921  0.260815
# V2     0.735896  1.000000  0.779916  0.606684  0.419669  0.332329  0.279040
# V3     0.571537  0.779916  1.000000  0.781786  0.546141  0.346275  0.190434
# V4     0.491438  0.606684  0.781786  1.000000  0.726943  0.352805  0.246440
# V5     0.344797  0.419669  0.546141  0.726943  1.000000  0.597053  0.335422
# ...         ...       ...       ...       ...       ...       ...       ...
# V57    0.313725  0.280341  0.380819  0.340254  0.219395  0.161333  0.186324
# V58    0.368132  0.353042  0.334108  0.344865  0.238793  0.203986  0.242646
# V59    0.357116  0.352200  0.425047  0.420266  0.290982  0.220573  0.183578
# V60    0.347078  0.358761  0.373948  0.400626  0.253710  0.178158  0.222493
# Class -0.271694 -0.231238 -0.192195 -0.250638 -0.222232 -0.132327 -0.114748
#
# ...

# %%
corr_matrix=df.corr()
corr_matrix['Class'].sort_values(ascending=False)
# Out:
# Class    1.000000
# V36      0.269151
# V35      0.227670
# V37      0.209055
# V34      0.172010
#            ...
# V45     -0.339406
# V10     -0.341142
# V49     -0.351312
# V12     -0.392245
# V11     -0.432855
# Name: Class, Length: 61, dtype: float64

# %% [raw]
# very weak correlation

# %% [markdown]
# data distribution among all the columns

# %%
df.plot(kind='density',subplots=True, layout=(6,11), sharex=False,legend=False,fontsize=1,figsize=(18,12))
plt.show()

# %% [raw]
# data is skewed in many columns, so we remove skewness

# %% [markdown]
# splitting data into x and y to remove skewness

# %%
x=df.drop('Class',axis=1)
y=df['Class']

# %%
#checking skewness

x.skew()
# Out:
# V1     2.131088
# V2     2.155644
# V3     2.652518
# V4     3.401697
# V5     2.018141
# V6     1.248166
# V7     0.970820
# V8     1.481107
# V9     1.633870
# V10    1.281258
# V11    0.987813
# V12    0.588681
# V13    0.736584
# V14    1.022369
# V15    0.763964
# V16    0.694671
# V17    0.654480
# V18    0.525845
# V19    0.283182
# V20   -0.085331
# V21   -0.252741
# V22   -0.392289
# V23   -0.594350
# V24   -0.691861
# V25   -0.788909
# V26   -0.671580
# V27   -0.627843
# V28   -0.615447
# V29   -0.442007
# V30   -0.132390
# V31    0.259797
# V32    0.313420
# V33    0.423864
# V34    0.563296
# V35    0.591654
# V36    0.619868
# V37    0.676994
# V38    1.033366
# V39    0.908835
# V40    0.861280
# V41    0.863526
# V42    0.860110
# V43    0.909317
# V44    1.235086
# V45    1.366839
# V46    1.706674
# V47    1.790155
# V48    1.277722
# V49    1.273385
# V50    1.761714
# V51    2.716060
# V52    2.093976
# V53    1.060572
# V54    1.093090
# V55    1.789946
# ...

# %% [raw]
# there is skewness in many columns so remove the skewness using transform techniques

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)
x=pd.DataFrame(x_new,columns=x.columns)

# %%
x.skew()
# Out:
# V1     0.200661
# V2     0.196446
# V3     0.187103
# V4     0.190002
# V5     0.140451
# V6     0.038764
# V7     0.017842
# V8     0.039388
# V9     0.077245
# V10    0.073024
# V11    0.047685
# V12    0.033161
# V13    0.024720
# V14    0.039062
# V15    0.070344
# V16    0.102740
# V17    0.124196
# V18    0.094088
# V19    0.019011
# V20   -0.074176
# V21   -0.106673
# V22   -0.144238
# V23   -0.180086
# V24   -0.163443
# V25   -0.205760
# V26   -0.202206
# V27   -0.195002
# V28   -0.167409
# V29   -0.133525
# V30   -0.047004
# V31   -0.001851
# V32    0.005106
# V33    0.020193
# V34    0.047734
# V35    0.078044
# V36    0.087954
# V37    0.100569
# V38    0.086653
# V39    0.078671
# V40    0.035032
# V41    0.061931
# V42    0.049309
# V43    0.032043
# V44    0.083057
# V45    0.170784
# V46    0.169289
# V47    0.120549
# V48    0.096302
# V49    0.132635
# V50    0.106623
# V51    0.077191
# V52    0.148282
# V53    0.130364
# V54    0.125757
# V55    0.189057
# ...

# %% [raw]
# skewness is reduced, so need not transform again

# %%
#plotting box plot for first 30

x.iloc[:,0:30].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
#plotting box plot for next 30

x.iloc[:,30:].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [raw]
# few values in v6,v7 and v44 ,as they are very close to the whisker so it is ignored

# %% [markdown]
# finding best random state

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
 
maxAccu=0
maxRS=0
for i in range (0,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr=LogisticRegression()
    lr.fit(x_train,y_train)
    predrf=lr.predict(x_test)
    acc=accuracy_score(y_test,predrf)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('best accuracy score is :',maxAccu,' on Random state',maxRS)
# Out:
# best accuracy score is : 0.9523809523809523  on Random state 41

# %% [raw]
# we have found that teh best random state is at 41 , we will create train,test,split using this random state

# %% [markdown]
# creating train,test,split ar 41

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=41)

# %% [markdown]
# # Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

lr=LogisticRegression()
lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
print('accuracy score=',accuracy_score(y_test,predlr)*100)
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# accuracy score= 95.23809523809523
# [[23  1]
#  [ 1 17]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        24
#            1       0.94      0.94      0.94        18
#
#     accuracy                           0.95        42
#    macro avg       0.95      0.95      0.95        42
# weighted avg       0.95      0.95      0.95        42

# %% [markdown]
# # Decison tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
preddt=dt.predict(x_test)
print('accuracy score=',accuracy_score(y_test,preddt)*100)
print(confusion_matrix(y_test,preddt))
print(classification_report(y_test,preddt))
# Out:
# accuracy score= 88.09523809523809
# [[23  1]
#  [ 4 14]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90        24
#            1       0.93      0.78      0.85        18
#
#     accuracy                           0.88        42
#    macro avg       0.89      0.87      0.88        42
# weighted avg       0.89      0.88      0.88        42

# %% [markdown]
# # Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier()
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print('accuracy score=',accuracy_score(y_test,predrf)*100)
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# accuracy score= 97.61904761904762
# [[24  0]
#  [ 1 17]]
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        24
#            1       1.00      0.94      0.97        18
#
#     accuracy                           0.98        42
#    macro avg       0.98      0.97      0.98        42
# weighted avg       0.98      0.98      0.98        42

# %% [markdown]
# # SVC: support vector classifier

# %%
from sklearn.svm import SVC

svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print('accuracy score=',accuracy_score(y_test,predsvc)*100)
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# accuracy score= 95.23809523809523
# [[24  0]
#  [ 2 16]]
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        24
#            1       1.00      0.89      0.94        18
#
#     accuracy                           0.95        42
#    macro avg       0.96      0.94      0.95        42
# weighted avg       0.96      0.95      0.95        42

# %% [raw]
# logistic regression,random forest classifier and svc producing good accuracy, now we check cross validation score as well for overfitting(if existing )

# %% [markdown]
# # cross validation

# %%
from sklearn.model_selection import cross_val_score

scr=cross_val_score(lr,x,y,cv=5)
print('cross validation score of logistic regression is',scr.mean())
# Out:
# cross validation score of logistic regression is 0.6638792102206736

# %%
scr=cross_val_score(rf,x,y,cv=5)
print('cross validation score of logistic regression is',scr.mean())
# Out:
# cross validation score of logistic regression is 0.6930313588850174

# %%
scr=cross_val_score(svc,x,y,cv=5)
print('cross validation score of logistic regression is',scr.mean())
# Out:
# cross validation score of logistic regression is 0.6492450638792102

# %% [raw]
# random forest classifeior produces best cross val score so we proceed with rfc

# %% [markdown]
# # Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

#create parameters to pass 
parameters={'max_features': ['auto','sqrt','log2'],
           'max_depth': [4,5,6,7,8],
            'criterion': ['gini','entropy']
           }

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameters,cv=5,scoring='accuracy')
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 7, 'max_features': 'auto'}

# %%
GCV_pred=GCV.best_estimator_.predict(x_test)
accuracy_score(y_test,GCV_pred)
# Out:
# 0.8809523809523809

# %% [markdown]
# # ROC AUC curve

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(GCV.best_estimator_,x_test,y_test)
plt.title('rOC AUC curve')
plt.show()

# %% [raw]
# final accuracy is .99 ie 99% it is a vey good accuracy

# %% [markdown]
# saving in pickle form

# %%
import joblib
joblib.dump(GCV.best_estimator_,"SONARmodel.pkl")
# Out:
# ['SONARmodel.pkl']
