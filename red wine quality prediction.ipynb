# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('red wine quality prediction.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.loc[(df['quality'] < 7.0),'quality']=0   # quality 7 and above is 1(good) and below 7 is 0(bad)
df.loc[(df['quality'] >= 7.0),'quality']=1

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
import seaborn as sns 
sns.heatmap(df.isnull())
plt.title('null value')
plt.show()

# %%
sns.scatterplot(x='fixed acidity',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='quality'>

# %%
sns.scatterplot(x='volatile acidity',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='quality'>

# %%
sns.scatterplot(x='residual sugar',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='quality'>

# %%
sns.scatterplot(x='citric acid',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='quality'>

# %%
sns.scatterplot(x='chlorides',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='quality'>

# %%
sns.scatterplot(x='free sulfur dioxide',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='quality'>

# %%
sns.scatterplot(x='total sulfur dioxide',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='quality'>

# %%
sns.scatterplot(x='pH',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %%
sns.scatterplot(x='density',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='density', ylabel='quality'>

# %%
sns.scatterplot(x='sulphates',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='quality'>

# %%
sns.scatterplot(x='alcohol',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     0.135710
# std       0.154386     0.169507     1.065668     0.342587
# min       2.740000     0.330000     8.400000     0.000000
# 25%       3.210000     0.550000     9.500000     0.000000
# 50%       3.310000     0.620000    10.200000     0.000000
# 75%       3.400000     0.730000    11.100000     0.000000
# max       4.010000     2.000000    14.900000     1.000000

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.120061         -0.270712     0.214716
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.047779  -0.097308            -0.071747
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.139517 -0.150460 -0.057283   0.199485
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.120061
# volatile acidity     -0.202288 -0.270712
# citric acid           0.109903  0.214716
# residual sugar        0.042075  0.047779
# chlorides            -0.221141 -0.097308
# free sulfur dioxide  -0.069408 -0.071747
# total sulfur dioxide -0.205654 -0.139517
# density              -0.496180 -0.150460
# pH                    0.205633 -0.057283
# sulphates             0.093595  0.199485
# alcohol               1.000000  0.407315
# quality               0.407315  1.000000

# %%
df.corr()['quality']
# Out:
# fixed acidity           0.120061
# volatile acidity       -0.270712
# citric acid             0.214716
# residual sugar          0.047779
# chlorides              -0.097308
# free sulfur dioxide    -0.071747
# total sulfur dioxide   -0.139517
# density                -0.150460
# pH                     -0.057283
# sulphates               0.199485
# alcohol                 0.407315
# quality                 1.000000
# Name: quality, dtype: float64

# %%
df.corr()['quality'].sort_values()
# Out:
# volatile acidity       -0.270712
# density                -0.150460
# total sulfur dioxide   -0.139517
# chlorides              -0.097308
# free sulfur dioxide    -0.071747
# pH                     -0.057283
# residual sugar          0.047779
# fixed acidity           0.120061
# sulphates               0.199485
# citric acid             0.214716
# alcohol                 0.407315
# quality                 1.000000
# Name: quality, dtype: float64

# %%
corr_mat=df.corr()

plt.figure(figsize=[22,12])
sns.heatmap(corr_mat,annot=True)
plt.title('correlation matrix')
plt.show()

# %%
df=df.drop(['volatile acidity','total sulfur dioxide'],axis=1)

# %%
df
# Out:
#       fixed acidity  citric acid  residual sugar  chlorides  \
# 0               7.4         0.00             1.9      0.076
# 1               7.8         0.00             2.6      0.098
# 2               7.8         0.04             2.3      0.092
# 3              11.2         0.56             1.9      0.075
# 4               7.4         0.00             1.9      0.076
# ...             ...          ...             ...        ...
# 1594            6.2         0.08             2.0      0.090
# 1595            5.9         0.10             2.2      0.062
# 1596            6.3         0.13             2.3      0.076
# 1597            5.9         0.12             2.0      0.075
# 1598            6.0         0.47             3.6      0.067
#
#       free sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0                    11.0  0.99780  3.51       0.56      9.4        0
# 1                    25.0  0.99680  3.20       0.68      9.8        0
# 2                    15.0  0.99700  3.26       0.65      9.8        0
# 3                    17.0  0.99800  3.16       0.58      9.8        0
# 4                    11.0  0.99780  3.51       0.56      9.4        0
# ...                   ...      ...   ...        ...      ...      ...
# 1594                 32.0  0.99490  3.45       0.58     10.5        0
# 1595                 39.0  0.99512  3.52       0.76     11.2        0
# 1596                 29.0  0.99574  3.42       0.75     11.0        0
# 1597                 32.0  0.99547  3.57       0.71     10.2        0
# 1598                 18.0  0.99549  3.39       0.66     11.0        0
#
# [1599 rows x 10 columns]

# %%
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='h')
    plt.tight_layout()

# %%
df.plot(kind='density',subplots=True, layout=(3,4), sharex=False,legend=False,fontsize=1,figsize=(22,18))
plt.show()

# %%
df.skew()
# Out:
# fixed acidity          0.982751
# citric acid            0.318337
# residual sugar         4.540655
# chlorides              5.680347
# free sulfur dioxide    1.250567
# density                0.071288
# pH                     0.193683
# sulphates              2.428672
# alcohol                0.860829
# quality                2.129363
# dtype: float64

# %%
sns.distplot(df['fixed acidity'])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Density'>

# %%
sns.distplot(df['citric acid'])
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='Density'>

# %%
sns.distplot(df['residual sugar'])
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='Density'>

# %%
sns.distplot(df['chlorides'])
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='Density'>

# %%
sns.distplot(df['free sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %%
sns.distplot(df['density'])
# Out:
# <AxesSubplot:xlabel='density', ylabel='Density'>

# %%
sns.distplot(df['pH'])
# Out:
# <AxesSubplot:xlabel='pH', ylabel='Density'>

# %%
sns.distplot(df['sulphates'])
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='Density'>

# %%
sns.distplot(df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %%
df.boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
df.plot(kind='box',subplots=True,layout=(3,4),figsize=(10,15))
# Out:
# fixed acidity             AxesSubplot(0.125,0.653529;0.168478x0.226471)
# citric acid            AxesSubplot(0.327174,0.653529;0.168478x0.226471)
# residual sugar         AxesSubplot(0.529348,0.653529;0.168478x0.226471)
# chlorides              AxesSubplot(0.731522,0.653529;0.168478x0.226471)
# free sulfur dioxide       AxesSubplot(0.125,0.381765;0.168478x0.226471)
# density                AxesSubplot(0.327174,0.381765;0.168478x0.226471)
# pH                     AxesSubplot(0.529348,0.381765;0.168478x0.226471)
# sulphates              AxesSubplot(0.731522,0.381765;0.168478x0.226471)
# alcohol                       AxesSubplot(0.125,0.11;0.168478x0.226471)
# quality                    AxesSubplot(0.327174,0.11;0.168478x0.226471)
# dtype: object

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (1599, 10)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   17,   17,   19,   33,   42,   43,   45,   57,
#          81,   81,   83,   86,   88,   91,   92,   95,  106,  106,  142,
#         144,  147,  151,  151,  151,  151,  163,  164,  169,  169,  181,
#         226,  226,  240,  243,  244,  258,  258,  274,  281,  291,  324,
#         325,  339,  340,  347,  374,  381,  391,  396,  396,  400,  400,
#         442,  442,  451,  467,  480,  480,  494,  544,  554,  554,  555,
#         555,  557,  557,  568,  584,  588,  595,  608,  614,  639,  649,
#         652,  652,  652,  692,  692,  695,  723,  730,  754,  776,  777,
#         795,  821,  836,  837,  889,  911,  917,  923,  925,  926,  982,
#        1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079, 1081, 1111, 1114,
#        1131, 1154, 1165, 1175, 1186, 1231, 1235, 1244, 1244, 1260, 1269,
#        1269, 1270, 1270, 1288, 1289, 1295, 1296, 1300, 1316, 1319, 1319,
#        1321, 1358, 1367, 1370, 1370, 1372, 1372, 1374, 1434, 1434, 1434,
#        1435, 1435, 1435, 1474, 1474, 1474, 1476, 1476, 1476, 1558, 1558,
#        1570, 1574, 1589], dtype=int64), array([7, 4, 4, 3, 7, 3, 2, 3, 7, 6, 4, 3, 7, 3, 7, 7, 7, 7, 6, 3, 7, 8,
#        8, 3, 1, 3, 6, 7, 2, 2, 3, 7, 3, 3, 7, 3, 0, 0, 3, 7, 2, 3, 3, 2,
#        2, 7, 7, 0, 0, 0, 0, 2, 4, 2, 4, 0, 5, 3, 8, 2, 5, 2, 0, 0, 5, 0,
#        5, 0, 5, 3, 4, 8, 2, 5, 7, 7, 2, 0, 2, 8, 3, 7, 6, 7, 3, 3, 3, 3,
#        7, 8, 5, 5, 5, 2, 2, 2, 4, 4, 4, 5, 5, 2, 3, 7, 2, 2, 2, 2, 6, 5,
#        4, 4, 3, 4, 2, 4, 2, 2, 4, 3, 5, 8, 5, 8, 7, 7, 4, 4, 6, 6, 3, 7,
#        6, 4, 7, 3, 7, 3, 7, 3, 2, 4, 5, 2, 4, 5, 2, 4, 5, 2, 4, 5, 3, 4,
#        3, 2, 2], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print('Old Dataframe',df.shape)
print('New dataframe',df_new.shape)
# Out:
# Old Dataframe (1599, 10)
# New dataframe (1477, 10)

# %%
data_loss=((1599-1468)/1599)*100
print('data loss=',data_loss,'%')
# Out:
# data loss= 8.19262038774234 %

# %%
df_new
# Out:
#       fixed acidity  citric acid  residual sugar  chlorides  \
# 0               7.4         0.00             1.9      0.076
# 1               7.8         0.00             2.6      0.098
# 2               7.8         0.04             2.3      0.092
# 3              11.2         0.56             1.9      0.075
# 4               7.4         0.00             1.9      0.076
# ...             ...          ...             ...        ...
# 1594            6.2         0.08             2.0      0.090
# 1595            5.9         0.10             2.2      0.062
# 1596            6.3         0.13             2.3      0.076
# 1597            5.9         0.12             2.0      0.075
# 1598            6.0         0.47             3.6      0.067
#
#       free sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0                    11.0  0.99780  3.51       0.56      9.4        0
# 1                    25.0  0.99680  3.20       0.68      9.8        0
# 2                    15.0  0.99700  3.26       0.65      9.8        0
# 3                    17.0  0.99800  3.16       0.58      9.8        0
# 4                    11.0  0.99780  3.51       0.56      9.4        0
# ...                   ...      ...   ...        ...      ...      ...
# 1594                 32.0  0.99490  3.45       0.58     10.5        0
# 1595                 39.0  0.99512  3.52       0.76     11.2        0
# 1596                 29.0  0.99574  3.42       0.75     11.0        0
# 1597                 32.0  0.99547  3.57       0.71     10.2        0
# 1598                 18.0  0.99549  3.39       0.66     11.0        0
#
# [1477 rows x 10 columns]

# %%
df_new.shape
# Out:
# (1477, 10)

# %%
x=df_new.drop('quality',axis=1)
y=df_new['quality']

# %%
x
# Out:
#       fixed acidity  citric acid  residual sugar  chlorides  \
# 0               7.4         0.00             1.9      0.076
# 1               7.8         0.00             2.6      0.098
# 2               7.8         0.04             2.3      0.092
# 3              11.2         0.56             1.9      0.075
# 4               7.4         0.00             1.9      0.076
# ...             ...          ...             ...        ...
# 1594            6.2         0.08             2.0      0.090
# 1595            5.9         0.10             2.2      0.062
# 1596            6.3         0.13             2.3      0.076
# 1597            5.9         0.12             2.0      0.075
# 1598            6.0         0.47             3.6      0.067
#
#       free sulfur dioxide  density    pH  sulphates  alcohol
# 0                    11.0  0.99780  3.51       0.56      9.4
# 1                    25.0  0.99680  3.20       0.68      9.8
# 2                    15.0  0.99700  3.26       0.65      9.8
# 3                    17.0  0.99800  3.16       0.58      9.8
# 4                    11.0  0.99780  3.51       0.56      9.4
# ...                   ...      ...   ...        ...      ...
# 1594                 32.0  0.99490  3.45       0.58     10.5
# 1595                 39.0  0.99512  3.52       0.76     11.2
# 1596                 29.0  0.99574  3.42       0.75     11.0
# 1597                 32.0  0.99547  3.57       0.71     10.2
# 1598                 18.0  0.99549  3.39       0.66     11.0
#
# [1477 rows x 9 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: quality, Length: 1477, dtype: int64

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[-0.467465  , -1.51959338, -0.60498871, ...,  1.35394091,
#         -0.57501133, -1.1112312 ],
#        [-0.17003705, -1.51959338,  0.65058504, ..., -0.82131133,
#          0.46196892, -0.52657346],
#        [-0.17003705, -1.24022127,  0.21094643, ..., -0.38596159,
#          0.23172948, -0.52657346],
#        ...,
#        [-1.45160246, -0.66085597,  0.21094643, ...,  0.74083878,
#          0.93752177,  0.74324638],
#        [-1.88642951, -0.72214727, -0.36960658, ...,  1.75479591,
#          0.67571504, -0.03321591],
#        [-1.77311057,  1.073598  ,  1.54018924, ...,  0.53322662,
#          0.31040413,  0.74324638]])

# %%
#standard scaler to fit the values
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.467465  , -1.51959338, -0.60498871, ...,  1.35394091,
#         -0.57501133, -1.1112312 ],
#        [-0.17003705, -1.51959338,  0.65058504, ..., -0.82131133,
#          0.46196892, -0.52657346],
#        [-0.17003705, -1.24022127,  0.21094643, ..., -0.38596159,
#          0.23172948, -0.52657346],
#        ...,
#        [-1.45160246, -0.66085597,  0.21094643, ...,  0.74083878,
#          0.93752177,  0.74324638],
#        [-1.88642951, -0.72214727, -0.36960658, ...,  1.75479591,
#          0.67571504, -0.03321591],
#        [-1.77311057,  1.073598  ,  1.54018924, ...,  0.53322662,
#          0.31040413,  0.74324638]])

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print('At random_state:',i)
        print('Training accuracy_score',accuracy_score(y_train,pred_train)*100)
        print('testing accuracy_score',accuracy_score(y_test,pred_test)*100,'\n\n')
# Out:
# At random_state: 10
# Training accuracy_score 88.90770533446232
# testing accuracy_score 88.85135135135135
#
#
# At random_state: 143
# Training accuracy_score 89.24640135478408
# testing accuracy_score 89.1891891891892
#
#
# At random_state: 202
# Training accuracy_score 89.24640135478408
# testing accuracy_score 89.1891891891892
#
#
# At random_state: 236
# Training accuracy_score 88.90770533446232
# testing accuracy_score 88.85135135135135
#
#
# At random_state: 363
# Training accuracy_score 88.90770533446232
# testing accuracy_score 88.85135135135135
#
#
# At random_state: 434
# Training accuracy_score 89.24640135478408
# testing accuracy_score 89.1891891891892
#
#
# At random_state: 435
# Training accuracy_score 88.90770533446232
# testing accuracy_score 88.85135135135135
#
#
# At random_state: 466
# Training accuracy_score 88.90770533446232
# testing accuracy_score 88.85135135135135
#
#
# At random_state: 485
# Training accuracy_score 88.48433530906011
# testing accuracy_score 88.51351351351352
#
#
# At random_state: 573
# Training accuracy_score 88.48433530906011
# testing accuracy_score 88.51351351351352
#
#
# At random_state: 584
# Training accuracy_score 88.90770533446232
# testing accuracy_score 88.85135135135135
#
#
# At random_state: 623
# Training accuracy_score 88.2303132938188
# testing accuracy_score 88.17567567567568
#
#
# At random_state: 759
# Training accuracy_score 89.24640135478408
# testing accuracy_score 89.1891891891892
#
#
# At random_state: 799
# Training accuracy_score 88.90770533446232
# testing accuracy_score 88.85135135135135
#
#
# At random_state: 855
# Training accuracy_score 88.90770533446232
# testing accuracy_score 88.85135135135135
#
#
# At random_state: 877
# Training accuracy_score 88.90770533446232
# testing accuracy_score 88.85135135135135
#
#
# At random_state: 926
# Training accuracy_score 88.90770533446232
# testing accuracy_score 88.85135135135135
#
#
# At random_state: 969
# Training accuracy_score 89.16172734970364
# testing accuracy_score 89.1891891891892

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=926,test_size=.20)
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.89       258
#            1       0.09      0.05      0.07        38
#
#     accuracy                           0.81       296
#    macro avg       0.48      0.49      0.48       296
# weighted avg       0.77      0.81      0.79       296

# %%
#decision tree classifier

from sklearn.tree import DecisionTreeClassifier

dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
preddt=dt.predict(x_test)
print('accuracy score=',accuracy_score(y_test,preddt)*100)
print(confusion_matrix(y_test,preddt))
print(classification_report(y_test,preddt))
# Out:
# accuracy score= 83.1081081081081
# [[226  32]
#  [ 18  20]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90       258
#            1       0.38      0.53      0.44        38
#
#     accuracy                           0.83       296
#    macro avg       0.66      0.70      0.67       296
# weighted avg       0.86      0.83      0.84       296

# %%
#random forest classifier

from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier()
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print('accuracy score=',accuracy_score(y_test,predrf)*100)
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# accuracy score= 90.2027027027027
# [[249   9]
#  [ 20  18]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.94       258
#            1       0.67      0.47      0.55        38
#
#     accuracy                           0.90       296
#    macro avg       0.80      0.72      0.75       296
# weighted avg       0.89      0.90      0.89       296

# %%
#SVC 

from sklearn.svm import SVC

svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print('accuracy score=',accuracy_score(y_test,predsvc)*100)
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# accuracy score= 89.86486486486487
# [[250   8]
#  [ 22  16]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94       258
#            1       0.67      0.42      0.52        38
#
#     accuracy                           0.90       296
#    macro avg       0.79      0.70      0.73       296
# weighted avg       0.89      0.90      0.89       296

# %%
#cross validation for logistic regression

pred_lr=lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss= accuracy_score(y_test,pred_lr)
for j in range(2,10):
    lsscore=cross_val_score(lr,x,y,cv=j)
    lsc=lsscore.mean()
    print('at cv:',j)
    print('cross validation score is: ',lsc*100)
    print('accuracy score is: ',lss*100)
    print('\n')
# Out:
# at cv: 2
# cross validation score is:  85.98340245919374
# accuracy score is:  88.17567567567568
#
#
# at cv: 3
# cross validation score is:  88.42205511304607
# accuracy score is:  88.17567567567568
#
#
# at cv: 4
# cross validation score is:  87.94807002124075
# accuracy score is:  88.17567567567568
#
#
# at cv: 5
# cross validation score is:  87.6090242785158
# accuracy score is:  88.17567567567568
#
#
# at cv: 6
# cross validation score is:  87.60903196076497
# accuracy score is:  88.17567567567568
#
#
# at cv: 7
# cross validation score is:  87.88083953960732
# accuracy score is:  88.17567567567568
#
#
# at cv: 8
# cross validation score is:  88.48927732079905
# accuracy score is:  88.17567567567568
#
#
# at cv: 9
# cross validation score is:  88.15143302948181
# accuracy score is:  88.17567567567568

# %%
lsscore_selected= cross_val_score(lr,x,y,cv=6).mean()
print('the cv score is: ',lsscore_selected,'\nthe accuracy score is: ',lss)
# Out:
# the cv score is:  0.8760903196076496
# the accuracy score is:  0.8817567567567568

# %%
lsscore_selected= cross_val_score(dt,x,y,cv=6).mean()
print('the cv score is: ',lsscore_selected,'\nthe accuracy score is: ',lss)
# Out:
# the cv score is:  0.834117814862359
# the accuracy score is:  0.8817567567567568

# %%
lsscore_selected= cross_val_score(rf,x,y,cv=6).mean()
print('the cv score is: ',lsscore_selected,'\nthe accuracy score is: ',lss)
# Out:
# the cv score is:  0.8821961094104868
# the accuracy score is:  0.8817567567567568

# %%
lsscore_selected= cross_val_score(svc,x,y,cv=6).mean()
print('the cv score is: ',lsscore_selected,'\nthe accuracy score is: ',lss)
# Out:
# the cv score is:  0.8672909603589963
# the accuracy score is:  0.8817567567567568

# %%
#hyperparameter tuning

from sklearn.model_selection import GridSearchCV

#create parameters to pass 
parameters={'max_features': ['auto','sqrt','log2'],
           'max_depth': [4,5,6,7,8],
            'criterion': ['gini','entropy']
           }

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameters,cv=5,scoring='accuracy')
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 8, 'max_features': 'auto'}

# %%
GCV_pred=GCV.best_estimator_.predict(x_test)
accuracy_score(y_test,GCV_pred)
# Out:
# 0.8885135135135135

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(GCV.best_estimator_,x_test,y_test)
plt.title('ROC AUC plot')
plt.show()

# %%
import joblib
joblib.dump(GCV.best_estimator_,'red wine_quality.pkl')
# Out:
# ['red wine_quality.pkl']
