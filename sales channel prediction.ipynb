# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('sales channel prediction.csv')

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# radio         float64
# newspaper     float64
# sales         float64
# dtype: object

# %%
df.isnull()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0         False  False  False      False  False
# 1         False  False  False      False  False
# 2         False  False  False      False  False
# 3         False  False  False      False  False
# 4         False  False  False      False  False
# ..          ...    ...    ...        ...    ...
# 195       False  False  False      False  False
# 196       False  False  False      False  False
# 197       False  False  False      False  False
# 198       False  False  False      False  False
# 199       False  False  False      False  False
#
# [200 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.corr()
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
df.corr()['sales']
# Out:
# Unnamed: 0   -0.051616
# TV            0.782224
# radio         0.576223
# newspaper     0.228299
# sales         1.000000
# Name: sales, dtype: float64

# %%
plt.figure(figsize=(7,5))
sns.heatmap(df.corr(),annot=True,fmt='.02f',linewidth=2)
plt.title('correlation matrix')
plt.show()

# %%
df=df.drop(['Unnamed: 0'],axis=1)
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
sns.scatterplot(x='TV',y='sales',data=df)
# Out:
# <AxesSubplot:xlabel='TV', ylabel='sales'>

# %%
sns.scatterplot(x='radio',y='sales',data=df)
# Out:
# <AxesSubplot:xlabel='radio', ylabel='sales'>

# %%
sns.scatterplot(x='newspaper',y='sales',data=df)
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='sales'>

# %%
df.skew()
# Out:
# TV          -0.069853
# radio        0.094175
# newspaper    0.894720
# sales        0.407571
# dtype: float64

# %%
df.plot(kind='density',subplots=True,layout=(4,3),figsize=(10,15))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %%
sns.boxplot(df['TV'])
# Out:
# <AxesSubplot:xlabel='TV'>

# %%
sns.distplot(df['TV'])
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Density'>

# %%
sns.distplot(df['radio'])
# Out:
# <AxesSubplot:xlabel='radio', ylabel='Density'>

# %%
sns.distplot(df['newspaper'])
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='Density'>

# %%
sns.boxplot(df['radio'])
# Out:
# <AxesSubplot:xlabel='radio'>

# %%
sns.boxplot(df['newspaper'])
# Out:
# <AxesSubplot:xlabel='newspaper'>

# %%
sns.pairplot(df)
plt.show()

# %%
df.boxplot(figsize=[12,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor  
X = df[[ 'TV', 'radio', 'newspaper']]
  
# VIF dataframe                                       # to find multi colinearity
vif_df = pd.DataFrame()
vif_df["feature"] = X.columns
  
# calculating VIF for each feature
vif_df["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]                 #we find there's no much mutlicolinearity in the data
print(vif_df)
# Out:
#      feature       VIF
# 0         TV  2.486772
# 1      radio  3.285462
# 2  newspaper  3.055245

# %%
len(np.where(z>3)[0])
# Out:
# 2

# %%
df_new=df[(z<3).all(axis=1)]
print('old_dataframe',df.shape)
print('new_dataframe',df_new.shape)
# Out:
# old_dataframe (200, 4)
# new_dataframe (198, 4)

# %%
dataloss=(200-198)/200*100
print('dataloss =',dataloss,'%')
# Out:
# dataloss = 1.0 %

# %%
x=df_new.drop(['sales'],axis=1)
y=df_new['sales']

# %%
x
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [198 rows x 3 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 198, dtype: float64

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
df_new.skew()
# Out:
# TV          -0.082332
# radio        0.114842
# newspaper    0.650112
# sales        0.407130
# dtype: float64

# %%
x
# Out:
# array([[ 0.97510307,  0.98087971,  1.64869732],
#        [-1.16814523,  1.07204678,  0.82574845],
#        [-1.51741137,  1.46682477,  1.65177665],
#        [ 0.03347414,  1.19275107,  1.30494105],
#        [ 0.37786916, -0.77542007,  1.30158352],
#        [-1.64636488,  1.64303559,  1.82367532],
#        [-1.01663659,  0.67287513, -0.12971692],
#        [-0.32063785, -0.17175495, -0.85649398],
#        [-1.64800926, -1.52949868, -2.02291051],
#        [ 0.60591777, -1.47455549, -0.25282981],
#        [-0.91897916, -1.1701078 , -0.09338842],
#        [ 0.78672526,  0.11469947, -1.5590095 ],
#        [-1.42673002,  0.81535771,  1.54576975],
#        [-0.57092383, -1.0203899 , -1.21927873],
#        [ 0.6579356 ,  0.67909892,  0.86000433],
#        [ 0.55283643,  1.57278318,  1.11221281],
#        [ 1.61100839,  1.09021393,  1.21324161],
#        [-0.88413704, -0.11280027, -0.41760087],
#        [-0.01496639,  0.1082392 , -0.37095479],
#        [ 0.83185486,  0.3519114 ,  1.12982744],
#        [ 1.0648648 , -1.23164735, -0.12971692],
#        [-1.57584411, -0.41777853,  0.99379139],
#        [ 0.95301391, -0.35053156,  0.00780755],
#        [-0.96193193, -0.6457181 , -0.41760087],
#        [ 1.38041783, -1.38196085, -0.34798825],
# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
for i in range (0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f'at random state {i}, the training sccuracy is,{r2_score(y_train,pred_train)}')
    print(f'at random state {i}, the testing accuracy is,{r2_score(y_test,pred_test)}')
    print('\n')
# Out:
# at random state 0, the training sccuracy is,0.887651956911577
# at random state 0, the testing accuracy is,0.9089534087791836
#
#
# at random state 1, the training sccuracy is,0.894646388149097
# at random state 1, the testing accuracy is,0.88004757301431
#
#
# at random state 2, the training sccuracy is,0.9060723019610656
# at random state 2, the testing accuracy is,0.8448982176577586
#
#
# at random state 3, the training sccuracy is,0.8925826010707005
# at random state 3, the testing accuracy is,0.8950052408439985
#
#
# at random state 4, the training sccuracy is,0.8969430979982633
# at random state 4, the testing accuracy is,0.8629516284657703
#
#
# at random state 5, the training sccuracy is,0.8969335924524874
# at random state 5, the testing accuracy is,0.8605583133311904
#
#
# at random state 6, the training sccuracy is,0.8960422957758555
# at random state 6, the testing accuracy is,0.8773513838064108
#
#
# at random state 7, the training sccuracy is,0.8891187448788926
# at random state 7, the testing accuracy is,0.9033271582830187
#
#
# at random state 8, the training sccuracy is,0.8988422734100736
# at random state 8, the testing accuracy is,0.8667127409618052
#
#
# at random state 9, the training sccuracy is,0.887546139196302
# at random state 9, the testing accuracy is,0.9125665474655003
#
#
# at random state 10, the training sccuracy is,0.9194877159238715
# at random state 10, the testing accuracy is,0.7896401163933965
#
#
# at random state 11, the training sccuracy is,0.8832571821053032
# at random state 11, the testing accuracy is,0.9212894090980158
#
#
# at random state 12, the training sccuracy is,0.8917055104916523
# at random state 12, the testing accuracy is,0.8957866927602642
#
#
# at random state 13, the training sccuracy is,0.9035796874141765
# at random state 13, the testing accuracy is,0.8437863280459124
#
#
# at random state 14, the training sccuracy is,0.8843226444018331
# at random state 14, the testing accuracy is,0.9096771007795099
#
#
# at random state 15, the training sccuracy is,0.890478502593429
# at random state 15, the testing accuracy is,0.9001169975365411
#
#
# at random state 16, the training sccuracy is,0.8891334368048935
# at random state 16, the testing accuracy is,0.9045774485080351
#
#
# at random state 17, the training sccuracy is,0.888118737054185
# at random state 17, the testing accuracy is,0.909109919215
#
#
# at random state 18, the training sccuracy is,0.9072310494467994
# at random state 18, the testing accuracy is,0.837638443672529
#
#
# at random state 19, the training sccuracy is,0.8960567807746873
# at random state 19, the testing accuracy is,0.8564544195793496
#
#
# at random state 20, the training sccuracy is,0.8835546014055721
# at random state 20, the testing accuracy is,0.9127066778296986
#
#
# at random state 21, the training sccuracy is,0.8820142287583087
# at random state 21, the testing accuracy is,0.927152044714263
#
#
# at random state 22, the training sccuracy is,0.8851010804789081
# at random state 22, the testing accuracy is,0.9215665068409326
#
#
# at random state 23, the training sccuracy is,0.882735195772991
# at random state 23, the testing accuracy is,0.9274363206842117
#
#
# at random state 24, the training sccuracy is,0.8794938637414508
# at random state 24, the testing accuracy is,0.9415163142933334
#
#
# at random state 25, the training sccuracy is,0.882114795768282
# at random state 25, the testing accuracy is,0.9306623460667458
#
#
# at random state 26, the training sccuracy is,0.903238471271713
# at random state 26, the testing accuracy is,0.8122707645101674
#
#
# at random state 27, the training sccuracy is,0.9061730101034339
# at random state 27, the testing accuracy is,0.8230507802825541
#
#
# at random state 28, the training sccuracy is,0.9111003375663767
# at random state 28, the testing accuracy is,0.8288865714260056
#
#
# at random state 29, the training sccuracy is,0.9037121152918597
# at random state 29, the testing accuracy is,0.8489424447081044
#
#
# at random state 30, the training sccuracy is,0.9107606076642855
# at random state 30, the testing accuracy is,0.822047959361579
#
#
# at random state 31, the training sccuracy is,0.8795510951319069
# at random state 31, the testing accuracy is,0.9274544415583098
#
#
# at random state 32, the training sccuracy is,0.8855391280192961
# at random state 32, the testing accuracy is,0.9163146229725477
#
#
# at random state 33, the training sccuracy is,0.8884732404499053
# at random state 33, the testing accuracy is,0.9050037875477586
#
#
# at random state 34, the training sccuracy is,0.8947749436053578
# at random state 34, the testing accuracy is,0.8779061989522118
#
#
# at random state 35, the training sccuracy is,0.8875060866900626
# at random state 35, the testing accuracy is,0.9163812760546086
#
#
# at random state 36, the training sccuracy is,0.8879558046724405
# at random state 36, the testing accuracy is,0.9091847945172352
#
#
# at random state 37, the training sccuracy is,0.890941126646066
# at random state 37, the testing accuracy is,0.9049932879212408
#
#
# at random state 38, the training sccuracy is,0.8871699374106147
# at random state 38, the testing accuracy is,0.9173379122878049
#
#
# at random state 39, the training sccuracy is,0.9004198404225261
# at random state 39, the testing accuracy is,0.8581733282764193
#
#
# at random state 40, the training sccuracy is,0.8919371838997344
# at random state 40, the testing accuracy is,0.8903176047032664
#
#
# at random state 41, the training sccuracy is,0.896690428759299
# at random state 41, the testing accuracy is,0.8644366814495482
#
#
# at random state 42, the training sccuracy is,0.8929227094167005
# at random state 42, the testing accuracy is,0.8908811847241096
#
#
# at random state 43, the training sccuracy is,0.8961969383957055
# at random state 43, the testing accuracy is,0.8791829016578152
#
#
# at random state 44, the training sccuracy is,0.8992406610044749
# at random state 44, the testing accuracy is,0.8233817777584636
#
#
# at random state 45, the training sccuracy is,0.8938790272546205
# at random state 45, the testing accuracy is,0.8839196323488477
#
#
# at random state 46, the training sccuracy is,0.8970029837013715
# at random state 46, the testing accuracy is,0.8725301298034557
#
#
# at random state 47, the training sccuracy is,0.8922649076648099
# at random state 47, the testing accuracy is,0.8920510813546956
#
#
# at random state 48, the training sccuracy is,0.8984080677314695
# at random state 48, the testing accuracy is,0.8701807371493531
#
#
# at random state 49, the training sccuracy is,0.9065633908399553
# at random state 49, the testing accuracy is,0.8389187103404422
#
#
# at random state 50, the training sccuracy is,0.8995025444370829
# at random state 50, the testing accuracy is,0.8361348618742672
#
#
# at random state 51, the training sccuracy is,0.8898087463590976
# at random state 51, the testing accuracy is,0.8992073022615893
#
#
# at random state 52, the training sccuracy is,0.8933853493728101
# at random state 52, the testing accuracy is,0.8862374449102892
#
#
# at random state 53, the training sccuracy is,0.9017367014339203
# at random state 53, the testing accuracy is,0.8530450315514121
#
#
# at random state 54, the training sccuracy is,0.898115993491607
# at random state 54, the testing accuracy is,0.867926524528157
#
#
# at random state 55, the training sccuracy is,0.8922611359706284
# at random state 55, the testing accuracy is,0.8922509735267743
#
#
# at random state 56, the training sccuracy is,0.9013089684039983
# at random state 56, the testing accuracy is,0.8540109596264898
#
#
# at random state 57, the training sccuracy is,0.9003339263295471
# at random state 57, the testing accuracy is,0.8657565824409402
#
#
# at random state 58, the training sccuracy is,0.8800003776333974
# at random state 58, the testing accuracy is,0.9265683164051105
#
#
# at random state 59, the training sccuracy is,0.88655718866525
# at random state 59, the testing accuracy is,0.9109879747818171
#
#
# at random state 60, the training sccuracy is,0.8951878436488064
# at random state 60, the testing accuracy is,0.8830375536637746
#
#
# at random state 61, the training sccuracy is,0.9018512443670824
# at random state 61, the testing accuracy is,0.8544111674757082
#
#
# at random state 62, the training sccuracy is,0.8984762469419558
# at random state 62, the testing accuracy is,0.8552860972434726
#
#
# at random state 63, the training sccuracy is,0.8937984657587225
# at random state 63, the testing accuracy is,0.886338903666416
#
#
# at random state 64, the training sccuracy is,0.8855991660345288
# at random state 64, the testing accuracy is,0.918156502693925
#
#
# at random state 65, the training sccuracy is,0.8982210302397114
# at random state 65, the testing accuracy is,0.8731244556970348
#
#
# at random state 66, the training sccuracy is,0.8971444497845297
# at random state 66, the testing accuracy is,0.8764806471943664
#
#
# at random state 67, the training sccuracy is,0.8888336078483067
# at random state 67, the testing accuracy is,0.9054723560378996
#
#
# at random state 68, the training sccuracy is,0.8993954077505968
# at random state 68, the testing accuracy is,0.8675534029302641
#
#
# at random state 69, the training sccuracy is,0.8908246112945777
# at random state 69, the testing accuracy is,0.8984252855201322
#
#
# at random state 70, the training sccuracy is,0.882893564599166
# at random state 70, the testing accuracy is,0.9153801435878126
#
#
# at random state 71, the training sccuracy is,0.9064106901259898
# at random state 71, the testing accuracy is,0.8092644454679083
#
#
# at random state 72, the training sccuracy is,0.8880569087353963
# at random state 72, the testing accuracy is,0.9102580804931344
#
#
# at random state 73, the training sccuracy is,0.8961462434202774
# at random state 73, the testing accuracy is,0.8727390165301958
#
#
# at random state 74, the training sccuracy is,0.8716942661454817
# at random state 74, the testing accuracy is,0.9277780562015955
#
#
# at random state 75, the training sccuracy is,0.8948309037387028
# at random state 75, the testing accuracy is,0.8642494468695324
#
#
# at random state 76, the training sccuracy is,0.9014709987623731
# at random state 76, the testing accuracy is,0.8505241395139785
#
#
# at random state 77, the training sccuracy is,0.8863002718116214
# at random state 77, the testing accuracy is,0.9172554426569565
#
#
# at random state 78, the training sccuracy is,0.9090613183353508
# at random state 78, the testing accuracy is,0.7996235397388759
#
#
# at random state 79, the training sccuracy is,0.8909253545664884
# at random state 79, the testing accuracy is,0.8939805326799114
#
#
# at random state 80, the training sccuracy is,0.8905521932157018
# at random state 80, the testing accuracy is,0.9013517678161389
#
#
# at random state 81, the training sccuracy is,0.8857247564593793
# at random state 81, the testing accuracy is,0.9178038154956918
#
#
# at random state 82, the training sccuracy is,0.9070449476221734
# at random state 82, the testing accuracy is,0.8367441146604282
#
#
# at random state 83, the training sccuracy is,0.8979273456406925
# at random state 83, the testing accuracy is,0.8776043367025299
#
#
# at random state 84, the training sccuracy is,0.8835038133417217
# at random state 84, the testing accuracy is,0.9204036290557414
#
#
# at random state 85, the training sccuracy is,0.9079979849737276
# at random state 85, the testing accuracy is,0.7810746731780528
# at random state 86, the training sccuracy is,0.8909524359313872
# at random state 86, the testing accuracy is,0.9006919078988138
#
#
# at random state 87, the training sccuracy is,0.9096402376196124
# at random state 87, the testing accuracy is,0.8168932487779963
#
#
# at random state 88, the training sccuracy is,0.8949963210980534
# at random state 88, the testing accuracy is,0.8827370901609608
#
#
# at random state 89, the training sccuracy is,0.9014674973603718
# at random state 89, the testing accuracy is,0.8412084955059409
#
#
# at random state 90, the training sccuracy is,0.8782864819083691
# at random state 90, the testing accuracy is,0.9409303884284794
#
#
# at random state 91, the training sccuracy is,0.8907937212928047
# at random state 91, the testing accuracy is,0.8950336017855742
#
#
# at random state 92, the training sccuracy is,0.892037830702618
# at random state 92, the testing accuracy is,0.8902586311945704
#
#
# at random state 93, the training sccuracy is,0.9049840246580848
# at random state 93, the testing accuracy is,0.845907120082809
#
#
# at random state 94, the training sccuracy is,0.8998017748240077
# at random state 94, the testing accuracy is,0.8707746534651589
#
#
# at random state 95, the training sccuracy is,0.90500438974816
# at random state 95, the testing accuracy is,0.8490091204771155
#
#
# at random state 96, the training sccuracy is,0.9010850416786775
# at random state 96, the testing accuracy is,0.8497541271017177
#
#
# at random state 97, the training sccuracy is,0.8916171974765821
# at random state 97, the testing accuracy is,0.8975799705470211
#
#
# at random state 98, the training sccuracy is,0.9057179466066557
# at random state 98, the testing accuracy is,0.8405258764585248
#
#
# at random state 99, the training sccuracy is,0.8810209426074258
# at random state 99, the testing accuracy is,0.9279299622320564

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=53,test_size=.20)
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)
print(r2_score(y_test,pred_test))
# Out:
# 0.8530450315514121

# %%
from sklearn.tree import DecisionTreeRegressor
dtc=DecisionTreeRegressor()

from sklearn.svm import SVR
svr=SVR()

from sklearn.neighbors import KNeighborsRegressor
knn= KNeighborsRegressor()


model=[DecisionTreeRegressor(),SVR(),KNeighborsRegressor()]
for m in model:
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=53,test_size=.20)
    m.fit(x_train,y_train)
    pred_train=m.predict(x_train)
    pred_test=m.predict(x_test)
    print(m)
    print(f'at random state 53, the training sccuracy is,{r2_score(y_train,pred_train)}')
    print(f'at random state 53, the testing accuracy is,{r2_score(y_test,pred_test)}')
    print('\n')
# Out:
# DecisionTreeRegressor()
# at random state 53, the training sccuracy is,1.0
# at random state 53, the testing accuracy is,0.9359179238046536
#
#
# SVR()
# at random state 53, the training sccuracy is,0.9388806792128774
# at random state 53, the testing accuracy is,0.8534509294771846
#
#
# KNeighborsRegressor()
# at random state 53, the training sccuracy is,0.9670618591303208
# at random state 53, the testing accuracy is,0.8821703965872236

# %%
#cross validation

Train_accuracy=r2_score(y_train,pred_train)
testing_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is {cv_mean} and the train accuracy score is {Train_accuracy} and test accuracy score is {testing_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is 0.8884293884646675 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 3 the cv score is 0.8865013027699055 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 4 the cv score is 0.8862025071661894 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 5 the cv score is 0.8835125773390702 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 6 the cv score is 0.8850263176334817 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 7 the cv score is 0.88155654149156 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 8 the cv score is 0.8860107515323403 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 9 the cv score is 0.8789659556697184 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236

# %%
#cross validation

Train_accuracy=r2_score(y_train,pred_train)
testing_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(dtc,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is {cv_mean} and the train accuracy score is {Train_accuracy} and test accuracy score is {testing_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is 0.9272151058046771 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 3 the cv score is 0.9361214619571352 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 4 the cv score is 0.935657641151014 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 5 the cv score is 0.9506286901812928 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 6 the cv score is 0.9422305234288878 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 7 the cv score is 0.9497391275860663 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 8 the cv score is 0.9412080267216263 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 9 the cv score is 0.9395981694591753 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236

# %%
#cross validation

Train_accuracy=r2_score(y_train,pred_train)
testing_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(svr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is {cv_mean} and the train accuracy score is {Train_accuracy} and test accuracy score is {testing_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is 0.854430562852859 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 3 the cv score is 0.8941571193443218 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 4 the cv score is 0.9034056637579055 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 5 the cv score is 0.9103705771161218 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 6 the cv score is 0.9145652625158385 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 7 the cv score is 0.9120983316344573 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 8 the cv score is 0.9147863066930619 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 9 the cv score is 0.9164542570980715 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236

# %%
#cross validation

Train_accuracy=r2_score(y_train,pred_train)
testing_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(knn,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is {cv_mean} and the train accuracy score is {Train_accuracy} and test accuracy score is {testing_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is 0.9176068366716993 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 3 the cv score is 0.9159649839642352 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 4 the cv score is 0.9375845288549799 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 5 the cv score is 0.9371574531553971 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 6 the cv score is 0.9340550818613762 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 7 the cv score is 0.9376637314019086 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 8 the cv score is 0.9383185892156485 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236
#
#
# at cross fold 9 the cv score is 0.9346511624839411 and the train accuracy score is 0.9670618591303208 and test accuracy score is 0.8821703965872236

# %%
#grid search cv

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

from sklearn.linear_model import Lasso

parameters={'alpha':[.0001, .001, .01, .1, 1, 10 ],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.1, 'random_state': 0}

# %%
#model training


ls=Lasso(alpha=.01,random_state=0)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
ls_score_training*100
# Out:
# 90.17263395132883

# %%
lss=r2_score(y_test,pred_ls)
lss*100
# Out:
# 85.32079249692117

# %%
cv_score=cross_val_score(knn,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# 93.7157453155397

# %%
#ENsemble technique

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['mse','mae' ],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion='mae',max_features='auto')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_dec=rf.predict(x_test)

rfs=r2_score(y_test,pred_dec)
print('r2_score:',rfs*100)

rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print('cross val score',rfc*100)
# Out:
# r2_score: 95.93575475379835
# cross val score 97.81370078528502

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbreg = GradientBoostingRegressor(random_state=0)

clf = GradientBoostingRegressor(n_estimators=200,max_depth=5, random_state=0).fit(x_train, y_train)
gbreg.fit(x_train, y_train)

rf.score(x_train,y_train)
pred_dec=rf.predict(x_test)

rfs=r2_score(y_test,pred_dec)
print('r2_score:',rfs*100)

rfscore=cross_val_score(gbreg,x,y,cv=5)
rfc=rfscore.mean()
print('cross val score',rfc*100)
# Out:
# r2_score: 95.93575475379835
# cross val score 97.82684675924381

# %%
import pickle
filename='saleschannelprediction.pkl'
pickle.dump(rf,open(filename,'wb'))

# %%
loadmodel=pickle.load(open('saleschannelprediction.pkl','rb'))
result=loadmodel.score(x_test,y_test)
print(result*100)
# Out:
# 95.93575475379835

# %%
conclusion=pd.DataFrame([loadmodel.predict(x_test)[:],pred_dec[:]],index=['predicted','original'])
conclusion
# Out:
#               0       1      2       3      4     5      6       7      8   \
# predicted  19.53  20.688  10.42  11.349  5.851  9.66  17.64  21.452  8.543
# original   19.53  20.688  10.42  11.349  5.851  9.66  17.64  21.452  8.543
#
#                9   ...     30      31      32     33      34      35      36  \
# predicted  11.751  ...  11.75  16.942  10.598  6.616  10.123  10.336  20.609
# original   11.751  ...  11.75  16.942  10.598  6.616  10.123  10.336  20.609
#
#                37     38      39
# predicted  12.073  11.21  13.719
# original   12.073  11.21  13.719
#
# [2 rows x 40 columns]
