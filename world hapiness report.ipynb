# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('world happiness.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
#
# [158 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
#check null values in heatmap
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#label encode to convert object data into int value

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Country']=le.fit_transform(df['Country'])
df['Region']=le.fit_transform(df['Region'])

# %%
df['Country'].value_counts()
# Out:
# 135    1
# 10     1
# 51     1
# 77     1
# 57     1
#       ..
# 70     1
# 125    1
# 81     1
# 101    1
# 141    1
# Name: Country, Length: 158, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# 8    40
# 1    29
# 3    22
# 9    21
# 4    20
# 6     9
# 7     7
# 2     6
# 5     2
# 0     2
# Name: Region, dtype: int64

# %%
df.dtypes
# Out:
# Country                            int32
# Region                             int32
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# 50%          0.043940                  0.910245    1.029510
# 75%          0.052300                  1.158448    1.214405
# max          0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# std                    0.247078    0.150693                       0.120034
# min                    0.000000    0.000000                       0.000000
# 25%                    0.439185    0.328330                       0.061675
# 50%                    0.696705    0.435515                       0.107220
# 75%                    0.811013    0.549092                       0.180255
# max                    1.025250    0.669730                       0.551910
#
#        Generosity  Dystopia Residual
# count  158.000000         158.000000
# mean     0.237296           2.098977
# std      0.126685           0.553550
# min      0.000000           0.328580
# 25%      0.150553           1.759410
# 50%      0.216130           2.095415
# 75%      0.309883           2.462415
# max      0.795880           3.602140

# %%
df.corr()
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.033879 -0.022600        0.158516
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# Country                               0.083380        0.033879
# Region                               -0.176791       -0.022600
# Happiness Rank                       -0.992105        0.158516
# Happiness Score                       1.000000       -0.177254
# Standard Error                       -0.177254        1.000000
# Economy (GDP per Capita)              0.780966       -0.217651
# Family                                0.740605       -0.120728
# Health (Life Expectancy)              0.724200       -0.310287
# Freedom                               0.568211       -0.129773
# Trust (Government Corruption)         0.395199       -0.178325
# Generosity                            0.180319       -0.088439
# Dystopia Residual                     0.530474        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Country                                        0.037808  0.159416
# Region                                        -0.260139 -0.168533
# Happiness Rank                                -0.785267 -0.733644
# Happiness Score                                0.780966  0.740605
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# Health (Life Expectancy)                       0.816478  0.531104
# Freedom                                        0.370300  0.441518
# Trust (Government Corruption)                  0.307885  0.205605
# Generosity                                    -0.010465  0.087513
# Dystopia Residual                              0.040059  0.148117
#
#                                Health (Life Expectancy)   Freedom  \
# Country                                        0.037829  0.085684
# Region                                        -0.357508  0.092567
# Happiness Rank                                -0.735613 -0.556886
# Happiness Score                                0.724200  0.568211
# Standard Error                                -0.310287 -0.129773
# Economy (GDP per Capita)                       0.816478  0.370300
# Family                                         0.531104  0.441518
# Health (Life Expectancy)                       1.000000  0.360477
# Freedom                                        0.360477  1.000000
# Trust (Government Corruption)                  0.248335  0.493524
# Generosity                                     0.108335  0.373916
# Dystopia Residual                              0.018979  0.062783
#
#                                Trust (Government Corruption)  Generosity  \
# Country                                             0.088155    0.118085
# Region                                              0.165040    0.273557
# Happiness Rank                                     -0.372315   -0.160142
# Happiness Score                                     0.395199    0.180319
# Standard Error                                     -0.178325   -0.088439
# Economy (GDP per Capita)                            0.307885   -0.010465
# Family                                              0.205605    0.087513
# Health (Life Expectancy)                            0.248335    0.108335
# Freedom                                             0.493524    0.373916
# Trust (Government Corruption)                       1.000000    0.276123
# Generosity                                          0.276123    1.000000
# Dystopia Residual                                  -0.033105   -0.101301
#
#                                Dystopia Residual
# Country                                -0.019778
# Region                                 -0.057276
# Happiness Rank                         -0.521999
# Happiness Score                         0.530474
# Standard Error                          0.083981
# Economy (GDP per Capita)                0.040059
# Family                                  0.148117
# Health (Life Expectancy)                0.018979
# Freedom                                 0.062783
# Trust (Government Corruption)          -0.033105
# Generosity                             -0.101301
# Dystopia Residual                       1.000000

# %%
df.corr()['Happiness Score']
# Out:
# Country                          0.083380
# Region                          -0.176791
# Happiness Rank                  -0.992105
# Happiness Score                  1.000000
# Standard Error                  -0.177254
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Dystopia Residual                0.530474
# Name: Happiness Score, dtype: float64

# %%
df.corr()['Happiness Score'].sort_values()
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Region                          -0.176791
# Country                          0.083380
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %%
plt.figure(figsize=(10,14))
sns.heatmap(df.corr(),annot=True,fmt='.2f',linewidth=2)
plt.title('correlation matrix')
plt.show()

# %%
df=df.drop(['Happiness Rank','Standard Error'],axis=1)
df
# Out:
#      Country  Region  Happiness Score  Economy (GDP per Capita)   Family  \
# 0        135       9            7.587                   1.39651  1.34951
# 1         58       9            7.561                   1.30232  1.40223
# 2         37       9            7.527                   1.32548  1.36058
# 3        105       9            7.522                   1.45900  1.33095
# 4         24       5            7.427                   1.32629  1.32261
# ..       ...     ...              ...                       ...      ...
# 153      118       8            3.465                   0.22208  0.77370
# 154       13       8            3.340                   0.28665  0.35386
# 155      136       4            3.006                   0.66320  0.47489
# 156       21       8            2.905                   0.01530  0.41587
# 157      141       8            2.839                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
#
# [158 rows x 10 columns]

# %%
sns.scatterplot(x='Country',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Region',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Happiness Score',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Happiness Score'>

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Score                  0.097769
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df.plot(kind='kde',subplots=True,layout=(4,3),figsize=(10,15))  #we see skewness present in some columns
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %%
sns.pairplot(df)
plt.show()

# %%
df.boxplot(figsize=[12,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
df.plot(kind='box',subplots=True,layout=(4,3),figsize=(10,15))
# Out:
# Country                             AxesSubplot(0.125,0.712609;0.227941x0.167391)
# Region                           AxesSubplot(0.398529,0.712609;0.227941x0.167391)
# Happiness Score                  AxesSubplot(0.672059,0.712609;0.227941x0.167391)
# Economy (GDP per Capita)            AxesSubplot(0.125,0.511739;0.227941x0.167391)
# Family                           AxesSubplot(0.398529,0.511739;0.227941x0.167391)
# Health (Life Expectancy)         AxesSubplot(0.672059,0.511739;0.227941x0.167391)
# Freedom                              AxesSubplot(0.125,0.31087;0.227941x0.167391)
# Trust (Government Corruption)     AxesSubplot(0.398529,0.31087;0.227941x0.167391)
# Generosity                        AxesSubplot(0.672059,0.31087;0.227941x0.167391)
# Dystopia Residual                       AxesSubplot(0.125,0.11;0.227941x0.167391)
# dtype: object

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (158, 10)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27, 128, 147, 153, 155, 157], dtype=int64), array([7, 8, 4, 7, 9, 4], dtype=int64))

# %%
df.drop([27,128,147,153,155,157],axis=0)
# Out:
#      Country  Region  Happiness Score  Economy (GDP per Capita)   Family  \
# 0        135       9            7.587                   1.39651  1.34951
# 1         58       9            7.561                   1.30232  1.40223
# 2         37       9            7.527                   1.32548  1.36058
# 3        105       9            7.522                   1.45900  1.33095
# 4         24       5            7.427                   1.32629  1.32261
# ..       ...     ...              ...                       ...      ...
# 150       66       8            3.655                   0.46534  0.77115
# 151       20       8            3.587                   0.25812  0.85188
# 152        0       7            3.575                   0.31982  0.30285
# 154       13       8            3.340                   0.28665  0.35386
# 156       21       8            2.905                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 150                   0.15185  0.46866                        0.17922
# 151                   0.27125  0.39493                        0.12832
# 152                   0.30335  0.23414                        0.09719
# 154                   0.31910  0.48450                        0.08010
# 156                   0.22396  0.11850                        0.10062
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 150     0.20165            1.41723
# 151     0.21747            1.46494
# 152     0.36510            1.95210
# 154     0.18260            1.63328
# 156     0.19727            1.83302
#
# [152 rows x 10 columns]

# %%
print(np.where(z<3))
# Out:
# (array([  0,   0,   0, ..., 157, 157, 157], dtype=int64), array([0, 1, 2, ..., 7, 8, 9], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print('Old Dataframe',df.shape)
print('New dataframe',df_new.shape)
# Out:
# Old Dataframe (158, 10)
# New dataframe (152, 10)

# %%
data_loss=((158-152)/158)*100
print('data loss=',data_loss,'%')
# Out:
# data loss= 3.79746835443038 %

# %%
df_new
# Out:
#      Country  Region  Happiness Score  Economy (GDP per Capita)   Family  \
# 0        135       9            7.587                   1.39651  1.34951
# 1         58       9            7.561                   1.30232  1.40223
# 2         37       9            7.527                   1.32548  1.36058
# 3        105       9            7.522                   1.45900  1.33095
# 4         24       5            7.427                   1.32629  1.32261
# ..       ...     ...              ...                       ...      ...
# 150       66       8            3.655                   0.46534  0.77115
# 151       20       8            3.587                   0.25812  0.85188
# 152        0       7            3.575                   0.31982  0.30285
# 154       13       8            3.340                   0.28665  0.35386
# 156       21       8            2.905                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 150                   0.15185  0.46866                        0.17922
# 151                   0.27125  0.39493                        0.12832
# 152                   0.30335  0.23414                        0.09719
# 154                   0.31910  0.48450                        0.08010
# 156                   0.22396  0.11850                        0.10062
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 150     0.20165            1.41723
# 151     0.21747            1.46494
# 152     0.36510            1.95210
# 154     0.18260            1.63328
# 156     0.19727            1.83302
#
# [152 rows x 10 columns]

# %%
x=df_new.drop('Happiness Score',axis=1)
y=df_new['Happiness Score']

# %%
x
# Out:
#      Country  Region  Economy (GDP per Capita)   Family  \
# 0        135       9                   1.39651  1.34951
# 1         58       9                   1.30232  1.40223
# 2         37       9                   1.32548  1.36058
# 3        105       9                   1.45900  1.33095
# 4         24       5                   1.32629  1.32261
# ..       ...     ...                       ...      ...
# 150       66       8                   0.46534  0.77115
# 151       20       8                   0.25812  0.85188
# 152        0       7                   0.31982  0.30285
# 154       13       8                   0.28665  0.35386
# 156       21       8                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 150                   0.15185  0.46866                        0.17922
# 151                   0.27125  0.39493                        0.12832
# 152                   0.30335  0.23414                        0.09719
# 154                   0.31910  0.48450                        0.08010
# 156                   0.22396  0.11850                        0.10062
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 150     0.20165            1.41723
# 151     0.21747            1.46494
# 152     0.36510            1.95210
# 154     0.18260            1.63328
# 156     0.19727            1.83302
#
# [152 rows x 9 columns]

# %%
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 152, dtype: float64

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)
x=pd.DataFrame(x_new,columns=x.columns)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.1887051 ,  1.23986819,  1.49611068, ...,  1.8220699 ,
#          0.65595135,  0.74453432],
#        [-0.31421047,  1.23986819,  1.19771756, ...,  0.35523024,
#          1.57166845,  1.10426166],
#        [-0.81704158,  1.23986819,  1.27024568, ...,  1.95457489,
#          0.97742359,  0.69531125],
#        ...,
#        [-2.10859031,  0.67236186, -1.35114936, ..., -0.16357633,
#          1.13659521, -0.34441601],
#        [-1.51998719,  0.96090613, -1.4183337 , ..., -0.40394411,
#         -0.32359556, -0.94945138],
#        [-1.26108344,  0.96090613, -1.91827051, ..., -0.11827784,
#         -0.18319784, -0.57122297]])

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
x.shape
# Out:
# (152, 9)

# %%
y.shape
# Out:
# (152,)

# %%
#linear regression
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
pred=lr.predict(x_test)
print('predicted happiness score:',pred)
print('acctual happiness score',y_test)
# Out:
# predicted happiness score: [5.53248631 3.69816301 4.8995841  5.08100579 4.0225456  3.85024023
#  6.6716831  7.25841613 6.97527798 6.96814895 4.01081512 4.52661541
#  4.69933272 6.90444594 5.37178701 7.38969712 5.64275248 6.53424865
#  4.39110972 4.63235194 4.59418121 6.4619396  5.76946984 5.5573741
#  5.71697885 3.95361943 6.38500965 5.0626218  4.55805102 6.07925031
#  5.11071557 6.54175988 6.82619728 5.90695077 5.27341699 7.30748496
#  4.31466759 4.59633302 5.81911574 6.62229674 3.58198473 4.30171352
#  7.45089363 6.33808144 6.09546705 3.80161061 4.6893314  6.97853713
#  7.3476407  4.36954836 4.9582978 ]
# acctual happiness score 69     5.548
# 150    3.655
# 97     4.885
# 83     5.140
# 137    3.995
# 141    3.904
# 26     6.670
# 12     7.200
# 18     6.937
# 15     6.983
# 136    4.033
# 130    4.292
# 109    4.686
# 19     6.901
# 70     5.477
# 9      7.284
# 66     5.689
# 31     6.485
# 127    4.332
# 116    4.565
# 114    4.610
# 32     6.477
# 57     5.824
# 68     5.589
# 61     5.759
# 140    3.931
# 37     6.298
# 87     5.102
# 113    4.633
# 43     6.003
# 86     5.123
# 30     6.505
# 22     6.810
# 52     5.878
# 76     5.286
# 11     7.226
# 129    4.297
# 115    4.571
# 56     5.828
# 28     6.575
# 151    3.587
# 126    4.350
# 4      7.427
# 33     6.455
# 46     5.984
# 142    3.896
# 111    4.677
# 16     6.946
# 10     7.278
# 123    4.436
# 96     4.898
# Name: Happiness Score, dtype: float64

# %%
for i in range (0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f'for random state {i},the training accuracy is',{r2_score(y_train,pred_train)})
    print(f'for random state {i} ,the testing accuracy is',{r2_score(y_test, pred_test)})
    print('\n')
# Out:
# for random state 0,the training accuracy is {0.9955973297647485}
# for random state 0 ,the testing accuracy is {0.9944293147329664}
#
#
# for random state 1,the training accuracy is {0.9963089764474485}
# for random state 1 ,the testing accuracy is {0.9895373456586491}
#
#
# for random state 2,the training accuracy is {0.9953179984259644}
# for random state 2 ,the testing accuracy is {0.99519874604147}
#
#
# for random state 3,the training accuracy is {0.9959819352863601}
# for random state 3 ,the testing accuracy is {0.9928139297348394}
#
#
# for random state 4,the training accuracy is {0.9950697065762302}
# for random state 4 ,the testing accuracy is {0.9956518498290692}
#
#
# for random state 5,the training accuracy is {0.9955640135705419}
# for random state 5 ,the testing accuracy is {0.994412820384288}
#
#
# for random state 6,the training accuracy is {0.9956095914780224}
# for random state 6 ,the testing accuracy is {0.9944064180497849}
#
#
# for random state 7,the training accuracy is {0.9961452468842957}
# for random state 7 ,the testing accuracy is {0.9908839957237676}
#
#
# for random state 8,the training accuracy is {0.9953204402951364}
# for random state 8 ,the testing accuracy is {0.9952164283294848}
#
#
# for random state 9,the training accuracy is {0.9950231814808491}
# for random state 9 ,the testing accuracy is {0.9965172247737742}
#
#
# for random state 10,the training accuracy is {0.9950287409146095}
# for random state 10 ,the testing accuracy is {0.9967357506978891}
#
#
# for random state 11,the training accuracy is {0.9947685819378803}
# for random state 11 ,the testing accuracy is {0.9971568293415471}
#
#
# for random state 12,the training accuracy is {0.9949201359732639}
# for random state 12 ,the testing accuracy is {0.9968356953047766}
#
#
# for random state 13,the training accuracy is {0.995117849350025}
# for random state 13 ,the testing accuracy is {0.9962646215431282}
#
#
# for random state 14,the training accuracy is {0.995227040250576}
# for random state 14 ,the testing accuracy is {0.995112263514763}
#
#
# for random state 15,the training accuracy is {0.9953677804430178}
# for random state 15 ,the testing accuracy is {0.9950541436193567}
#
#
# for random state 16,the training accuracy is {0.9954592462929138}
# for random state 16 ,the testing accuracy is {0.994917727306812}
#
#
# for random state 17,the training accuracy is {0.9958449947913638}
# for random state 17 ,the testing accuracy is {0.9931388432576136}
#
#
# for random state 18,the training accuracy is {0.995498193211401}
# for random state 18 ,the testing accuracy is {0.9946339526372492}
#
#
# for random state 19,the training accuracy is {0.9955484505542542}
# for random state 19 ,the testing accuracy is {0.9945009955382506}
#
#
# for random state 20,the training accuracy is {0.9952898984014109}
# for random state 20 ,the testing accuracy is {0.9953999768693522}
#
#
# for random state 21,the training accuracy is {0.9954493279642516}
# for random state 21 ,the testing accuracy is {0.9947835387859414}
#
#
# for random state 22,the training accuracy is {0.9956982300898658}
# for random state 22 ,the testing accuracy is {0.9938609626538781}
#
#
# for random state 23,the training accuracy is {0.995531594895807}
# for random state 23 ,the testing accuracy is {0.9944153385933562}
#
#
# for random state 24,the training accuracy is {0.99542353726624}
# for random state 24 ,the testing accuracy is {0.9946442408281962}
#
#
# for random state 25,the training accuracy is {0.9953483583490155}
# for random state 25 ,the testing accuracy is {0.9955381577189465}
#
#
# for random state 26,the training accuracy is {0.9951819043890437}
# for random state 26 ,the testing accuracy is {0.9962895335434478}
#
#
# for random state 27,the training accuracy is {0.9958169637401393}
# for random state 27 ,the testing accuracy is {0.9929911488811131}
#
#
# for random state 28,the training accuracy is {0.9960320989762823}
# for random state 28 ,the testing accuracy is {0.9918385083483057}
#
#
# for random state 29,the training accuracy is {0.9953253812370019}
# for random state 29 ,the testing accuracy is {0.9952754769425252}
#
#
# for random state 30,the training accuracy is {0.9957097192995646}
# for random state 30 ,the testing accuracy is {0.9941864513095805}
#
#
# for random state 31,the training accuracy is {0.9954279441416086}
# for random state 31 ,the testing accuracy is {0.9952216642942854}
#
#
# for random state 32,the training accuracy is {0.9962252061893618}
# for random state 32 ,the testing accuracy is {0.9919829116163004}
#
#
# for random state 33,the training accuracy is {0.9958400523435281}
# for random state 33 ,the testing accuracy is {0.9932351789917384}
#
#
# for random state 34,the training accuracy is {0.9955004375713297}
# for random state 34 ,the testing accuracy is {0.9947365416856786}
#
#
# for random state 35,the training accuracy is {0.9954031551886285}
# for random state 35 ,the testing accuracy is {0.9952988248663616}
#
#
# for random state 36,the training accuracy is {0.9962573937142402}
# for random state 36 ,the testing accuracy is {0.9908021257186624}
#
#
# for random state 37,the training accuracy is {0.9949160275516219}
# for random state 37 ,the testing accuracy is {0.9963687597106815}
#
#
# for random state 38,the training accuracy is {0.9957025654392446}
# for random state 38 ,the testing accuracy is {0.9937191127170633}
#
#
# for random state 39,the training accuracy is {0.9947296760166867}
# for random state 39 ,the testing accuracy is {0.997470412670806}
#
#
# for random state 40,the training accuracy is {0.9952294528063875}
# for random state 40 ,the testing accuracy is {0.9958119703907613}
#
#
# for random state 41,the training accuracy is {0.9959852559946615}
# for random state 41 ,the testing accuracy is {0.9922322208297593}
#
#
# for random state 42,the training accuracy is {0.9951733111061078}
# for random state 42 ,the testing accuracy is {0.9962782834385645}
#
#
# for random state 43,the training accuracy is {0.9953433093882037}
# for random state 43 ,the testing accuracy is {0.9954069702831048}
#
#
# for random state 44,the training accuracy is {0.9953758290401663}
# for random state 44 ,the testing accuracy is {0.9954675914470893}
#
#
# for random state 45,the training accuracy is {0.9957805828356483}
# for random state 45 ,the testing accuracy is {0.9939888732716916}
#
#
# for random state 46,the training accuracy is {0.995667350823803}
# for random state 46 ,the testing accuracy is {0.9938429910382989}
#
#
# for random state 47,the training accuracy is {0.9957772987989288}
# for random state 47 ,the testing accuracy is {0.9944041653401597}
#
#
# for random state 48,the training accuracy is {0.9953918969589428}
# for random state 48 ,the testing accuracy is {0.9952987260134549}
#
#
# for random state 49,the training accuracy is {0.9951306636996645}
# for random state 49 ,the testing accuracy is {0.9960235273545285}
#
#
# for random state 50,the training accuracy is {0.9960031232277932}
# for random state 50 ,the testing accuracy is {0.9926682258471209}
#
#
# for random state 51,the training accuracy is {0.9954593271154701}
# for random state 51 ,the testing accuracy is {0.9948393087096006}
#
#
# for random state 52,the training accuracy is {0.9955073148689674}
# for random state 52 ,the testing accuracy is {0.9946318025027272}
#
#
# for random state 53,the training accuracy is {0.9955073382759181}
# for random state 53 ,the testing accuracy is {0.9948316426331599}
#
#
# for random state 54,the training accuracy is {0.9954667555424171}
# for random state 54 ,the testing accuracy is {0.9946145800381404}
#
#
# for random state 55,the training accuracy is {0.9957881716939415}
# for random state 55 ,the testing accuracy is {0.9936997748867935}
#
#
# for random state 56,the training accuracy is {0.9952395798864828}
# for random state 56 ,the testing accuracy is {0.994874658937189}
#
#
# for random state 57,the training accuracy is {0.9954390662171381}
# for random state 57 ,the testing accuracy is {0.9951372339986063}
#
#
# for random state 58,the training accuracy is {0.9953851516917709}
# for random state 58 ,the testing accuracy is {0.9954064344881269}
#
#
# for random state 59,the training accuracy is {0.9955378743761875}
# for random state 59 ,the testing accuracy is {0.9937798125594307}
#
#
# for random state 60,the training accuracy is {0.9952659096761594}
# for random state 60 ,the testing accuracy is {0.9954888224843557}
#
#
# for random state 61,the training accuracy is {0.9963869744094994}
# for random state 61 ,the testing accuracy is {0.9909414538885699}
# for random state 62,the training accuracy is {0.9958198247858806}
# for random state 62 ,the testing accuracy is {0.9933516116295704}
#
#
# for random state 63,the training accuracy is {0.9962834723090582}
# for random state 63 ,the testing accuracy is {0.9911134561933362}
#
#
# for random state 64,the training accuracy is {0.995818842306604}
# for random state 64 ,the testing accuracy is {0.9935859800858179}
#
#
# for random state 65,the training accuracy is {0.9960059769727266}
# for random state 65 ,the testing accuracy is {0.9929119711897011}
#
#
# for random state 66,the training accuracy is {0.9954734040508784}
# for random state 66 ,the testing accuracy is {0.9951900705291082}
#
#
# for random state 67,the training accuracy is {0.9956881933899245}
# for random state 67 ,the testing accuracy is {0.994211106654717}
#
#
# for random state 68,the training accuracy is {0.9957402862324715}
# for random state 68 ,the testing accuracy is {0.9937863607491056}
#
#
# for random state 69,the training accuracy is {0.9954066713754676}
# for random state 69 ,the testing accuracy is {0.995221553207031}
#
#
# for random state 70,the training accuracy is {0.9955946826363106}
# for random state 70 ,the testing accuracy is {0.9941105856620375}
#
#
# for random state 71,the training accuracy is {0.9958669849610199}
# for random state 71 ,the testing accuracy is {0.9919366991733753}
#
#
# for random state 72,the training accuracy is {0.9963179741803359}
# for random state 72 ,the testing accuracy is {0.9927471454655427}
#
#
# for random state 73,the training accuracy is {0.9955975300468197}
# for random state 73 ,the testing accuracy is {0.9943576575034776}
#
#
# for random state 74,the training accuracy is {0.9961531820324686}
# for random state 74 ,the testing accuracy is {0.9923794709123666}
#
#
# for random state 75,the training accuracy is {0.9962212011997337}
# for random state 75 ,the testing accuracy is {0.9910918236847318}
#
#
# for random state 76,the training accuracy is {0.9958713009018328}
# for random state 76 ,the testing accuracy is {0.9918608315525757}
#
#
# for random state 77,the training accuracy is {0.995454110295726}
# for random state 77 ,the testing accuracy is {0.9950245350879265}
#
#
# for random state 78,the training accuracy is {0.9958627315289902}
# for random state 78 ,the testing accuracy is {0.9920327503969792}
#
#
# for random state 79,the training accuracy is {0.9954303066280111}
# for random state 79 ,the testing accuracy is {0.9953647791611988}
#
#
# for random state 80,the training accuracy is {0.9955404706735578}
# for random state 80 ,the testing accuracy is {0.9923789992095732}
#
#
# for random state 81,the training accuracy is {0.9962106203742357}
# for random state 81 ,the testing accuracy is {0.9920656241502495}
#
#
# for random state 82,the training accuracy is {0.9955876882343451}
# for random state 82 ,the testing accuracy is {0.9941340023918185}
#
#
# for random state 83,the training accuracy is {0.9955636037464212}
# for random state 83 ,the testing accuracy is {0.9943431994976657}
#
#
# for random state 84,the training accuracy is {0.9952349021321927}
# for random state 84 ,the testing accuracy is {0.996039981372503}
#
#
# for random state 85,the training accuracy is {0.9951902349552613}
# for random state 85 ,the testing accuracy is {0.996028221366604}
#
#
# for random state 86,the training accuracy is {0.9962305001856347}
# for random state 86 ,the testing accuracy is {0.9919096304033307}
#
#
# for random state 87,the training accuracy is {0.9950245857934301}
# for random state 87 ,the testing accuracy is {0.996585449775597}
#
#
# for random state 88,the training accuracy is {0.9958978499926783}
# for random state 88 ,the testing accuracy is {0.9925339017952635}
#
#
# for random state 89,the training accuracy is {0.9955886427864787}
# for random state 89 ,the testing accuracy is {0.9934588512836209}
#
#
# for random state 90,the training accuracy is {0.9955136208903824}
# for random state 90 ,the testing accuracy is {0.9944555057460923}
#
#
# for random state 91,the training accuracy is {0.9954533520852443}
# for random state 91 ,the testing accuracy is {0.9944575015759377}
#
#
# for random state 92,the training accuracy is {0.9957578295976158}
# for random state 92 ,the testing accuracy is {0.9934128682028265}
#
#
# for random state 93,the training accuracy is {0.9957099502812681}
# for random state 93 ,the testing accuracy is {0.9942174398964905}
#
#
# for random state 94,the training accuracy is {0.9957482520403429}
# for random state 94 ,the testing accuracy is {0.9939918927040239}
#
#
# for random state 95,the training accuracy is {0.9954689912891836}
# for random state 95 ,the testing accuracy is {0.9949858520959036}
#
#
# for random state 96,the training accuracy is {0.9958986580200356}
# for random state 96 ,the testing accuracy is {0.9925981034672833}
#
#
# for random state 97,the training accuracy is {0.9946665902451914}
# for random state 97 ,the testing accuracy is {0.99814222265223}
#
#
# for random state 98,the training accuracy is {0.9956950869652151}
# for random state 98 ,the testing accuracy is {0.9932505331230259}
#
#
# for random state 99,the training accuracy is {0.9955264264778865}
# for random state 99 ,the testing accuracy is {0.9943461490380293}

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=69,test_size=0.20)

# %%
  lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.995221553207031

# %%
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred_test))
print('Mean squared error :',mean_squared_error(y_test,pred_test))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_test)))
# Out:
# error:
# Mean absolute error: 0.06455339525164545
# Mean squared error : 0.00665910700887095
# Root Mean Squared Error: 0.0816033517012074

# %%
from sklearn.tree import DecisionTreeRegressor
dtc=DecisionTreeRegressor()

# %%
for i in range (0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.20)
    dtc.fit(x_train,y_train)
    pred_train=dtc.predict(x_train)
    pred_test=dtc.predict(x_test)
    print(f'for random state {i},the training accuracy is',{r2_score(y_train,pred_train)})
    print(f'for random state {i} ,the testing accuracy is',{r2_score(y_test, pred_test)})
    print('\n')
# Out:
# for random state 0,the training accuracy is {1.0}
# for random state 0 ,the testing accuracy is {0.7908513902443373}
#
#
# for random state 1,the training accuracy is {1.0}
# for random state 1 ,the testing accuracy is {0.6822450552112791}
#
#
# for random state 2,the training accuracy is {1.0}
# for random state 2 ,the testing accuracy is {0.6659242470091018}
#
#
# for random state 3,the training accuracy is {1.0}
# for random state 3 ,the testing accuracy is {0.8097627999449939}
#
#
# for random state 4,the training accuracy is {1.0}
# for random state 4 ,the testing accuracy is {0.8574698043611043}
#
#
# for random state 5,the training accuracy is {1.0}
# for random state 5 ,the testing accuracy is {0.6021789422147781}
#
#
# for random state 6,the training accuracy is {1.0}
# for random state 6 ,the testing accuracy is {0.6552942401715345}
#
#
# for random state 7,the training accuracy is {1.0}
# for random state 7 ,the testing accuracy is {0.7519593280868007}
#
#
# for random state 8,the training accuracy is {1.0}
# for random state 8 ,the testing accuracy is {0.7846886907363185}
#
#
# for random state 9,the training accuracy is {1.0}
# for random state 9 ,the testing accuracy is {0.8589954265042897}
#
#
# for random state 10,the training accuracy is {1.0}
# for random state 10 ,the testing accuracy is {0.7766957177214249}
#
#
# for random state 11,the training accuracy is {1.0}
# for random state 11 ,the testing accuracy is {0.8780759164697916}
#
#
# for random state 12,the training accuracy is {1.0}
# for random state 12 ,the testing accuracy is {0.7606928655104203}
#
#
# for random state 13,the training accuracy is {1.0}
# for random state 13 ,the testing accuracy is {0.7757677229348805}
#
#
# for random state 14,the training accuracy is {1.0}
# for random state 14 ,the testing accuracy is {0.5797229439852875}
#
#
# for random state 15,the training accuracy is {1.0}
# for random state 15 ,the testing accuracy is {0.7789560014971431}
#
#
# for random state 16,the training accuracy is {1.0}
# for random state 16 ,the testing accuracy is {0.568699188239892}
#
#
# for random state 17,the training accuracy is {1.0}
# for random state 17 ,the testing accuracy is {0.7661250396502178}
#
#
# for random state 18,the training accuracy is {1.0}
# for random state 18 ,the testing accuracy is {0.6883422159713324}
#
#
# for random state 19,the training accuracy is {1.0}
# for random state 19 ,the testing accuracy is {0.7534247640025951}
#
#
# for random state 20,the training accuracy is {1.0}
# for random state 20 ,the testing accuracy is {0.7901258521427406}
#
#
# for random state 21,the training accuracy is {1.0}
# for random state 21 ,the testing accuracy is {0.767382192829282}
#
#
# for random state 22,the training accuracy is {1.0}
# for random state 22 ,the testing accuracy is {0.8232925223988208}
#
#
# for random state 23,the training accuracy is {1.0}
# for random state 23 ,the testing accuracy is {0.8563067148186334}
#
#
# for random state 24,the training accuracy is {1.0}
# for random state 24 ,the testing accuracy is {0.8461281258327408}
#
#
# for random state 25,the training accuracy is {1.0}
# for random state 25 ,the testing accuracy is {0.8330383575132887}
#
#
# for random state 26,the training accuracy is {1.0}
# for random state 26 ,the testing accuracy is {0.7608142936292783}
#
#
# for random state 27,the training accuracy is {1.0}
# for random state 27 ,the testing accuracy is {0.7920673310709073}
#
#
# for random state 28,the training accuracy is {1.0}
# for random state 28 ,the testing accuracy is {0.7587497579758147}
#
#
# for random state 29,the training accuracy is {1.0}
# for random state 29 ,the testing accuracy is {0.7599359719585469}
#
#
# for random state 30,the training accuracy is {1.0}
# for random state 30 ,the testing accuracy is {0.7885017076056404}
#
#
# for random state 31,the training accuracy is {1.0}
# for random state 31 ,the testing accuracy is {0.5547901292804702}
#
#
# for random state 32,the training accuracy is {1.0}
# for random state 32 ,the testing accuracy is {0.7698768067191442}
#
#
# for random state 33,the training accuracy is {1.0}
# for random state 33 ,the testing accuracy is {0.7911592482576693}
#
#
# for random state 34,the training accuracy is {1.0}
# for random state 34 ,the testing accuracy is {0.777439379037781}
#
#
# for random state 35,the training accuracy is {1.0}
# for random state 35 ,the testing accuracy is {0.7553347675118784}
#
#
# for random state 36,the training accuracy is {1.0}
# for random state 36 ,the testing accuracy is {0.7920072397512067}
#
#
# for random state 37,the training accuracy is {1.0}
# for random state 37 ,the testing accuracy is {0.7619776678711191}
#
#
# for random state 38,the training accuracy is {1.0}
# for random state 38 ,the testing accuracy is {0.7040111737297648}
#
#
# for random state 39,the training accuracy is {1.0}
# for random state 39 ,the testing accuracy is {0.8312917891020102}
#
#
# for random state 40,the training accuracy is {1.0}
# for random state 40 ,the testing accuracy is {0.5181038402568496}
#
#
# for random state 41,the training accuracy is {1.0}
# for random state 41 ,the testing accuracy is {0.40191958756456725}
#
#
# for random state 42,the training accuracy is {1.0}
# for random state 42 ,the testing accuracy is {0.7443402034733321}
#
#
# for random state 43,the training accuracy is {1.0}
# for random state 43 ,the testing accuracy is {0.8837220666111227}
#
#
# for random state 44,the training accuracy is {1.0}
# for random state 44 ,the testing accuracy is {0.7546631034910664}
#
#
# for random state 45,the training accuracy is {1.0}
# for random state 45 ,the testing accuracy is {0.8035644350050085}
#
#
# for random state 46,the training accuracy is {1.0}
# for random state 46 ,the testing accuracy is {0.674868549436076}
#
#
# for random state 47,the training accuracy is {1.0}
# for random state 47 ,the testing accuracy is {0.783736906140009}
#
#
# for random state 48,the training accuracy is {1.0}
# for random state 48 ,the testing accuracy is {0.8162528968296627}
#
#
# for random state 49,the training accuracy is {1.0}
# for random state 49 ,the testing accuracy is {0.8676906046129065}
#
#
# for random state 50,the training accuracy is {1.0}
# for random state 50 ,the testing accuracy is {0.8338728262055725}
#
#
# for random state 51,the training accuracy is {1.0}
# for random state 51 ,the testing accuracy is {0.702949188894977}
#
#
# for random state 52,the training accuracy is {1.0}
# for random state 52 ,the testing accuracy is {0.73966406146034}
#
#
# for random state 53,the training accuracy is {1.0}
# for random state 53 ,the testing accuracy is {0.7067866233218631}
#
#
# for random state 54,the training accuracy is {1.0}
# for random state 54 ,the testing accuracy is {0.6729750095883544}
#
#
# for random state 55,the training accuracy is {1.0}
# for random state 55 ,the testing accuracy is {0.8025599959912375}
#
#
# for random state 56,the training accuracy is {1.0}
# for random state 56 ,the testing accuracy is {0.8794433351133721}
#
#
# for random state 57,the training accuracy is {1.0}
# for random state 57 ,the testing accuracy is {0.6443032533432025}
#
#
# for random state 58,the training accuracy is {1.0}
# for random state 58 ,the testing accuracy is {0.562175084950175}
#
#
# for random state 59,the training accuracy is {1.0}
# for random state 59 ,the testing accuracy is {0.7583380155642103}
#
#
# for random state 60,the training accuracy is {1.0}
# for random state 60 ,the testing accuracy is {0.7724934834536301}
#
#
# for random state 61,the training accuracy is {1.0}
# for random state 61 ,the testing accuracy is {0.7237635957229684}
#
#
# for random state 62,the training accuracy is {1.0}
# for random state 62 ,the testing accuracy is {0.8174061472172183}
#
#
# for random state 63,the training accuracy is {1.0}
# for random state 63 ,the testing accuracy is {0.7040129870309975}
#
#
# for random state 64,the training accuracy is {1.0}
# for random state 64 ,the testing accuracy is {0.8319636729909134}
#
#
# for random state 65,the training accuracy is {1.0}
# for random state 65 ,the testing accuracy is {0.7552942733212171}
#
#
# for random state 66,the training accuracy is {1.0}
# for random state 66 ,the testing accuracy is {0.7215534497365268}
#
#
# for random state 67,the training accuracy is {1.0}
# for random state 67 ,the testing accuracy is {0.8492515648271248}
#
#
# for random state 68,the training accuracy is {1.0}
# for random state 68 ,the testing accuracy is {0.7831920151464669}
#
#
# for random state 69,the training accuracy is {1.0}
# for random state 69 ,the testing accuracy is {0.8495084392868768}
#
#
# for random state 70,the training accuracy is {1.0}
# for random state 70 ,the testing accuracy is {0.7657345450057889}
#
#
# for random state 71,the training accuracy is {1.0}
# for random state 71 ,the testing accuracy is {0.2779092244453323}
#
#
# for random state 72,the training accuracy is {1.0}
# for random state 72 ,the testing accuracy is {0.9031910300191227}
#
#
# for random state 73,the training accuracy is {1.0}
# for random state 73 ,the testing accuracy is {0.6395228745192623}
#
#
# for random state 74,the training accuracy is {1.0}
# for random state 74 ,the testing accuracy is {0.7042444487494053}
#
#
# for random state 75,the training accuracy is {1.0}
# for random state 75 ,the testing accuracy is {0.7284890882713829}
#
#
# for random state 76,the training accuracy is {1.0}
# for random state 76 ,the testing accuracy is {0.6282764634073073}
#
#
# for random state 77,the training accuracy is {1.0}
# for random state 77 ,the testing accuracy is {0.791179365464401}
#
#
# for random state 78,the training accuracy is {1.0}
# for random state 78 ,the testing accuracy is {0.7163850712068083}
#
#
# for random state 79,the training accuracy is {1.0}
# for random state 79 ,the testing accuracy is {0.6546844255522085}
#
#
# for random state 80,the training accuracy is {1.0}
# for random state 80 ,the testing accuracy is {0.6638522352873603}
#
#
# for random state 81,the training accuracy is {1.0}
# for random state 81 ,the testing accuracy is {0.7324656317326372}
#
#
# for random state 82,the training accuracy is {1.0}
# for random state 82 ,the testing accuracy is {0.8385669770525381}
#
#
# for random state 83,the training accuracy is {1.0}
# for random state 83 ,the testing accuracy is {0.8208679475498482}
#
#
# for random state 84,the training accuracy is {1.0}
# for random state 84 ,the testing accuracy is {0.7061518708837702}
#
#
# for random state 85,the training accuracy is {1.0}
# for random state 85 ,the testing accuracy is {0.6815430428553744}
#
#
# for random state 86,the training accuracy is {1.0}
# for random state 86 ,the testing accuracy is {0.8060458862282835}
#
#
# for random state 87,the training accuracy is {1.0}
# for random state 87 ,the testing accuracy is {0.7054326570308858}
#
#
# for random state 88,the training accuracy is {1.0}
# for random state 88 ,the testing accuracy is {0.7533687701392916}
# for random state 89,the training accuracy is {1.0}
# for random state 89 ,the testing accuracy is {0.8656346248309907}
#
#
# for random state 90,the training accuracy is {1.0}
# for random state 90 ,the testing accuracy is {0.8222444815152163}
#
#
# for random state 91,the training accuracy is {1.0}
# for random state 91 ,the testing accuracy is {0.61842335834262}
#
#
# for random state 92,the training accuracy is {1.0}
# for random state 92 ,the testing accuracy is {0.720448918842669}
#
#
# for random state 93,the training accuracy is {1.0}
# for random state 93 ,the testing accuracy is {0.7649390721160072}
#
#
# for random state 94,the training accuracy is {1.0}
# for random state 94 ,the testing accuracy is {0.7323448769261054}
#
#
# for random state 95,the training accuracy is {1.0}
# for random state 95 ,the testing accuracy is {0.7844461525280333}
#
#
# for random state 96,the training accuracy is {1.0}
# for random state 96 ,the testing accuracy is {0.7867313771618036}
#
#
# for random state 97,the training accuracy is {1.0}
# for random state 97 ,the testing accuracy is {0.6999565378801484}
#
#
# for random state 98,the training accuracy is {1.0}
# for random state 98 ,the testing accuracy is {0.5521668495268992}
#
#
# for random state 99,the training accuracy is {1.0}
# for random state 99 ,the testing accuracy is {0.8156760485424179}

# %%
from sklearn.svm import SVR
svr=SVR()

# %%
for i in range (0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.20)
    svr.fit(x_train,y_train)
    pred_train=svr.predict(x_train)
    pred_test=svr.predict(x_test)
    print(f'for random state {i},the training accuracy is',{r2_score(y_train,pred_train)})
    print(f'for random state {i} ,the testing accuracy is',{r2_score(y_test, pred_test)})
    print('\n')
# Out:
# for random state 0,the training accuracy is {0.9892923777233815}
# for random state 0 ,the testing accuracy is {0.9347473513264215}
#
#
# for random state 1,the training accuracy is {0.9908361007272386}
# for random state 1 ,the testing accuracy is {0.9645326602991743}
#
#
# for random state 2,the training accuracy is {0.9903365430991027}
# for random state 2 ,the testing accuracy is {0.9571225161388749}
#
#
# for random state 3,the training accuracy is {0.9911581272828943}
# for random state 3 ,the testing accuracy is {0.9658004218793249}
#
#
# for random state 4,the training accuracy is {0.9906412943573027}
# for random state 4 ,the testing accuracy is {0.9619143396853582}
#
#
# for random state 5,the training accuracy is {0.9920452925557898}
# for random state 5 ,the testing accuracy is {0.9499449754117258}
#
#
# for random state 6,the training accuracy is {0.9906984361427026}
# for random state 6 ,the testing accuracy is {0.9643527828420068}
#
#
# for random state 7,the training accuracy is {0.9914094008840033}
# for random state 7 ,the testing accuracy is {0.9246506587463799}
#
#
# for random state 8,the training accuracy is {0.9882504582659752}
# for random state 8 ,the testing accuracy is {0.963371639267096}
#
#
# for random state 9,the training accuracy is {0.9909061208883259}
# for random state 9 ,the testing accuracy is {0.9221728148528654}
#
#
# for random state 10,the training accuracy is {0.9898107603547569}
# for random state 10 ,the testing accuracy is {0.9631079814245682}
#
#
# for random state 11,the training accuracy is {0.9883586582795248}
# for random state 11 ,the testing accuracy is {0.951715152615422}
#
#
# for random state 12,the training accuracy is {0.9904415377196448}
# for random state 12 ,the testing accuracy is {0.975008350042783}
#
#
# for random state 13,the training accuracy is {0.9883185788924983}
# for random state 13 ,the testing accuracy is {0.9721676283467117}
#
#
# for random state 14,the training accuracy is {0.9897520424767875}
# for random state 14 ,the testing accuracy is {0.9705098773829275}
#
#
# for random state 15,the training accuracy is {0.9883460036327113}
# for random state 15 ,the testing accuracy is {0.9586258655192648}
#
#
# for random state 16,the training accuracy is {0.9901851900344674}
# for random state 16 ,the testing accuracy is {0.850430681205211}
#
#
# for random state 17,the training accuracy is {0.9874871515590175}
# for random state 17 ,the testing accuracy is {0.9314159872552449}
#
#
# for random state 18,the training accuracy is {0.9904844405279759}
# for random state 18 ,the testing accuracy is {0.9732357936691532}
#
#
# for random state 19,the training accuracy is {0.9871765711597856}
# for random state 19 ,the testing accuracy is {0.9337142922926382}
#
#
# for random state 20,the training accuracy is {0.9908739862846281}
# for random state 20 ,the testing accuracy is {0.9669110762320209}
#
#
# for random state 21,the training accuracy is {0.9919132227183564}
# for random state 21 ,the testing accuracy is {0.946904642612635}
#
#
# for random state 22,the training accuracy is {0.9890672231197765}
# for random state 22 ,the testing accuracy is {0.951124171435556}
#
#
# for random state 23,the training accuracy is {0.9907353958609393}
# for random state 23 ,the testing accuracy is {0.958144551731485}
#
#
# for random state 24,the training accuracy is {0.9906233022615079}
# for random state 24 ,the testing accuracy is {0.9744950190518099}
#
#
# for random state 25,the training accuracy is {0.988490728903704}
# for random state 25 ,the testing accuracy is {0.959559108553767}
#
#
# for random state 26,the training accuracy is {0.9903247599650378}
# for random state 26 ,the testing accuracy is {0.9660576147461998}
#
#
# for random state 27,the training accuracy is {0.9901181378390056}
# for random state 27 ,the testing accuracy is {0.956611942572663}
#
#
# for random state 28,the training accuracy is {0.9904996546924913}
# for random state 28 ,the testing accuracy is {0.95110767274848}
#
#
# for random state 29,the training accuracy is {0.9897072823412771}
# for random state 29 ,the testing accuracy is {0.9461905713884331}
#
#
# for random state 30,the training accuracy is {0.9886687830105467}
# for random state 30 ,the testing accuracy is {0.955219050865262}
#
#
# for random state 31,the training accuracy is {0.9878495829444289}
# for random state 31 ,the testing accuracy is {0.9146818752774357}
#
#
# for random state 32,the training accuracy is {0.990205569717556}
# for random state 32 ,the testing accuracy is {0.938389813756589}
#
#
# for random state 33,the training accuracy is {0.9901366630794198}
# for random state 33 ,the testing accuracy is {0.9194145554308181}
#
#
# for random state 34,the training accuracy is {0.9927302068888255}
# for random state 34 ,the testing accuracy is {0.9589090777782648}
#
#
# for random state 35,the training accuracy is {0.9915694954585825}
# for random state 35 ,the testing accuracy is {0.9482987169423304}
#
#
# for random state 36,the training accuracy is {0.9892809406347473}
# for random state 36 ,the testing accuracy is {0.9664693916304699}
#
#
# for random state 37,the training accuracy is {0.9885081769833121}
# for random state 37 ,the testing accuracy is {0.9587712260217665}
#
#
# for random state 38,the training accuracy is {0.9900649877269475}
# for random state 38 ,the testing accuracy is {0.9734778975990653}
#
#
# for random state 39,the training accuracy is {0.988270681378578}
# for random state 39 ,the testing accuracy is {0.9395932313515598}
#
#
# for random state 40,the training accuracy is {0.9907363077556496}
# for random state 40 ,the testing accuracy is {0.9255682467907077}
#
#
# for random state 41,the training accuracy is {0.9890328377366566}
# for random state 41 ,the testing accuracy is {0.9521408084378824}
#
#
# for random state 42,the training accuracy is {0.9895023724295908}
# for random state 42 ,the testing accuracy is {0.9598157791993508}
#
#
# for random state 43,the training accuracy is {0.9900215421479671}
# for random state 43 ,the testing accuracy is {0.9635235479739428}
#
#
# for random state 44,the training accuracy is {0.9905319133343502}
# for random state 44 ,the testing accuracy is {0.9402097127767016}
#
#
# for random state 45,the training accuracy is {0.9914164533237212}
# for random state 45 ,the testing accuracy is {0.9567299708816378}
#
#
# for random state 46,the training accuracy is {0.9907154357803887}
# for random state 46 ,the testing accuracy is {0.9519978020211377}
#
#
# for random state 47,the training accuracy is {0.9912877186473749}
# for random state 47 ,the testing accuracy is {0.9214110283305743}
#
#
# for random state 48,the training accuracy is {0.9875851261338433}
# for random state 48 ,the testing accuracy is {0.9514411736382342}
#
#
# for random state 49,the training accuracy is {0.9898420085217525}
# for random state 49 ,the testing accuracy is {0.9292999168580377}
#
#
# for random state 50,the training accuracy is {0.9877851147355462}
# for random state 50 ,the testing accuracy is {0.9443872493524016}
#
#
# for random state 51,the training accuracy is {0.990956291783541}
# for random state 51 ,the testing accuracy is {0.9602698958285348}
#
#
# for random state 52,the training accuracy is {0.9905919850154291}
# for random state 52 ,the testing accuracy is {0.9592541811890154}
#
#
# for random state 53,the training accuracy is {0.9898174653262276}
# for random state 53 ,the testing accuracy is {0.9497933305749158}
#
#
# for random state 54,the training accuracy is {0.9880101778316382}
# for random state 54 ,the testing accuracy is {0.9681751911160038}
#
#
# for random state 55,the training accuracy is {0.991539776584545}
# for random state 55 ,the testing accuracy is {0.8867066087915516}
#
#
# for random state 56,the training accuracy is {0.9893745499138016}
# for random state 56 ,the testing accuracy is {0.9596341628104371}
#
#
# for random state 57,the training accuracy is {0.9907574170325844}
# for random state 57 ,the testing accuracy is {0.9491539084970562}
#
#
# for random state 58,the training accuracy is {0.9910312667085266}
# for random state 58 ,the testing accuracy is {0.9397423310774119}
#
#
# for random state 59,the training accuracy is {0.9881935836819237}
# for random state 59 ,the testing accuracy is {0.9180971473112889}
#
#
# for random state 60,the training accuracy is {0.989923670651719}
# for random state 60 ,the testing accuracy is {0.9466650932669505}
#
#
# for random state 61,the training accuracy is {0.9917896567051774}
# for random state 61 ,the testing accuracy is {0.9302736288198459}
#
#
# for random state 62,the training accuracy is {0.9901134906472658}
# for random state 62 ,the testing accuracy is {0.9350879356912531}
#
#
# for random state 63,the training accuracy is {0.9880310148800713}
# for random state 63 ,the testing accuracy is {0.9642002703009709}
#
#
# for random state 64,the training accuracy is {0.9901257935671749}
# for random state 64 ,the testing accuracy is {0.9578107093351281}
#
#
# for random state 65,the training accuracy is {0.9904182461420173}
# for random state 65 ,the testing accuracy is {0.9551936435069542}
#
#
# for random state 66,the training accuracy is {0.9898031815086021}
# for random state 66 ,the testing accuracy is {0.9426829710882659}
#
#
# for random state 67,the training accuracy is {0.9906612597894262}
# for random state 67 ,the testing accuracy is {0.9347747058374661}
#
#
# for random state 68,the training accuracy is {0.99004122537752}
# for random state 68 ,the testing accuracy is {0.9575938741860687}
#
#
# for random state 69,the training accuracy is {0.9893038389150217}
# for random state 69 ,the testing accuracy is {0.960495402363368}
#
#
# for random state 70,the training accuracy is {0.988655312128442}
# for random state 70 ,the testing accuracy is {0.9781292565866797}
#
#
# for random state 71,the training accuracy is {0.9910082110012297}
# for random state 71 ,the testing accuracy is {0.96604131291828}
# for random state 72,the training accuracy is {0.99042699873783}
# for random state 72 ,the testing accuracy is {0.9380066422215614}
#
#
# for random state 73,the training accuracy is {0.9911912338578122}
# for random state 73 ,the testing accuracy is {0.9130163394011955}
#
#
# for random state 74,the training accuracy is {0.9916667274244004}
# for random state 74 ,the testing accuracy is {0.9566371510112311}
#
#
# for random state 75,the training accuracy is {0.9911719769188551}
# for random state 75 ,the testing accuracy is {0.9453458437535733}
#
#
# for random state 76,the training accuracy is {0.9914052369478472}
# for random state 76 ,the testing accuracy is {0.9391789790725195}
#
#
# for random state 77,the training accuracy is {0.9909826976681406}
# for random state 77 ,the testing accuracy is {0.9375600379373846}
#
#
# for random state 78,the training accuracy is {0.9902933440944879}
# for random state 78 ,the testing accuracy is {0.9559303262980843}
#
#
# for random state 79,the training accuracy is {0.9885617851522803}
# for random state 79 ,the testing accuracy is {0.9165369615822221}
#
#
# for random state 80,the training accuracy is {0.9909268915595024}
# for random state 80 ,the testing accuracy is {0.9402049223927516}
#
#
# for random state 81,the training accuracy is {0.991634393817812}
# for random state 81 ,the testing accuracy is {0.9388391904547092}
#
#
# for random state 82,the training accuracy is {0.991414228116324}
# for random state 82 ,the testing accuracy is {0.9524698325029619}
#
#
# for random state 83,the training accuracy is {0.9887779932245618}
# for random state 83 ,the testing accuracy is {0.9645547914092361}
#
#
# for random state 84,the training accuracy is {0.9902293425866827}
# for random state 84 ,the testing accuracy is {0.9349688418621587}
#
#
# for random state 85,the training accuracy is {0.9891692501229973}
# for random state 85 ,the testing accuracy is {0.9481312275228371}
#
#
# for random state 86,the training accuracy is {0.9909701762275385}
# for random state 86 ,the testing accuracy is {0.8938891398777662}
#
#
# for random state 87,the training accuracy is {0.9899753055467017}
# for random state 87 ,the testing accuracy is {0.9590846549309119}
#
#
# for random state 88,the training accuracy is {0.9881727463870724}
# for random state 88 ,the testing accuracy is {0.951625196789147}
#
#
# for random state 89,the training accuracy is {0.9902375703930417}
# for random state 89 ,the testing accuracy is {0.9752887023491258}
#
#
# for random state 90,the training accuracy is {0.990815940172103}
# for random state 90 ,the testing accuracy is {0.9489542695029218}
#
#
# for random state 91,the training accuracy is {0.9892169595807899}
# for random state 91 ,the testing accuracy is {0.937767542252873}
#
#
# for random state 92,the training accuracy is {0.9925152304928985}
# for random state 92 ,the testing accuracy is {0.8975303493709225}
#
#
# for random state 93,the training accuracy is {0.989437045371461}
# for random state 93 ,the testing accuracy is {0.9728208285874974}
#
#
# for random state 94,the training accuracy is {0.9908903727565428}
# for random state 94 ,the testing accuracy is {0.9356516997698489}
#
#
# for random state 95,the training accuracy is {0.9906196463916825}
# for random state 95 ,the testing accuracy is {0.9744828302903215}
#
#
# for random state 96,the training accuracy is {0.9899669847113041}
# for random state 96 ,the testing accuracy is {0.9722471407395555}
#
#
# for random state 97,the training accuracy is {0.9902510514944872}
# for random state 97 ,the testing accuracy is {0.9587255787781617}
#
#
# for random state 98,the training accuracy is {0.9910946869375017}
# for random state 98 ,the testing accuracy is {0.973484426606369}
#
#
# for random state 99,the training accuracy is {0.9881460953506145}
# for random state 99 ,the testing accuracy is {0.9116537357053959}

# %%
from sklearn.neighbors import KNeighborsRegressor
knn= KNeighborsRegressor()

# %%
for i in range (0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.20)
    knn.fit(x_train,y_train)
    pred_train=knn.predict(x_train)
    pred_test=knn.predict(x_test)
    print(f'for random state {i},the training accuracy is',{r2_score(y_train,pred_train)})
    print(f'for random state {i} ,the testing accuracy is',{r2_score(y_test, pred_test)})
    print('\n')
# Out:
# for random state 0,the training accuracy is {0.9295769115268657}
# for random state 0 ,the testing accuracy is {0.8874401813517093}
#
#
# for random state 1,the training accuracy is {0.9330884595444744}
# for random state 1 ,the testing accuracy is {0.8246855094566019}
#
#
# for random state 2,the training accuracy is {0.9271901949897756}
# for random state 2 ,the testing accuracy is {0.9085870533356826}
#
#
# for random state 3,the training accuracy is {0.9318690262685216}
# for random state 3 ,the testing accuracy is {0.9150661030903611}
#
#
# for random state 4,the training accuracy is {0.924136230390181}
# for random state 4 ,the testing accuracy is {0.9163282866695356}
#
#
# for random state 5,the training accuracy is {0.9327076939115369}
# for random state 5 ,the testing accuracy is {0.8629569609402152}
#
#
# for random state 6,the training accuracy is {0.922804728577094}
# for random state 6 ,the testing accuracy is {0.9406738448746271}
#
#
# for random state 7,the training accuracy is {0.9218040556300927}
# for random state 7 ,the testing accuracy is {0.8705050302588125}
#
#
# for random state 8,the training accuracy is {0.9116860786617218}
# for random state 8 ,the testing accuracy is {0.9320922172815601}
#
#
# for random state 9,the training accuracy is {0.9171912961488146}
# for random state 9 ,the testing accuracy is {0.9149435149660722}
#
#
# for random state 10,the training accuracy is {0.9326228939540939}
# for random state 10 ,the testing accuracy is {0.8841161107885827}
#
#
# for random state 11,the training accuracy is {0.9282945311981751}
# for random state 11 ,the testing accuracy is {0.9332785485053904}
#
#
# for random state 12,the training accuracy is {0.9264380626048916}
# for random state 12 ,the testing accuracy is {0.9275106087638333}
#
#
# for random state 13,the training accuracy is {0.9271386552982729}
# for random state 13 ,the testing accuracy is {0.9039312147020522}
#
#
# for random state 14,the training accuracy is {0.9254559187185235}
# for random state 14 ,the testing accuracy is {0.9178975416249395}
#
#
# for random state 15,the training accuracy is {0.9271595858952071}
# for random state 15 ,the testing accuracy is {0.9420912057439319}
#
#
# for random state 16,the training accuracy is {0.9463144778192455}
# for random state 16 ,the testing accuracy is {0.7704767414182748}
#
#
# for random state 17,the training accuracy is {0.9262809463744428}
# for random state 17 ,the testing accuracy is {0.9028037613903582}
#
#
# for random state 18,the training accuracy is {0.9343505107486367}
# for random state 18 ,the testing accuracy is {0.8905385850374382}
#
#
# for random state 19,the training accuracy is {0.9221844291987655}
# for random state 19 ,the testing accuracy is {0.9364670476687444}
#
#
# for random state 20,the training accuracy is {0.9243939307690585}
# for random state 20 ,the testing accuracy is {0.8954787260145128}
#
#
# for random state 21,the training accuracy is {0.9293069850138979}
# for random state 21 ,the testing accuracy is {0.923238812395348}
#
#
# for random state 22,the training accuracy is {0.9267389962839735}
# for random state 22 ,the testing accuracy is {0.8780058799246033}
#
#
# for random state 23,the training accuracy is {0.9300029992714048}
# for random state 23 ,the testing accuracy is {0.9112132478270424}
#
#
# for random state 24,the training accuracy is {0.9243724361011519}
# for random state 24 ,the testing accuracy is {0.8971004165861156}
#
#
# for random state 25,the training accuracy is {0.9347707079407912}
# for random state 25 ,the testing accuracy is {0.9127549184106803}
#
#
# for random state 26,the training accuracy is {0.9292659695393415}
# for random state 26 ,the testing accuracy is {0.9046154317304311}
#
#
# for random state 27,the training accuracy is {0.9309764761421483}
# for random state 27 ,the testing accuracy is {0.8991506621369212}
#
#
# for random state 28,the training accuracy is {0.9265875427139223}
# for random state 28 ,the testing accuracy is {0.8920405532694474}
#
#
# for random state 29,the training accuracy is {0.9282300184583161}
# for random state 29 ,the testing accuracy is {0.8891309799283832}
#
#
# for random state 30,the training accuracy is {0.93039537319379}
# for random state 30 ,the testing accuracy is {0.8892543846321572}
#
#
# for random state 31,the training accuracy is {0.9329759498165993}
# for random state 31 ,the testing accuracy is {0.8547622063971404}
#
#
# for random state 32,the training accuracy is {0.9346134428511481}
# for random state 32 ,the testing accuracy is {0.91669551074667}
#
#
# for random state 33,the training accuracy is {0.9079336789121573}
# for random state 33 ,the testing accuracy is {0.9212014633616392}
#
#
# for random state 34,the training accuracy is {0.9367907414732274}
# for random state 34 ,the testing accuracy is {0.9293941510499365}
#
#
# for random state 35,the training accuracy is {0.9386351242368426}
# for random state 35 ,the testing accuracy is {0.8814242501994602}
#
#
# for random state 36,the training accuracy is {0.9338630010399477}
# for random state 36 ,the testing accuracy is {0.896568979777386}
#
#
# for random state 37,the training accuracy is {0.926804474152073}
# for random state 37 ,the testing accuracy is {0.9062717852518168}
#
#
# for random state 38,the training accuracy is {0.9204589299931011}
# for random state 38 ,the testing accuracy is {0.9418239699395707}
#
#
# for random state 39,the training accuracy is {0.9282764470200188}
# for random state 39 ,the testing accuracy is {0.9089843883234701}
#
#
# for random state 40,the training accuracy is {0.9301308387858782}
# for random state 40 ,the testing accuracy is {0.8496499914567335}
#
#
# for random state 41,the training accuracy is {0.9329973775978337}
# for random state 41 ,the testing accuracy is {0.9087050814912327}
#
#
# for random state 42,the training accuracy is {0.9185276050291868}
# for random state 42 ,the testing accuracy is {0.9307246029656677}
#
#
# for random state 43,the training accuracy is {0.9203389355330694}
# for random state 43 ,the testing accuracy is {0.9241082198707375}
#
#
# for random state 44,the training accuracy is {0.9342101406159803}
# for random state 44 ,the testing accuracy is {0.9040965006732227}
#
#
# for random state 45,the training accuracy is {0.9361985150475368}
# for random state 45 ,the testing accuracy is {0.88265065714063}
#
#
# for random state 46,the training accuracy is {0.9215069477832004}
# for random state 46 ,the testing accuracy is {0.8289487722379404}
#
#
# for random state 47,the training accuracy is {0.9267450834871721}
# for random state 47 ,the testing accuracy is {0.8777688487703803}
#
#
# for random state 48,the training accuracy is {0.9339271320304452}
# for random state 48 ,the testing accuracy is {0.9157968755203539}
#
#
# for random state 49,the training accuracy is {0.9397574599028985}
# for random state 49 ,the testing accuracy is {0.8892564089273396}
#
#
# for random state 50,the training accuracy is {0.942848448067371}
# for random state 50 ,the testing accuracy is {0.9258560959289459}
#
#
# for random state 51,the training accuracy is {0.9287984730030325}
# for random state 51 ,the testing accuracy is {0.8411433233392966}
#
#
# for random state 52,the training accuracy is {0.9298903965320927}
# for random state 52 ,the testing accuracy is {0.9146772582272646}
#
#
# for random state 53,the training accuracy is {0.9245854503987478}
# for random state 53 ,the testing accuracy is {0.9256576305245791}
#
#
# for random state 54,the training accuracy is {0.9223188949691538}
# for random state 54 ,the testing accuracy is {0.9084621060326235}
#
#
# for random state 55,the training accuracy is {0.9360271658931789}
# for random state 55 ,the testing accuracy is {0.8967541125138185}
#
#
# for random state 56,the training accuracy is {0.9261906552434652}
# for random state 56 ,the testing accuracy is {0.9131034614754325}
#
#
# for random state 57,the training accuracy is {0.9294619274174605}
# for random state 57 ,the testing accuracy is {0.9189100616434369}
#
#
# for random state 58,the training accuracy is {0.9421956363177307}
# for random state 58 ,the testing accuracy is {0.847310261050787}
#
#
# for random state 59,the training accuracy is {0.9305139447363664}
# for random state 59 ,the testing accuracy is {0.8678062443452235}
#
#
# for random state 60,the training accuracy is {0.9224746005663428}
# for random state 60 ,the testing accuracy is {0.9106124603083549}
#
#
# for random state 61,the training accuracy is {0.9282010920761353}
# for random state 61 ,the testing accuracy is {0.9032050782296187}
#
#
# for random state 62,the training accuracy is {0.935770046457512}
# for random state 62 ,the testing accuracy is {0.8667671295926633}
# for random state 63,the training accuracy is {0.9238963286111297}
# for random state 63 ,the testing accuracy is {0.8861631646996648}
#
#
# for random state 64,the training accuracy is {0.9306455125971225}
# for random state 64 ,the testing accuracy is {0.8628209018594579}
#
#
# for random state 65,the training accuracy is {0.9214013842615763}
# for random state 65 ,the testing accuracy is {0.8994142581232092}
#
#
# for random state 66,the training accuracy is {0.9354567281248167}
# for random state 66 ,the testing accuracy is {0.896082593228696}
#
#
# for random state 67,the training accuracy is {0.9305014070873848}
# for random state 67 ,the testing accuracy is {0.9174519195511146}
#
#
# for random state 68,the training accuracy is {0.9250903232927995}
# for random state 68 ,the testing accuracy is {0.9089424791250613}
#
#
# for random state 69,the training accuracy is {0.9252824129352456}
# for random state 69 ,the testing accuracy is {0.8945694797642836}
#
#
# for random state 70,the training accuracy is {0.9299427738566678}
# for random state 70 ,the testing accuracy is {0.8922296114567108}
#
#
# for random state 71,the training accuracy is {0.9353408646813397}
# for random state 71 ,the testing accuracy is {0.8848233101220466}
#
#
# for random state 72,the training accuracy is {0.9211549677664886}
# for random state 72 ,the testing accuracy is {0.905113111578514}
#
#
# for random state 73,the training accuracy is {0.9334952296263858}
# for random state 73 ,the testing accuracy is {0.893497333656983}
#
#
# for random state 74,the training accuracy is {0.9380964184584015}
# for random state 74 ,the testing accuracy is {0.9041897906690208}
#
#
# for random state 75,the training accuracy is {0.9312581976290859}
# for random state 75 ,the testing accuracy is {0.8721409419069301}
#
#
# for random state 76,the training accuracy is {0.9391724710708036}
# for random state 76 ,the testing accuracy is {0.864709372087113}
#
#
# for random state 77,the training accuracy is {0.9339645381603311}
# for random state 77 ,the testing accuracy is {0.8751251722972956}
#
#
# for random state 78,the training accuracy is {0.9364172882624762}
# for random state 78 ,the testing accuracy is {0.8339190333236222}
#
#
# for random state 79,the training accuracy is {0.9349773148935581}
# for random state 79 ,the testing accuracy is {0.8753111022282878}
#
#
# for random state 80,the training accuracy is {0.9264167096427085}
# for random state 80 ,the testing accuracy is {0.8537800101395903}
#
#
# for random state 81,the training accuracy is {0.941498712336118}
# for random state 81 ,the testing accuracy is {0.8754490791368198}
#
#
# for random state 82,the training accuracy is {0.9386037639638224}
# for random state 82 ,the testing accuracy is {0.8878117255085777}
#
#
# for random state 83,the training accuracy is {0.9279795458427825}
# for random state 83 ,the testing accuracy is {0.864421867306086}
#
#
# for random state 84,the training accuracy is {0.9206878830828044}
# for random state 84 ,the testing accuracy is {0.9438588716539322}
#
#
# for random state 85,the training accuracy is {0.923256065683654}
# for random state 85 ,the testing accuracy is {0.8944997978985447}
#
#
# for random state 86,the training accuracy is {0.9294296180808097}
# for random state 86 ,the testing accuracy is {0.9313494035068615}
#
#
# for random state 87,the training accuracy is {0.9345493175502991}
# for random state 87 ,the testing accuracy is {0.8742476690762229}
#
#
# for random state 88,the training accuracy is {0.9279789096407238}
# for random state 88 ,the testing accuracy is {0.9036570425000122}
#
#
# for random state 89,the training accuracy is {0.9246266690100339}
# for random state 89 ,the testing accuracy is {0.9321888782329125}
#
#
# for random state 90,the training accuracy is {0.9317073543679983}
# for random state 90 ,the testing accuracy is {0.8589145199663981}
#
#
# for random state 91,the training accuracy is {0.9286596153557023}
# for random state 91 ,the testing accuracy is {0.9215007950290678}
#
#
# for random state 92,the training accuracy is {0.9287184383073236}
# for random state 92 ,the testing accuracy is {0.8662144535228199}
#
#
# for random state 93,the training accuracy is {0.9305361141239705}
# for random state 93 ,the testing accuracy is {0.9057502696334293}
#
#
# for random state 94,the training accuracy is {0.9273965512849688}
# for random state 94 ,the testing accuracy is {0.8818993798635688}
#
#
# for random state 95,the training accuracy is {0.9262845587033018}
# for random state 95 ,the testing accuracy is {0.9289528106523985}
#
#
# for random state 96,the training accuracy is {0.9313123120502}
# for random state 96 ,the testing accuracy is {0.8657816373532154}
#
#
# for random state 97,the training accuracy is {0.942317353660843}
# for random state 97 ,the testing accuracy is {0.9093455057423083}
#
#
# for random state 98,the training accuracy is {0.9378109744961118}
# for random state 98 ,the testing accuracy is {0.8157139650207589}
#
#
# for random state 99,the training accuracy is {0.9281937799700617}
# for random state 99 ,the testing accuracy is {0.9426536026192752}

# %%
#cross validation

Train_accuracy=r2_score(y_train,pred_train)
testing_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(knn,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is {cv_mean} and the train accuracy score is {Train_accuracy} and test accuracy score is {testing_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is -4.719812842873615 and the train accuracy score is 0.9281937799700617 and test accuracy score is 0.9426536026192752
#
#
# at cross fold 3 the cv score is -3.1930643012811246 and the train accuracy score is 0.9281937799700617 and test accuracy score is 0.9426536026192752
#
#
# at cross fold 4 the cv score is -5.592051440422882 and the train accuracy score is 0.9281937799700617 and test accuracy score is 0.9426536026192752
#
#
# at cross fold 5 the cv score is -5.464841816171268 and the train accuracy score is 0.9281937799700617 and test accuracy score is 0.9426536026192752
#
#
# at cross fold 6 the cv score is -7.221225060035013 and the train accuracy score is 0.9281937799700617 and test accuracy score is 0.9426536026192752
#
#
# at cross fold 7 the cv score is -8.940595081805943 and the train accuracy score is 0.9281937799700617 and test accuracy score is 0.9426536026192752
#
#
# at cross fold 8 the cv score is -10.209714111908252 and the train accuracy score is 0.9281937799700617 and test accuracy score is 0.9426536026192752
#
#
# at cross fold 9 the cv score is -10.531669235013652 and the train accuracy score is 0.9281937799700617 and test accuracy score is 0.9426536026192752

# %%
#grid search cv

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso

parameters={'alpha':[.0001, .001, .01, .1, 1, 10 ],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
#model training


ls=Lasso(alpha=.001,random_state=0)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
ls_score_training*100
# Out:
# 99.55209290650548

# %%
lss=r2_score(y_test,pred_ls)
lss*100
# Out:
# 99.44539457814525

# %%
cv_score=cross_val_score(lr,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# 85.3085361148216

# %%
#ENsemble technique

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['mse','mae' ],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion='mse',max_features='auto')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_dec=rf.predict(x_test)

rfs=r2_score(y_test,pred_dec)
print('r2_score:',rfs*100)

rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print('cross val score',rfc*100)
# Out:
# r2_score: 95.60542411406303
# cross val score -363.6676102735496

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbreg = GradientBoostingRegressor(random_state=0)

clf = GradientBoostingRegressor(n_estimators=200,max_depth=5, random_state=0).fit(x_train, y_train)
gbreg.fit(x_train, y_train)

rf.score(x_train,y_train)
pred_dec=rf.predict(x_test)

rfs=r2_score(y_test,pred_dec)
print('r2_score:',rfs*100)

rfscore=cross_val_score(gbreg,x,y,cv=5)
rfc=rfscore.mean()
print('cross val score',rfc*100)
# Out:
# r2_score: 95.60542411406303
# cross val score -264.55209827224

# %%
import pickle
filename='worldhappiness.pkl'
pickle.dump(rf,open(filename,'wb'))

# %%
loadmodel=pickle.load(open('worldhappiness.pkl','rb'))
result=loadmodel.score(x_test,y_test)
print(result*100)
# Out:
# 95.60542411406303

# %%
conclusion=pd.DataFrame([loadmodel.predict(x_test)[:],pred_dec[:]],index=['predicted','original'])
conclusion
# Out:
#                 0        1        2       3        4        5        6   \
# predicted  5.89429  4.90091  3.83436  5.0067  6.87587  4.48959  7.27554
# original   5.89429  4.90091  3.83436  5.0067  6.87587  4.48959  7.27554
#
#                7        8        9   ...       21       22       23       24  \
# predicted  6.7979  4.81108  5.72272  ...  3.93371  5.26909  4.37911  5.04185
# original   6.7979  4.81108  5.72272  ...  3.93371  5.26909  4.37911  5.04185
#
#                 25       26       27       28       29       30
# predicted  5.19435  4.47544  7.05819  4.67396  4.84347  4.81264
# original   5.19435  4.47544  7.05819  4.67396  4.84347  4.81264
#
# [2 rows x 31 columns]
