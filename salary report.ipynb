# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('salary report.csv')

# %%
df
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %%
df.head()
# Out:
#        rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0      Prof          B             19           18  Male  139750
# 1      Prof          B             20           16  Male  173200
# 2  AsstProf          B              4            3  Male   79750
# 3      Prof          B             45           39  Male  115000
# 4      Prof          B             40           41  Male  141500

# %%
df['sex']
# Out:
# 0      Male
# 1      Male
# 2      Male
# 3      Male
# 4      Male
#        ...
# 392    Male
# 393    Male
# 394    Male
# 395    Male
# 396    Male
# Name: sex, Length: 397, dtype: object

# %%
df['sex'].values
# Out:
# array(['Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male',
#        'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female',
#        'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female',
#        'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Female',
#        'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Female',
#        'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male',
#        'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female',
#        'Male', 'Female', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Female', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Female', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female', 'Male',
#        'Male', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male',
#        'Male', 'Male', 'Male', 'Male', 'Male'], dtype=object)

# %%
df.value_counts()
# Out:
# rank      discipline  yrs.since.phd  yrs.service  sex     salary
# AsstProf  B           4              4            Male    92000     3
#                       3              3            Male    89942     2
#                       4              4            Male    92700     2
# Prof      B           12             8            Male    118223    1
#                       15             10           Male    107986    1
#                                                                    ..
#           A           13             7            Male    103700    1
#                       12             7            Male    109707    1
#                                      6            Male    93000     1
#                                      0            Female  105000    1
#           B           56             49           Male    186960    1
# Length: 393, dtype: int64

# %%
df.dtypes
# Out:
# rank             object
# discipline       object
# yrs.since.phd     int64
# yrs.service       int64
# sex              object
# salary            int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# rank             0
# discipline       0
# yrs.since.phd    0
# yrs.service      0
# sex              0
# salary           0
# dtype: int64

# %%
#label encoder to convert categorical data into nominal data
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df['rank']=LE.fit_transform(df['rank'])
df['discipline']=LE.fit_transform(df['discipline'])
df['sex']=LE.fit_transform(df['sex'])

# %%
df['rank'].value_counts()
# Out:
# 2    266
# 1     67
# 0     64
# Name: rank, dtype: int64

# %%
df['discipline'].value_counts()
# Out:
# 1    216
# 0    181
# Name: discipline, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# 1    358
# 0     39
# Name: sex, dtype: int64

# %%
#there is no null data so we can proceed further

# %%
df.describe()
# Out:
#              rank  discipline  yrs.since.phd  yrs.service         sex  \
# count  397.000000  397.000000     397.000000   397.000000  397.000000
# mean     1.508816    0.544081      22.314861    17.614610    0.901763
# std      0.757486    0.498682      12.887003    13.006024    0.298010
# min      0.000000    0.000000       1.000000     0.000000    0.000000
# 25%      1.000000    0.000000      12.000000     7.000000    1.000000
# 50%      2.000000    1.000000      21.000000    16.000000    1.000000
# 75%      2.000000    1.000000      32.000000    27.000000    1.000000
# max      2.000000    1.000000      56.000000    60.000000    1.000000
#
#               salary
# count     397.000000
# mean   113706.458438
# std     30289.038695
# min     57800.000000
# 25%     91000.000000
# 50%    107300.000000
# 75%    134185.000000
# max    231545.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.dtypes
# Out:
# rank             int32
# discipline       int32
# yrs.since.phd    int64
# yrs.service      int64
# sex              int32
# salary           int64
# dtype: object

# %%
df.corr()
# Out:
#                    rank  discipline  yrs.since.phd  yrs.service       sex  \
# rank           1.000000   -0.086266       0.525500     0.447499  0.132492
# discipline    -0.086266    1.000000      -0.218087    -0.164599  0.003724
# yrs.since.phd  0.525500   -0.218087       1.000000     0.909649  0.148788
# yrs.service    0.447499   -0.164599       0.909649     1.000000  0.153740
# sex            0.132492    0.003724       0.148788     0.153740  1.000000
# salary         0.522207    0.156084       0.419231     0.334745  0.138610
#
#                  salary
# rank           0.522207
# discipline     0.156084
# yrs.since.phd  0.419231
# yrs.service    0.334745
# sex            0.138610
# salary         1.000000

# %%
corr_sr=df.corr()

# %%
plt.figure(figsize=[8,7])
sns.heatmap(corr_sr,annot=True)
plt.title('correlation matrix')
plt.show()

# %%
df.corr()['salary']
# Out:
# rank             0.522207
# discipline       0.156084
# yrs.since.phd    0.419231
# yrs.service      0.334745
# sex              0.138610
# salary           1.000000
# Name: salary, dtype: float64

# %%
df=df.drop(['sex'],axis=1)   #because sex contributes  less to the target variable salary

# %%
sns.scatterplot(x='rank',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='rank', ylabel='salary'>

# %%
sns.scatterplot(x='discipline',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='discipline', ylabel='salary'>

# %%
sns.scatterplot(x='yrs.since.phd',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='yrs.since.phd', ylabel='salary'>

# %%
sns.scatterplot(x='yrs.service',y='salary',data=df)
# Out:
# <AxesSubplot:xlabel='yrs.service', ylabel='salary'>

# %%
df.skew()
# Out:
# rank            -1.151164
# discipline      -0.177684
# yrs.since.phd    0.300880
# yrs.service      0.650569
# salary           0.714568
# dtype: float64

# %%
df.plot(kind='density',subplots=True,layout=(3,2),figsize=(10,15))  #we see skewness present in some columns
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>]],
#       dtype=object)

# %%
df.boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
df.plot(kind='box',subplots=True,layout=(2,3),figsize=(10,15))
# Out:
# yrs.since.phd       AxesSubplot(0.125,0.53;0.227941x0.35)
# yrs.service      AxesSubplot(0.398529,0.53;0.227941x0.35)
# salary           AxesSubplot(0.672059,0.53;0.227941x0.35)
# dtype: object

# %%
#to remove outliers perform zscore

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (397, 5)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 43, 131, 330, 364], dtype=int64), array([4, 3, 3, 4], dtype=int64))

# %%
df.drop([43, 131, 330, 364],axis=0)
# Out:
#      rank  discipline  yrs.since.phd  yrs.service  salary
# 0       2           1             19           18  139750
# 1       2           1             20           16  173200
# 2       1           1              4            3   79750
# 3       2           1             45           39  115000
# 4       2           1             40           41  141500
# ..    ...         ...            ...          ...     ...
# 392     2           0             33           30  103106
# 393     2           0             31           19  150564
# 394     2           0             42           25  101738
# 395     2           0             25           15   95329
# 396     1           0              8            4   81035
#
# [393 rows x 5 columns]

# %%
print(np.where(z<3))
# Out:
# (array([  0,   0,   0, ..., 396, 396, 396], dtype=int64), array([0, 1, 2, ..., 2, 3, 4], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print('Old Dataframe',df.shape)
print('New dataframe',df_new.shape)
# Out:
# Old Dataframe (397, 5)
# New dataframe (393, 5)

# %%
data_loss=((397-393)/397)*100
print('data loss=',data_loss,'%')
# Out:
# data loss= 1.0075566750629723 %

# %%
df_new
# Out:
#      rank  discipline  yrs.since.phd  yrs.service  salary
# 0       2           1             19           18  139750
# 1       2           1             20           16  173200
# 2       1           1              4            3   79750
# 3       2           1             45           39  115000
# 4       2           1             40           41  141500
# ..    ...         ...            ...          ...     ...
# 392     2           0             33           30  103106
# 393     2           0             31           19  150564
# 394     2           0             42           25  101738
# 395     2           0             25           15   95329
# 396     1           0              8            4   81035
#
# [393 rows x 5 columns]

# %%
#splitting the data into feature= x and target=y

# %%
x=df_new.drop('salary',axis=1)
y=df_new['salary']

# %%
x
# Out:
#      rank  discipline  yrs.since.phd  yrs.service
# 0       2           1             19           18
# 1       2           1             20           16
# 2       1           1              4            3
# 3       2           1             45           39
# 4       2           1             40           41
# ..    ...         ...            ...          ...
# 392     2           0             33           30
# 393     2           0             31           19
# 394     2           0             42           25
# 395     2           0             25           15
# 396     1           0              8            4
#
# [393 rows x 4 columns]

# %%
y
# Out:
# 0      139750
# 1      173200
# 2       79750
# 3      115000
# 4      141500
#         ...
# 392    103106
# 393    150564
# 394    101738
# 395     95329
# 396     81035
# Name: salary, Length: 393, dtype: int64

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)
x=pd.DataFrame(x_new,columns=x.columns)

# %%
#standard scaler to fit the values
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.69481738,  0.91457564, -0.11344983,  0.26888583],
#        [ 0.69481738,  0.91457564, -0.03455335,  0.1209006 ],
#        [-1.0753989 ,  0.91457564, -1.6242611 , -1.28449532],
#        ...,
#        [ 0.69481738, -1.09340328,  1.42772852,  0.72581897],
#        [ 0.69481738, -1.09340328,  0.33874878,  0.04312953],
#        [-1.0753989 , -1.09340328, -1.12908354, -1.11979784]])

# %%
#linear regression
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
for i in range (0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f'for random state {i},the training accuracy is',{r2_score(y_train,pred_train)})
    print(f'for random state {i} ,the testing accuracy is',{r2_score(y_test, pred_test)})
    print('\n')
# Out:
# for random state 0,the training accuracy is {0.42919944394742193}
# for random state 0 ,the testing accuracy is {0.40317042242867496}
#
#
# for random state 1,the training accuracy is {0.3869446937428265}
# for random state 1 ,the testing accuracy is {0.548381880957381}
#
#
# for random state 2,the training accuracy is {0.42522674021595974}
# for random state 2 ,the testing accuracy is {0.4017703740741667}
#
#
# for random state 3,the training accuracy is {0.436644845496034}
# for random state 3 ,the testing accuracy is {0.35343789445508955}
#
#
# for random state 4,the training accuracy is {0.4430944965263882}
# for random state 4 ,the testing accuracy is {0.3163178849061561}
#
#
# for random state 5,the training accuracy is {0.4025324909057393}
# for random state 5 ,the testing accuracy is {0.4942119600698577}
#
#
# for random state 6,the training accuracy is {0.4610336431001645}
# for random state 6 ,the testing accuracy is {0.2536655604556801}
#
#
# for random state 7,the training accuracy is {0.4155555403111174}
# for random state 7 ,the testing accuracy is {0.4302879176063267}
#
#
# for random state 8,the training accuracy is {0.41265968406754827}
# for random state 8 ,the testing accuracy is {0.4549938643132341}
#
#
# for random state 9,the training accuracy is {0.4257186913068399}
# for random state 9 ,the testing accuracy is {0.40472793802407125}
#
#
# for random state 10,the training accuracy is {0.4223750249404785}
# for random state 10 ,the testing accuracy is {0.42275866271228324}
#
#
# for random state 11,the training accuracy is {0.40520486081398255}
# for random state 11 ,the testing accuracy is {0.49330392904518194}
#
#
# for random state 12,the training accuracy is {0.4256443590751984}
# for random state 12 ,the testing accuracy is {0.4028725983976431}
#
#
# for random state 13,the training accuracy is {0.41242824155756874}
# for random state 13 ,the testing accuracy is {0.43997749723757873}
#
#
# for random state 14,the training accuracy is {0.45648102883328123}
# for random state 14 ,the testing accuracy is {0.286904594541171}
#
#
# for random state 15,the training accuracy is {0.38977406486756405}
# for random state 15 ,the testing accuracy is {0.5292420640015614}
#
#
# for random state 16,the training accuracy is {0.4669019742488344}
# for random state 16 ,the testing accuracy is {0.23857911113397046}
#
#
# for random state 17,the training accuracy is {0.4183665596737557}
# for random state 17 ,the testing accuracy is {0.4327760748012164}
#
#
# for random state 18,the training accuracy is {0.4369793349561427}
# for random state 18 ,the testing accuracy is {0.36451557993177264}
#
#
# for random state 19,the training accuracy is {0.3940807767598792}
# for random state 19 ,the testing accuracy is {0.495554153721415}
#
#
# for random state 20,the training accuracy is {0.3952034750017833}
# for random state 20 ,the testing accuracy is {0.5263537729191327}
#
#
# for random state 21,the training accuracy is {0.4398414357537841}
# for random state 21 ,the testing accuracy is {0.3346767251971393}
#
#
# for random state 22,the training accuracy is {0.43278400701460307}
# for random state 22 ,the testing accuracy is {0.3779335672505323}
#
#
# for random state 23,the training accuracy is {0.4549977798878484}
# for random state 23 ,the testing accuracy is {0.27683064729560836}
#
#
# for random state 24,the training accuracy is {0.4086714289374773}
# for random state 24 ,the testing accuracy is {0.475702157664158}
#
#
# for random state 25,the training accuracy is {0.4620909707619716}
# for random state 25 ,the testing accuracy is {0.17236293606958142}
#
#
# for random state 26,the training accuracy is {0.4248633371384014}
# for random state 26 ,the testing accuracy is {0.4048869388170887}
#
#
# for random state 27,the training accuracy is {0.4264169072057229}
# for random state 27 ,the testing accuracy is {0.3811857354603677}
#
#
# for random state 28,the training accuracy is {0.42994179616503037}
# for random state 28 ,the testing accuracy is {0.374729044819309}
#
#
# for random state 29,the training accuracy is {0.40864264216950885}
# for random state 29 ,the testing accuracy is {0.46571476994029515}
#
#
# for random state 30,the training accuracy is {0.4223927541859762}
# for random state 30 ,the testing accuracy is {0.4217374301236325}
#
#
# for random state 31,the training accuracy is {0.42005830034267877}
# for random state 31 ,the testing accuracy is {0.4175768192371484}
#
#
# for random state 32,the training accuracy is {0.4344583274973095}
# for random state 32 ,the testing accuracy is {0.37448142859385125}
#
#
# for random state 33,the training accuracy is {0.45700802195195933}
# for random state 33 ,the testing accuracy is {0.2714646797487028}
#
#
# for random state 34,the training accuracy is {0.43836808418437245}
# for random state 34 ,the testing accuracy is {0.36227551526414736}
#
#
# for random state 35,the training accuracy is {0.4015286616486129}
# for random state 35 ,the testing accuracy is {0.49508616881805123}
#
#
# for random state 36,the training accuracy is {0.4484554272805531}
# for random state 36 ,the testing accuracy is {0.3168439383590682}
#
#
# for random state 37,the training accuracy is {0.4293880959886722}
# for random state 37 ,the testing accuracy is {0.38757559017590404}
#
#
# for random state 38,the training accuracy is {0.4384041647570064}
# for random state 38 ,the testing accuracy is {0.3489352689392786}
#
#
# for random state 39,the training accuracy is {0.426851185712368}
# for random state 39 ,the testing accuracy is {0.40056895952541527}
#
#
# for random state 40,the training accuracy is {0.4461579199362796}
# for random state 40 ,the testing accuracy is {0.3183605532696846}
#
#
# for random state 41,the training accuracy is {0.4179306482478916}
# for random state 41 ,the testing accuracy is {0.4201263510596588}
#
#
# for random state 42,the training accuracy is {0.4524477843277175}
# for random state 42 ,the testing accuracy is {0.2925776460832009}
#
#
# for random state 43,the training accuracy is {0.4334884684168263}
# for random state 43 ,the testing accuracy is {0.3717427714155832}
#
#
# for random state 44,the training accuracy is {0.4274062061683094}
# for random state 44 ,the testing accuracy is {0.3976653356289338}
#
#
# for random state 45,the training accuracy is {0.43555280669859453}
# for random state 45 ,the testing accuracy is {0.3605938007110925}
#
#
# for random state 46,the training accuracy is {0.44895557380513074}
# for random state 46 ,the testing accuracy is {0.28978853890207024}
#
#
# for random state 47,the training accuracy is {0.42744315476032235}
# for random state 47 ,the testing accuracy is {0.3612147506143917}
#
#
# for random state 48,the training accuracy is {0.42141978467859065}
# for random state 48 ,the testing accuracy is {0.41651360750164446}
#
#
# for random state 49,the training accuracy is {0.42668631824557024}
# for random state 49 ,the testing accuracy is {0.3868756488465608}
#
#
# for random state 50,the training accuracy is {0.4291898423563152}
# for random state 50 ,the testing accuracy is {0.3771362365651203}
#
#
# for random state 51,the training accuracy is {0.4165134420746083}
# for random state 51 ,the testing accuracy is {0.44470163425437836}
#
#
# for random state 52,the training accuracy is {0.3966751755709903}
# for random state 52 ,the testing accuracy is {0.5092353216354393}
#
#
# for random state 53,the training accuracy is {0.42379219209768093}
# for random state 53 ,the testing accuracy is {0.4149403133663472}
#
#
# for random state 54,the training accuracy is {0.40796333648481187}
# for random state 54 ,the testing accuracy is {0.45837889713675883}
#
#
# for random state 55,the training accuracy is {0.4117244488418218}
# for random state 55 ,the testing accuracy is {0.46379590867723497}
#
#
# for random state 56,the training accuracy is {0.43426776168351333}
# for random state 56 ,the testing accuracy is {0.3694329164630208}
#
#
# for random state 57,the training accuracy is {0.4271451928643434}
# for random state 57 ,the testing accuracy is {0.39667151410720103}
#
#
# for random state 58,the training accuracy is {0.4872920273903699}
# for random state 58 ,the testing accuracy is {0.1891992984246288}
#
#
# for random state 59,the training accuracy is {0.4412058583229119}
# for random state 59 ,the testing accuracy is {0.3556835895583452}
#
#
# for random state 60,the training accuracy is {0.45372737223517157}
# for random state 60 ,the testing accuracy is {0.2683870933399426}
#
#
# for random state 61,the training accuracy is {0.4086872787457181}
# for random state 61 ,the testing accuracy is {0.48007572023451894}
#
#
# for random state 62,the training accuracy is {0.4249728244091966}
# for random state 62 ,the testing accuracy is {0.41296781296816065}
#
#
# for random state 63,the training accuracy is {0.4258062773680654}
# for random state 63 ,the testing accuracy is {0.39255514112017853}
#
#
# for random state 64,the training accuracy is {0.40732804384842203}
# for random state 64 ,the testing accuracy is {0.49750177214076263}
#
#
# for random state 65,the training accuracy is {0.405366001408096}
# for random state 65 ,the testing accuracy is {0.4936441806606229}
#
#
# for random state 66,the training accuracy is {0.4001890919289466}
# for random state 66 ,the testing accuracy is {0.5077913644245455}
#
#
# for random state 67,the training accuracy is {0.44065854292016027}
# for random state 67 ,the testing accuracy is {0.3328076333239819}
#
#
# for random state 68,the training accuracy is {0.4596727612253596}
# for random state 68 ,the testing accuracy is {0.28674914072258206}
#
#
# for random state 69,the training accuracy is {0.428616476989216}
# for random state 69 ,the testing accuracy is {0.4002728107872334}
#
#
# for random state 70,the training accuracy is {0.4474986471403055}
# for random state 70 ,the testing accuracy is {0.32217354260270337}
#
#
# for random state 71,the training accuracy is {0.4449458638518998}
# for random state 71 ,the testing accuracy is {0.34306291345086426}
#
#
# for random state 72,the training accuracy is {0.4530662352262802}
# for random state 72 ,the testing accuracy is {0.29895185451446193}
#
#
# for random state 73,the training accuracy is {0.4031808249246459}
# for random state 73 ,the testing accuracy is {0.47648203379593657}
#
#
# for random state 74,the training accuracy is {0.41994280662202765}
# for random state 74 ,the testing accuracy is {0.4245297678566753}
#
#
# for random state 75,the training accuracy is {0.425854547323393}
# for random state 75 ,the testing accuracy is {0.4032974009363489}
#
#
# for random state 76,the training accuracy is {0.42757135762634557}
# for random state 76 ,the testing accuracy is {0.4011102101587577}
#
#
# for random state 77,the training accuracy is {0.4343540292201644}
# for random state 77 ,the testing accuracy is {0.3696675435945549}
#
#
# for random state 78,the training accuracy is {0.44864911820957043}
# for random state 78 ,the testing accuracy is {0.31298699220760173}
#
#
# for random state 79,the training accuracy is {0.41227563258880673}
# for random state 79 ,the testing accuracy is {0.464314387559449}
# for random state 80,the training accuracy is {0.4256374644625671}
# for random state 80 ,the testing accuracy is {0.40652544395934787}
#
#
# for random state 81,the training accuracy is {0.41044412957633725}
# for random state 81 ,the testing accuracy is {0.44874126393521596}
#
#
# for random state 82,the training accuracy is {0.45180534286010743}
# for random state 82 ,the testing accuracy is {0.2850116544199408}
#
#
# for random state 83,the training accuracy is {0.4361862521799258}
# for random state 83 ,the testing accuracy is {0.3788787580777562}
#
#
# for random state 84,the training accuracy is {0.40448127924909283}
# for random state 84 ,the testing accuracy is {0.49625644046465167}
#
#
# for random state 85,the training accuracy is {0.4167811575405491}
# for random state 85 ,the testing accuracy is {0.4418528623671393}
#
#
# for random state 86,the training accuracy is {0.44346728934614554}
# for random state 86 ,the testing accuracy is {0.34346686280194094}
#
#
# for random state 87,the training accuracy is {0.4404087671926529}
# for random state 87 ,the testing accuracy is {0.3333296734534815}
#
#
# for random state 88,the training accuracy is {0.42204555153487444}
# for random state 88 ,the testing accuracy is {0.41310498039595045}
#
#
# for random state 89,the training accuracy is {0.4261219528730883}
# for random state 89 ,the testing accuracy is {0.40227948078486453}
#
#
# for random state 90,the training accuracy is {0.4130783377138897}
# for random state 90 ,the testing accuracy is {0.4554035393984174}
#
#
# for random state 91,the training accuracy is {0.4119415258133263}
# for random state 91 ,the testing accuracy is {0.465925664510361}
#
#
# for random state 92,the training accuracy is {0.38921359400534317}
# for random state 92 ,the testing accuracy is {0.5134140149236849}
#
#
# for random state 93,the training accuracy is {0.4323361037526494}
# for random state 93 ,the testing accuracy is {0.3826720794656051}
#
#
# for random state 94,the training accuracy is {0.4438808357263343}
# for random state 94 ,the testing accuracy is {0.3061235687154009}
#
#
# for random state 95,the training accuracy is {0.42664703752583366}
# for random state 95 ,the testing accuracy is {0.4056514899976401}
#
#
# for random state 96,the training accuracy is {0.4330811058046127}
# for random state 96 ,the testing accuracy is {0.37236752448661226}
#
#
# for random state 97,the training accuracy is {0.43217886747693735}
# for random state 97 ,the testing accuracy is {0.376907132436351}
#
#
# for random state 98,the training accuracy is {0.41375283975906374}
# for random state 98 ,the testing accuracy is {0.45448707292491575}
#
#
# for random state 99,the training accuracy is {0.41318050289537644}
# for random state 99 ,the testing accuracy is {0.4470748061681492}

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=62,test_size=.20)
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.41296781296816065

# %%
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred_test))
print('Mean squared error :',mean_squared_error(y_test,pred_test))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_test)))
# Out:
# error:
# Mean absolute error: 16542.147921367618
# Mean squared error : 422208577.73548514
# Root Mean Squared Error: 20547.714659676516

# %%
#we see accuracy is less so perform with other regression techniques

# %%
from sklearn.tree import DecisionTreeRegressor
dtc=DecisionTreeRegressor()

# %%
for i in range (0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.20)
    dtc.fit(x_train,y_train)
    pred_train=dtc.predict(x_train)
    pred_test=dtc.predict(x_test)
    print(f'for random state {i},the training accuracy is',{r2_score(y_train,pred_train)})
    print(f'for random state {i} ,the testing accuracy is',{r2_score(y_test, pred_test)})
    print('\n')
# Out:
# for random state 0,the training accuracy is {0.9465588750942855}
# for random state 0 ,the testing accuracy is {0.08777970119664835}
#
#
# for random state 1,the training accuracy is {0.9541975323477848}
# for random state 1 ,the testing accuracy is {0.08633786531297705}
#
#
# for random state 2,the training accuracy is {0.9423023528170305}
# for random state 2 ,the testing accuracy is {-0.061277481492918895}
#
#
# for random state 3,the training accuracy is {0.9473416365329431}
# for random state 3 ,the testing accuracy is {0.23955174238536014}
#
#
# for random state 4,the training accuracy is {0.9613380693306876}
# for random state 4 ,the testing accuracy is {-0.27458462537905426}
#
#
# for random state 5,the training accuracy is {0.9356359729446851}
# for random state 5 ,the testing accuracy is {-0.06266724016283831}
#
#
# for random state 6,the training accuracy is {0.9491172895173017}
# for random state 6 ,the testing accuracy is {0.022264187938104918}
#
#
# for random state 7,the training accuracy is {0.9330980812937908}
# for random state 7 ,the testing accuracy is {-0.027667642470238896}
#
#
# for random state 8,the training accuracy is {0.9429813399660432}
# for random state 8 ,the testing accuracy is {0.1420228641766298}
#
#
# for random state 9,the training accuracy is {0.921836258897712}
# for random state 9 ,the testing accuracy is {0.2314692018872132}
#
#
# for random state 10,the training accuracy is {0.9403685614925479}
# for random state 10 ,the testing accuracy is {0.046131924034990335}
#
#
# for random state 11,the training accuracy is {0.9454074729034604}
# for random state 11 ,the testing accuracy is {-0.062289727840520115}
#
#
# for random state 12,the training accuracy is {0.9540653513772888}
# for random state 12 ,the testing accuracy is {0.35296068219267185}
#
#
# for random state 13,the training accuracy is {0.9367343294144667}
# for random state 13 ,the testing accuracy is {0.22788487372513366}
#
#
# for random state 14,the training accuracy is {0.9432813956233667}
# for random state 14 ,the testing accuracy is {-0.36715772040323413}
#
#
# for random state 15,the training accuracy is {0.9536333458918657}
# for random state 15 ,the testing accuracy is {0.3190801906038834}
#
#
# for random state 16,the training accuracy is {0.9412216841018897}
# for random state 16 ,the testing accuracy is {0.01771762051663406}
#
#
# for random state 17,the training accuracy is {0.9412655117638883}
# for random state 17 ,the testing accuracy is {0.11748373120236755}
#
#
# for random state 18,the training accuracy is {0.9505193619128075}
# for random state 18 ,the testing accuracy is {0.011816296692408468}
#
#
# for random state 19,the training accuracy is {0.9291780735375339}
# for random state 19 ,the testing accuracy is {0.007120782820681071}
#
#
# for random state 20,the training accuracy is {0.9483004992893714}
# for random state 20 ,the testing accuracy is {-0.14175210773909286}
#
#
# for random state 21,the training accuracy is {0.9573884905621223}
# for random state 21 ,the testing accuracy is {-0.14565662596326567}
#
#
# for random state 22,the training accuracy is {0.9334934959098559}
# for random state 22 ,the testing accuracy is {0.17038387693470425}
#
#
# for random state 23,the training accuracy is {0.9342249365072747}
# for random state 23 ,the testing accuracy is {-0.007792055172981982}
#
#
# for random state 24,the training accuracy is {0.9405989181603452}
# for random state 24 ,the testing accuracy is {0.10870722717472603}
#
#
# for random state 25,the training accuracy is {0.9334870909955613}
# for random state 25 ,the testing accuracy is {0.16186485576260135}
#
#
# for random state 26,the training accuracy is {0.9430320151955256}
# for random state 26 ,the testing accuracy is {-0.09432913307389379}
#
#
# for random state 27,the training accuracy is {0.9386554798160096}
# for random state 27 ,the testing accuracy is {0.03885195180796619}
#
#
# for random state 28,the training accuracy is {0.9390481951200953}
# for random state 28 ,the testing accuracy is {-0.43556387674665054}
#
#
# for random state 29,the training accuracy is {0.9413916731369315}
# for random state 29 ,the testing accuracy is {0.34492036426232875}
#
#
# for random state 30,the training accuracy is {0.9523215615082895}
# for random state 30 ,the testing accuracy is {0.3500926603353538}
#
#
# for random state 31,the training accuracy is {0.9366450360983845}
# for random state 31 ,the testing accuracy is {0.15063283525066584}
#
#
# for random state 32,the training accuracy is {0.9535538730202908}
# for random state 32 ,the testing accuracy is {0.14666122148751048}
#
#
# for random state 33,the training accuracy is {0.9444487129906542}
# for random state 33 ,the testing accuracy is {-0.14957324898218127}
#
#
# for random state 34,the training accuracy is {0.941239209227619}
# for random state 34 ,the testing accuracy is {-0.13107834201853974}
#
#
# for random state 35,the training accuracy is {0.9438007415274979}
# for random state 35 ,the testing accuracy is {0.21906580325502734}
#
#
# for random state 36,the training accuracy is {0.9683367605332727}
# for random state 36 ,the testing accuracy is {-0.10791026433103212}
#
#
# for random state 37,the training accuracy is {0.951558672660591}
# for random state 37 ,the testing accuracy is {0.02242037318142409}
#
#
# for random state 38,the training accuracy is {0.9450645849463147}
# for random state 38 ,the testing accuracy is {0.1899644358730066}
#
#
# for random state 39,the training accuracy is {0.9598873958278626}
# for random state 39 ,the testing accuracy is {-0.3299594849276213}
#
#
# for random state 40,the training accuracy is {0.9440518405880381}
# for random state 40 ,the testing accuracy is {-0.060449616552718854}
#
#
# for random state 41,the training accuracy is {0.928633188199838}
# for random state 41 ,the testing accuracy is {-0.012040648241133267}
#
#
# for random state 42,the training accuracy is {0.9303047653734662}
# for random state 42 ,the testing accuracy is {-0.007505145829375337}
#
#
# for random state 43,the training accuracy is {0.9450387883855851}
# for random state 43 ,the testing accuracy is {-0.060480491729952846}
#
#
# for random state 44,the training accuracy is {0.9640374228686411}
# for random state 44 ,the testing accuracy is {-0.3957881704427162}
#
#
# for random state 45,the training accuracy is {0.9415892835246981}
# for random state 45 ,the testing accuracy is {0.025700861387973006}
#
#
# for random state 46,the training accuracy is {0.9465758234106326}
# for random state 46 ,the testing accuracy is {-0.23367749230559154}
#
#
# for random state 47,the training accuracy is {0.9388120391941588}
# for random state 47 ,the testing accuracy is {-0.17529255647472852}
#
#
# for random state 48,the training accuracy is {0.9465187382098934}
# for random state 48 ,the testing accuracy is {-0.12236421819172572}
#
#
# for random state 49,the training accuracy is {0.9279247081057694}
# for random state 49 ,the testing accuracy is {-0.1358259746458672}
#
#
# for random state 50,the training accuracy is {0.9442059051652871}
# for random state 50 ,the testing accuracy is {-0.42574278127847}
#
#
# for random state 51,the training accuracy is {0.9352184567374816}
# for random state 51 ,the testing accuracy is {0.1963713054313756}
#
#
# for random state 52,the training accuracy is {0.9555039713508452}
# for random state 52 ,the testing accuracy is {0.03050095186387536}
#
#
# for random state 53,the training accuracy is {0.9568982131306532}
# for random state 53 ,the testing accuracy is {0.004691548126147915}
#
#
# for random state 54,the training accuracy is {0.9503514286237603}
# for random state 54 ,the testing accuracy is {-0.06816684450384969}
#
#
# for random state 55,the training accuracy is {0.9484612815155259}
# for random state 55 ,the testing accuracy is {-0.1006370424177856}
#
#
# for random state 56,the training accuracy is {0.9512985000852513}
# for random state 56 ,the testing accuracy is {-0.17101759662949712}
#
#
# for random state 57,the training accuracy is {0.9419530012151055}
# for random state 57 ,the testing accuracy is {0.0314789364701471}
#
#
# for random state 58,the training accuracy is {0.954273275703615}
# for random state 58 ,the testing accuracy is {-0.054920178635115}
#
#
# for random state 59,the training accuracy is {0.9385724688151056}
# for random state 59 ,the testing accuracy is {0.1424075938078636}
#
#
# for random state 60,the training accuracy is {0.9421788649337753}
# for random state 60 ,the testing accuracy is {-0.23001663294335928}
#
#
# for random state 61,the training accuracy is {0.9370851143719889}
# for random state 61 ,the testing accuracy is {0.08768785574278215}
#
#
# for random state 62,the training accuracy is {0.9678335031351342}
# for random state 62 ,the testing accuracy is {-0.22283969470995824}
# for random state 63,the training accuracy is {0.9568534671120751}
# for random state 63 ,the testing accuracy is {0.1627035620920706}
#
#
# for random state 64,the training accuracy is {0.9376044501071964}
# for random state 64 ,the testing accuracy is {-0.038644464949944446}
#
#
# for random state 65,the training accuracy is {0.9354720725636494}
# for random state 65 ,the testing accuracy is {0.21985476326052777}
#
#
# for random state 66,the training accuracy is {0.937828730912983}
# for random state 66 ,the testing accuracy is {0.11332116679087445}
#
#
# for random state 67,the training accuracy is {0.947304629780847}
# for random state 67 ,the testing accuracy is {-0.20043753732919156}
#
#
# for random state 68,the training accuracy is {0.9314668410673401}
# for random state 68 ,the testing accuracy is {0.07157931405425078}
#
#
# for random state 69,the training accuracy is {0.9407951347811329}
# for random state 69 ,the testing accuracy is {-0.026468688198666435}
#
#
# for random state 70,the training accuracy is {0.9330615106243041}
# for random state 70 ,the testing accuracy is {0.12407248359689926}
#
#
# for random state 71,the training accuracy is {0.9493700060275062}
# for random state 71 ,the testing accuracy is {-0.005027825836313671}
#
#
# for random state 72,the training accuracy is {0.9484937003679077}
# for random state 72 ,the testing accuracy is {-0.12544317691262652}
#
#
# for random state 73,the training accuracy is {0.9242325550919426}
# for random state 73 ,the testing accuracy is {0.3906471415712861}
#
#
# for random state 74,the training accuracy is {0.9349054280554149}
# for random state 74 ,the testing accuracy is {0.29533041346957756}
#
#
# for random state 75,the training accuracy is {0.9523800908263137}
# for random state 75 ,the testing accuracy is {0.2098339508327871}
#
#
# for random state 76,the training accuracy is {0.9396010291961323}
# for random state 76 ,the testing accuracy is {0.02074512471775558}
#
#
# for random state 77,the training accuracy is {0.938294840772272}
# for random state 77 ,the testing accuracy is {0.1538025549034423}
#
#
# for random state 78,the training accuracy is {0.9356138786044454}
# for random state 78 ,the testing accuracy is {0.06846688933660772}
#
#
# for random state 79,the training accuracy is {0.9287317024086713}
# for random state 79 ,the testing accuracy is {0.08853632877280126}
#
#
# for random state 80,the training accuracy is {0.9391728792954598}
# for random state 80 ,the testing accuracy is {0.07081459922945577}
#
#
# for random state 81,the training accuracy is {0.9686117171743849}
# for random state 81 ,the testing accuracy is {0.11705093251374032}
#
#
# for random state 82,the training accuracy is {0.9409410157650113}
# for random state 82 ,the testing accuracy is {-0.02914406315928475}
#
#
# for random state 83,the training accuracy is {0.9459906752298024}
# for random state 83 ,the testing accuracy is {0.10609771848819427}
#
#
# for random state 84,the training accuracy is {0.944876087370627}
# for random state 84 ,the testing accuracy is {0.1652204216321529}
#
#
# for random state 85,the training accuracy is {0.9548515471577035}
# for random state 85 ,the testing accuracy is {-0.06907476470629059}
#
#
# for random state 86,the training accuracy is {0.9558482896417313}
# for random state 86 ,the testing accuracy is {-0.08321857414135359}
#
#
# for random state 87,the training accuracy is {0.9417234770496492}
# for random state 87 ,the testing accuracy is {0.07755002295956248}
#
#
# for random state 88,the training accuracy is {0.9563192900936692}
# for random state 88 ,the testing accuracy is {0.013548017760076858}
#
#
# for random state 89,the training accuracy is {0.9341766565521735}
# for random state 89 ,the testing accuracy is {0.3701195507269742}
#
#
# for random state 90,the training accuracy is {0.9462131563943683}
# for random state 90 ,the testing accuracy is {0.30503437364174024}
#
#
# for random state 91,the training accuracy is {0.950631223327722}
# for random state 91 ,the testing accuracy is {0.06009171035913541}
#
#
# for random state 92,the training accuracy is {0.9442292097824477}
# for random state 92 ,the testing accuracy is {0.2136125131694302}
#
#
# for random state 93,the training accuracy is {0.9429377476388418}
# for random state 93 ,the testing accuracy is {0.2657483385386016}
#
#
# for random state 94,the training accuracy is {0.9420112701171353}
# for random state 94 ,the testing accuracy is {-0.053237366429205846}
#
#
# for random state 95,the training accuracy is {0.9633762897220128}
# for random state 95 ,the testing accuracy is {0.20294568395861068}
#
#
# for random state 96,the training accuracy is {0.929285871755963}
# for random state 96 ,the testing accuracy is {0.13068349052880546}
#
#
# for random state 97,the training accuracy is {0.9453155163088441}
# for random state 97 ,the testing accuracy is {0.1152525798358528}
#
#
# for random state 98,the training accuracy is {0.936827337435672}
# for random state 98 ,the testing accuracy is {-0.046013336600091215}
#
#
# for random state 99,the training accuracy is {0.9445533281843193}
# for random state 99 ,the testing accuracy is {0.40301066814986775}

# %%
from sklearn.svm import SVR
svr=SVR()

# %%
for i in range (0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.20)
    svr.fit(x_train,y_train)
    pred_train=svr.predict(x_train)
    pred_test=svr.predict(x_test)
    print(f'for random state {i},the training accuracy is',{r2_score(y_train,pred_train)})
    print(f'for random state {i} ,the testing accuracy is',{r2_score(y_test, pred_test)})
    print('\n')
# Out:
# for random state 0,the training accuracy is {-0.031250814666510474}
# for random state 0 ,the testing accuracy is {-0.014567334380603203}
#
#
# for random state 1,the training accuracy is {-0.03874222100841074}
# for random state 1 ,the testing accuracy is {-0.04435605502050399}
#
#
# for random state 2,the training accuracy is {-0.036044201233079054}
# for random state 2 ,the testing accuracy is {-0.0672611750818346}
#
#
# for random state 3,the training accuracy is {-0.04866499052407569}
# for random state 3 ,the testing accuracy is {-0.05627028833875314}
#
#
# for random state 4,the training accuracy is {-0.03902555480360115}
# for random state 4 ,the testing accuracy is {-0.03201077377015493}
#
#
# for random state 5,the training accuracy is {-0.0354124302801766}
# for random state 5 ,the testing accuracy is {-0.0036297182306535003}
#
#
# for random state 6,the training accuracy is {-0.03476978716761869}
# for random state 6 ,the testing accuracy is {-0.11626338862466312}
#
#
# for random state 7,the training accuracy is {-0.03698147522197903}
# for random state 7 ,the testing accuracy is {0.001202584310414423}
#
#
# for random state 8,the training accuracy is {-0.047128999659988846}
# for random state 8 ,the testing accuracy is {-0.004337536848961543}
#
#
# for random state 9,the training accuracy is {-0.03200332889922275}
# for random state 9 ,the testing accuracy is {-0.07981829651861783}
#
#
# for random state 10,the training accuracy is {-0.033567739372738714}
# for random state 10 ,the testing accuracy is {-0.04819270593772007}
#
#
# for random state 11,the training accuracy is {-0.035955241478467626}
# for random state 11 ,the testing accuracy is {-0.0453301105710846}
#
#
# for random state 12,the training accuracy is {-0.03525188657941358}
# for random state 12 ,the testing accuracy is {-0.05849461772054987}
#
#
# for random state 13,the training accuracy is {-0.04115886956361292}
# for random state 13 ,the testing accuracy is {0.0007735087958438136}
#
#
# for random state 14,the training accuracy is {-0.02901861323993038}
# for random state 14 ,the testing accuracy is {-0.0804105673438682}
#
#
# for random state 15,the training accuracy is {-0.038846102442208874}
# for random state 15 ,the testing accuracy is {-0.036815011049786905}
#
#
# for random state 16,the training accuracy is {-0.026490888481365937}
# for random state 16 ,the testing accuracy is {-0.076378896423978}
#
#
# for random state 17,the training accuracy is {-0.041070841489577736}
# for random state 17 ,the testing accuracy is {-0.039658102974695186}
#
#
# for random state 18,the training accuracy is {-0.04476984130315942}
# for random state 18 ,the testing accuracy is {-0.04136427950242094}
#
#
# for random state 19,the training accuracy is {-0.03999161948486041}
# for random state 19 ,the testing accuracy is {-0.19293832398230437}
#
#
# for random state 20,the training accuracy is {-0.04585136172076454}
# for random state 20 ,the testing accuracy is {-0.007018886410965042}
#
#
# for random state 21,the training accuracy is {-0.03490932348061593}
# for random state 21 ,the testing accuracy is {-0.05505564246983696}
#
#
# for random state 22,the training accuracy is {-0.031956422186003364}
# for random state 22 ,the testing accuracy is {-0.01599915157518561}
#
#
# for random state 23,the training accuracy is {-0.03203790827339237}
# for random state 23 ,the testing accuracy is {-0.010319046368608698}
#
#
# for random state 24,the training accuracy is {-0.04882759665775316}
# for random state 24 ,the testing accuracy is {-0.02677440298778766}
#
#
# for random state 25,the training accuracy is {-0.04995356531019901}
# for random state 25 ,the testing accuracy is {-0.0012676527407518012}
#
#
# for random state 26,the training accuracy is {-0.035531369199386154}
# for random state 26 ,the testing accuracy is {-0.09256773364807458}
#
#
# for random state 27,the training accuracy is {-0.037832848905751115}
# for random state 27 ,the testing accuracy is {0.0015460981713862898}
#
#
# for random state 28,the training accuracy is {-0.03807822318657883}
# for random state 28 ,the testing accuracy is {-0.08026930869555216}
#
#
# for random state 29,the training accuracy is {-0.03346927959528423}
# for random state 29 ,the testing accuracy is {-0.0625195332316959}
#
#
# for random state 30,the training accuracy is {-0.047611730112179895}
# for random state 30 ,the testing accuracy is {-0.012231568955582306}
#
#
# for random state 31,the training accuracy is {-0.030498426435185744}
# for random state 31 ,the testing accuracy is {-0.08324596146251162}
#
#
# for random state 32,the training accuracy is {-0.03748498943691403}
# for random state 32 ,the testing accuracy is {-0.03256300645093968}
#
#
# for random state 33,the training accuracy is {-0.038808167489717604}
# for random state 33 ,the testing accuracy is {-0.027590453637446277}
#
#
# for random state 34,the training accuracy is {-0.03469659062330033}
# for random state 34 ,the testing accuracy is {-0.035066179232201566}
#
#
# for random state 35,the training accuracy is {-0.04108111349088128}
# for random state 35 ,the testing accuracy is {-0.006563473439710643}
#
#
# for random state 36,the training accuracy is {-0.0335778852247921}
# for random state 36 ,the testing accuracy is {-0.06838921705039236}
#
#
# for random state 37,the training accuracy is {-0.037415601914926766}
# for random state 37 ,the testing accuracy is {-0.003890006728944684}
#
#
# for random state 38,the training accuracy is {-0.04105813540692704}
# for random state 38 ,the testing accuracy is {-0.007267366125225605}
#
#
# for random state 39,the training accuracy is {-0.0432452619319188}
# for random state 39 ,the testing accuracy is {-0.018922458765984196}
#
#
# for random state 40,the training accuracy is {-0.03635080746778496}
# for random state 40 ,the testing accuracy is {-0.03433856515613587}
#
#
# for random state 41,the training accuracy is {-0.04624319504495378}
# for random state 41 ,the testing accuracy is {-0.001718514181163977}
#
#
# for random state 42,the training accuracy is {-0.02827809053568986}
# for random state 42 ,the testing accuracy is {-0.13513128776136352}
#
#
# for random state 43,the training accuracy is {-0.04243152295621755}
# for random state 43 ,the testing accuracy is {-0.026236246961540033}
#
#
# for random state 44,the training accuracy is {-0.027935745445231364}
# for random state 44 ,the testing accuracy is {-0.088646933130472}
#
#
# for random state 45,the training accuracy is {-0.03879666089218081}
# for random state 45 ,the testing accuracy is {-0.04949378861800602}
#
#
# for random state 46,the training accuracy is {-0.033192320559899624}
# for random state 46 ,the testing accuracy is {-0.08281268709151224}
#
#
# for random state 47,the training accuracy is {-0.05121118611061548}
# for random state 47 ,the testing accuracy is {-0.0016948647666295003}
#
#
# for random state 48,the training accuracy is {-0.031175999392817122}
# for random state 48 ,the testing accuracy is {-0.08534688361564391}
#
#
# for random state 49,the training accuracy is {-0.03848182069198325}
# for random state 49 ,the testing accuracy is {-0.045830259936815}
#
#
# for random state 50,the training accuracy is {-0.04435075382701448}
# for random state 50 ,the testing accuracy is {-0.0106507814994381}
#
#
# for random state 51,the training accuracy is {-0.040835562804266035}
# for random state 51 ,the testing accuracy is {-0.03567412673678816}
#
#
# for random state 52,the training accuracy is {-0.037398521449471644}
# for random state 52 ,the testing accuracy is {-0.07403826480065878}
#
#
# for random state 53,the training accuracy is {-0.039940300900564996}
# for random state 53 ,the testing accuracy is {-0.008402404484055825}
#
#
# for random state 54,the training accuracy is {-0.03818747561468028}
# for random state 54 ,the testing accuracy is {-0.13580733683090407}
#
#
# for random state 55,the training accuracy is {-0.03929830603584339}
# for random state 55 ,the testing accuracy is {-0.026202100910852844}
#
#
# for random state 56,the training accuracy is {-0.0381493685976424}
# for random state 56 ,the testing accuracy is {-0.09637325706029198}
#
#
# for random state 57,the training accuracy is {-0.03309263942688423}
# for random state 57 ,the testing accuracy is {-0.0691739727273053}
#
#
# for random state 58,the training accuracy is {-0.03123193728955087}
# for random state 58 ,the testing accuracy is {-0.018665471977960646}
#
#
# for random state 59,the training accuracy is {-0.043812926365718985}
# for random state 59 ,the testing accuracy is {-0.026598552518058982}
#
#
# for random state 60,the training accuracy is {-0.027199801542276747}
# for random state 60 ,the testing accuracy is {-0.11482763454477629}
#
#
# for random state 61,the training accuracy is {-0.038619040357405154}
# for random state 61 ,the testing accuracy is {-0.0011076926269337761}
# for random state 62,the training accuracy is {-0.03401197922410959}
# for random state 62 ,the testing accuracy is {-0.06043973809305658}
#
#
# for random state 63,the training accuracy is {-0.03958591735052064}
# for random state 63 ,the testing accuracy is {-0.08354649798027047}
#
#
# for random state 64,the training accuracy is {-0.03840926744803652}
# for random state 64 ,the testing accuracy is {-0.008949639497729978}
#
#
# for random state 65,the training accuracy is {-0.03489657005099556}
# for random state 65 ,the testing accuracy is {-0.07033092395832119}
#
#
# for random state 66,the training accuracy is {-0.04516957533663457}
# for random state 66 ,the testing accuracy is {-0.039955870936174254}
#
#
# for random state 67,the training accuracy is {-0.047477359840881084}
# for random state 67 ,the testing accuracy is {-0.0028757778810475365}
#
#
# for random state 68,the training accuracy is {-0.03992854017323588}
# for random state 68 ,the testing accuracy is {-0.032413001285342524}
#
#
# for random state 69,the training accuracy is {-0.04191911181596053}
# for random state 69 ,the testing accuracy is {-0.05155498570356687}
#
#
# for random state 70,the training accuracy is {-0.03522474152838351}
# for random state 70 ,the testing accuracy is {-0.051352979663146}
#
#
# for random state 71,the training accuracy is {-0.04737452646667384}
# for random state 71 ,the testing accuracy is {-0.0064771728484300795}
#
#
# for random state 72,the training accuracy is {-0.032486585785996835}
# for random state 72 ,the testing accuracy is {-0.0441730032757528}
#
#
# for random state 73,the training accuracy is {-0.036933929058030834}
# for random state 73 ,the testing accuracy is {-0.015953381322628912}
#
#
# for random state 74,the training accuracy is {-0.046154536928665335}
# for random state 74 ,the testing accuracy is {-0.013252567693482042}
#
#
# for random state 75,the training accuracy is {-0.03084120679498814}
# for random state 75 ,the testing accuracy is {-0.08227070716981055}
#
#
# for random state 76,the training accuracy is {-0.044434742429931395}
# for random state 76 ,the testing accuracy is {-0.09664821840933624}
#
#
# for random state 77,the training accuracy is {-0.042900150211674815}
# for random state 77 ,the testing accuracy is {-0.010737162175511683}
#
#
# for random state 78,the training accuracy is {-0.039927354175485874}
# for random state 78 ,the testing accuracy is {-0.03212293877844896}
#
#
# for random state 79,the training accuracy is {-0.043450754572673445}
# for random state 79 ,the testing accuracy is {-0.08016457030502111}
#
#
# for random state 80,the training accuracy is {-0.038349581462095106}
# for random state 80 ,the testing accuracy is {-0.02888642689318721}
#
#
# for random state 81,the training accuracy is {-0.03268632226612356}
# for random state 81 ,the testing accuracy is {-0.077781021945599}
#
#
# for random state 82,the training accuracy is {-0.03933406387932492}
# for random state 82 ,the testing accuracy is {-0.064887341503582}
#
#
# for random state 83,the training accuracy is {-0.03687890623793555}
# for random state 83 ,the testing accuracy is {-0.04351601498359137}
#
#
# for random state 84,the training accuracy is {-0.03611897932091357}
# for random state 84 ,the testing accuracy is {-0.0024489653441939208}
#
#
# for random state 85,the training accuracy is {-0.03995395833617077}
# for random state 85 ,the testing accuracy is {-0.032573369408388064}
#
#
# for random state 86,the training accuracy is {-0.036342368079730125}
# for random state 86 ,the testing accuracy is {-0.03457687924563935}
#
#
# for random state 87,the training accuracy is {-0.042347718064447815}
# for random state 87 ,the testing accuracy is {-0.029674753737310544}
#
#
# for random state 88,the training accuracy is {-0.037050295602041095}
# for random state 88 ,the testing accuracy is {-0.10153787383931911}
#
#
# for random state 89,the training accuracy is {-0.03214429240455696}
# for random state 89 ,the testing accuracy is {-0.0016826782191041723}
#
#
# for random state 90,the training accuracy is {-0.0471247093501157}
# for random state 90 ,the testing accuracy is {-0.032127024804251336}
#
#
# for random state 91,the training accuracy is {-0.03771491853104747}
# for random state 91 ,the testing accuracy is {-0.04406753688869203}
#
#
# for random state 92,the training accuracy is {-0.03676659117599601}
# for random state 92 ,the testing accuracy is {-0.13785485233877282}
#
#
# for random state 93,the training accuracy is {-0.03544185324209703}
# for random state 93 ,the testing accuracy is {-0.06258141487200652}
#
#
# for random state 94,the training accuracy is {-0.036921179784630054}
# for random state 94 ,the testing accuracy is {-0.04934793970305318}
#
#
# for random state 95,the training accuracy is {-0.038355478219758155}
# for random state 95 ,the testing accuracy is {-0.04125283583377648}
#
#
# for random state 96,the training accuracy is {-0.03988190774467282}
# for random state 96 ,the testing accuracy is {-0.028997699410879152}
#
#
# for random state 97,the training accuracy is {-0.038204394286211585}
# for random state 97 ,the testing accuracy is {-0.04758054830313818}
#
#
# for random state 98,the training accuracy is {-0.048533861642490184}
# for random state 98 ,the testing accuracy is {-0.008767245411719138}
#
#
# for random state 99,the training accuracy is {-0.04146695191992977}
# for random state 99 ,the testing accuracy is {-0.03860148601944147}

# %%
from sklearn.neighbors import KNeighborsRegressor
knn= KNeighborsRegressor()

# %%
for i in range (0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.20)
    knn.fit(x_train,y_train)
    pred_train=knn.predict(x_train)
    pred_test=knn.predict(x_test)
    print(f'for random state {i},the training accuracy is',{r2_score(y_train,pred_train)})
    print(f'for random state {i} ,the testing accuracy is',{r2_score(y_test, pred_test)})
    print('\n')
# Out:
# for random state 0,the training accuracy is {0.626053277135203}
# for random state 0 ,the testing accuracy is {0.4321359939091527}
#
#
# for random state 1,the training accuracy is {0.6054898717851758}
# for random state 1 ,the testing accuracy is {0.4818858229323064}
#
#
# for random state 2,the training accuracy is {0.6297664105573597}
# for random state 2 ,the testing accuracy is {0.3033622002469868}
#
#
# for random state 3,the training accuracy is {0.609108798349814}
# for random state 3 ,the testing accuracy is {0.48352914066213404}
#
#
# for random state 4,the training accuracy is {0.651385438960749}
# for random state 4 ,the testing accuracy is {0.2003190691164103}
#
#
# for random state 5,the training accuracy is {0.5960797069871978}
# for random state 5 ,the testing accuracy is {0.4594629175258047}
#
#
# for random state 6,the training accuracy is {0.6435683819452827}
# for random state 6 ,the testing accuracy is {0.3131943275201756}
#
#
# for random state 7,the training accuracy is {0.625331531327852}
# for random state 7 ,the testing accuracy is {0.48354568836814726}
#
#
# for random state 8,the training accuracy is {0.6368563481783927}
# for random state 8 ,the testing accuracy is {0.3844819613838596}
#
#
# for random state 9,the training accuracy is {0.6066129005813183}
# for random state 9 ,the testing accuracy is {0.5065707397195487}
#
#
# for random state 10,the training accuracy is {0.6286322450548515}
# for random state 10 ,the testing accuracy is {0.3597600377353267}
#
#
# for random state 11,the training accuracy is {0.5988875387163589}
# for random state 11 ,the testing accuracy is {0.45071431665495676}
#
#
# for random state 12,the training accuracy is {0.6115583021978501}
# for random state 12 ,the testing accuracy is {0.5287087209618144}
#
#
# for random state 13,the training accuracy is {0.6254200385985256}
# for random state 13 ,the testing accuracy is {0.5007887108922058}
#
#
# for random state 14,the training accuracy is {0.6677599974750024}
# for random state 14 ,the testing accuracy is {0.2810887731191971}
#
#
# for random state 15,the training accuracy is {0.599429131914077}
# for random state 15 ,the testing accuracy is {0.559261546079413}
#
#
# for random state 16,the training accuracy is {0.6299639168741789}
# for random state 16 ,the testing accuracy is {0.3435568663163491}
#
#
# for random state 17,the training accuracy is {0.6413128594812343}
# for random state 17 ,the testing accuracy is {0.3374240175330694}
#
#
# for random state 18,the training accuracy is {0.6122170853162887}
# for random state 18 ,the testing accuracy is {0.49727393112381524}
#
#
# for random state 19,the training accuracy is {0.6113587974998926}
# for random state 19 ,the testing accuracy is {0.4709237974121401}
#
#
# for random state 20,the training accuracy is {0.6167187800223781}
# for random state 20 ,the testing accuracy is {0.46242453639180503}
#
#
# for random state 21,the training accuracy is {0.6586578245890984}
# for random state 21 ,the testing accuracy is {0.2022563886735319}
#
#
# for random state 22,the training accuracy is {0.6245947603361497}
# for random state 22 ,the testing accuracy is {0.41542532643447105}
#
#
# for random state 23,the training accuracy is {0.6353108160581765}
# for random state 23 ,the testing accuracy is {0.3511760610199257}
#
#
# for random state 24,the training accuracy is {0.6459193503658591}
# for random state 24 ,the testing accuracy is {0.46981679595186077}
#
#
# for random state 25,the training accuracy is {0.6330940196734329}
# for random state 25 ,the testing accuracy is {0.25865146189324173}
#
#
# for random state 26,the training accuracy is {0.6480567219590729}
# for random state 26 ,the testing accuracy is {0.2015960972480776}
#
#
# for random state 27,the training accuracy is {0.6113653189669332}
# for random state 27 ,the testing accuracy is {0.4034665047954632}
#
#
# for random state 28,the training accuracy is {0.6404754033213818}
# for random state 28 ,the testing accuracy is {0.15034855971896743}
#
#
# for random state 29,the training accuracy is {0.6151621215788058}
# for random state 29 ,the testing accuracy is {0.5057747519440046}
#
#
# for random state 30,the training accuracy is {0.6025217262744629}
# for random state 30 ,the testing accuracy is {0.5894107698812249}
#
#
# for random state 31,the training accuracy is {0.6227907142929237}
# for random state 31 ,the testing accuracy is {0.40809991689510405}
#
#
# for random state 32,the training accuracy is {0.6062533497645264}
# for random state 32 ,the testing accuracy is {0.4750332846203018}
#
#
# for random state 33,the training accuracy is {0.6220586174563041}
# for random state 33 ,the testing accuracy is {0.3054478464952102}
#
#
# for random state 34,the training accuracy is {0.625046341218852}
# for random state 34 ,the testing accuracy is {0.45577543195204506}
#
#
# for random state 35,the training accuracy is {0.5980742958495424}
# for random state 35 ,the testing accuracy is {0.5328075128568086}
#
#
# for random state 36,the training accuracy is {0.6663766896332872}
# for random state 36 ,the testing accuracy is {0.18695638800680447}
#
#
# for random state 37,the training accuracy is {0.6296594225186597}
# for random state 37 ,the testing accuracy is {0.44529066063317424}
#
#
# for random state 38,the training accuracy is {0.627214998762338}
# for random state 38 ,the testing accuracy is {0.45965752316154584}
#
#
# for random state 39,the training accuracy is {0.6536316132769148}
# for random state 39 ,the testing accuracy is {0.36286761864698525}
#
#
# for random state 40,the training accuracy is {0.6371122334659668}
# for random state 40 ,the testing accuracy is {0.3775450326862587}
#
#
# for random state 41,the training accuracy is {0.6190475096210162}
# for random state 41 ,the testing accuracy is {0.4038613981943143}
#
#
# for random state 42,the training accuracy is {0.6193158343206301}
# for random state 42 ,the testing accuracy is {0.4374614886353563}
#
#
# for random state 43,the training accuracy is {0.6333182737731596}
# for random state 43 ,the testing accuracy is {0.31365768453138854}
#
#
# for random state 44,the training accuracy is {0.629358399048837}
# for random state 44 ,the testing accuracy is {0.34894411870339304}
#
#
# for random state 45,the training accuracy is {0.6112740510587433}
# for random state 45 ,the testing accuracy is {0.5185407151653626}
#
#
# for random state 46,the training accuracy is {0.6254107519921452}
# for random state 46 ,the testing accuracy is {0.3059694195523017}
#
#
# for random state 47,the training accuracy is {0.6309196316943224}
# for random state 47 ,the testing accuracy is {0.3815410090625182}
#
#
# for random state 48,the training accuracy is {0.610038862196757}
# for random state 48 ,the testing accuracy is {0.5001660450716638}
#
#
# for random state 49,the training accuracy is {0.6131584465412083}
# for random state 49 ,the testing accuracy is {0.44129536049667484}
#
#
# for random state 50,the training accuracy is {0.6335613225162455}
# for random state 50 ,the testing accuracy is {0.3769817521209522}
#
#
# for random state 51,the training accuracy is {0.6237192425494602}
# for random state 51 ,the testing accuracy is {0.38767031346787206}
#
#
# for random state 52,the training accuracy is {0.6125250743237508}
# for random state 52 ,the testing accuracy is {0.5201912942485867}
#
#
# for random state 53,the training accuracy is {0.6391638018500347}
# for random state 53 ,the testing accuracy is {0.3999735524502107}
#
#
# for random state 54,the training accuracy is {0.6028221833463394}
# for random state 54 ,the testing accuracy is {0.4169877210820697}
#
#
# for random state 55,the training accuracy is {0.6184012668701762}
# for random state 55 ,the testing accuracy is {0.4762623532136425}
#
#
# for random state 56,the training accuracy is {0.6572985877732971}
# for random state 56 ,the testing accuracy is {0.2881842904889429}
#
#
# for random state 57,the training accuracy is {0.6253931693201177}
# for random state 57 ,the testing accuracy is {0.38732005641151124}
#
#
# for random state 58,the training accuracy is {0.6260709531366326}
# for random state 58 ,the testing accuracy is {0.1953234435119442}
#
#
# for random state 59,the training accuracy is {0.6186155895845518}
# for random state 59 ,the testing accuracy is {0.4909556926957612}
#
#
# for random state 60,the training accuracy is {0.6421952965818407}
# for random state 60 ,the testing accuracy is {0.2598333077954138}
#
#
# for random state 61,the training accuracy is {0.6072214770928466}
# for random state 61 ,the testing accuracy is {0.49703180118011514}
#
#
# for random state 62,the training accuracy is {0.637612318456014}
# for random state 62 ,the testing accuracy is {0.3868100800756382}
#
#
# for random state 63,the training accuracy is {0.6124477398235275}
# for random state 63 ,the testing accuracy is {0.4945134475098283}
#
#
# for random state 64,the training accuracy is {0.610614521432832}
# for random state 64 ,the testing accuracy is {0.46181850370518784}
#
#
# for random state 65,the training accuracy is {0.5992931548886926}
# for random state 65 ,the testing accuracy is {0.5406560391771158}
#
#
# for random state 66,the training accuracy is {0.611221118987777}
# for random state 66 ,the testing accuracy is {0.5467694495244151}
#
#
# for random state 67,the training accuracy is {0.6430181329716187}
# for random state 67 ,the testing accuracy is {0.3253864430281007}
#
#
# for random state 68,the training accuracy is {0.623120297333202}
# for random state 68 ,the testing accuracy is {0.45822852117301494}
#
#
# for random state 69,the training accuracy is {0.6367544447323158}
# for random state 69 ,the testing accuracy is {0.398896184044947}
#
#
# for random state 70,the training accuracy is {0.6506571547166433}
# for random state 70 ,the testing accuracy is {0.2984208306769297}
#
#
# for random state 71,the training accuracy is {0.6410359962053076}
# for random state 71 ,the testing accuracy is {0.3416972305752476}
# for random state 72,the training accuracy is {0.6411750154005703}
# for random state 72 ,the testing accuracy is {0.23708613407340695}
#
#
# for random state 73,the training accuracy is {0.6077811254470582}
# for random state 73 ,the testing accuracy is {0.5249093042542439}
#
#
# for random state 74,the training accuracy is {0.6140380111329825}
# for random state 74 ,the testing accuracy is {0.4378186417438622}
#
#
# for random state 75,the training accuracy is {0.6320466053249126}
# for random state 75 ,the testing accuracy is {0.4410597055727439}
#
#
# for random state 76,the training accuracy is {0.6254996718962029}
# for random state 76 ,the testing accuracy is {0.403871333380893}
#
#
# for random state 77,the training accuracy is {0.6289980793108912}
# for random state 77 ,the testing accuracy is {0.43048703389886}
#
#
# for random state 78,the training accuracy is {0.6122501373892297}
# for random state 78 ,the testing accuracy is {0.4839941482688257}
#
#
# for random state 79,the training accuracy is {0.6408084969948113}
# for random state 79 ,the testing accuracy is {0.46386380358692303}
#
#
# for random state 80,the training accuracy is {0.6497023741335872}
# for random state 80 ,the testing accuracy is {0.4013745085751792}
#
#
# for random state 81,the training accuracy is {0.6192522173252021}
# for random state 81 ,the testing accuracy is {0.43554818823141195}
#
#
# for random state 82,the training accuracy is {0.649513617462466}
# for random state 82 ,the testing accuracy is {0.34447211182425586}
#
#
# for random state 83,the training accuracy is {0.6480987262838334}
# for random state 83 ,the testing accuracy is {0.3625912424483885}
#
#
# for random state 84,the training accuracy is {0.6219767066088915}
# for random state 84 ,the testing accuracy is {0.43508936402399034}
#
#
# for random state 85,the training accuracy is {0.6035744091928668}
# for random state 85 ,the testing accuracy is {0.39664828359502124}
#
#
# for random state 86,the training accuracy is {0.6390030147152231}
# for random state 86 ,the testing accuracy is {0.3510569357059743}
#
#
# for random state 87,the training accuracy is {0.6240869904815892}
# for random state 87 ,the testing accuracy is {0.3564234504881062}
#
#
# for random state 88,the training accuracy is {0.6147856560500006}
# for random state 88 ,the testing accuracy is {0.44638351047555613}
#
#
# for random state 89,the training accuracy is {0.6044485602460614}
# for random state 89 ,the testing accuracy is {0.4897738341760214}
#
#
# for random state 90,the training accuracy is {0.5891750700541147}
# for random state 90 ,the testing accuracy is {0.5636683110029042}
#
#
# for random state 91,the training accuracy is {0.6296058418072512}
# for random state 91 ,the testing accuracy is {0.44014229982910846}
#
#
# for random state 92,the training accuracy is {0.5738427031024389}
# for random state 92 ,the testing accuracy is {0.5344297794589783}
#
#
# for random state 93,the training accuracy is {0.5946286207561178}
# for random state 93 ,the testing accuracy is {0.5189597978269636}
#
#
# for random state 94,the training accuracy is {0.6647217156268559}
# for random state 94 ,the testing accuracy is {0.24991618700552443}
#
#
# for random state 95,the training accuracy is {0.634537941533599}
# for random state 95 ,the testing accuracy is {0.4395557364405558}
#
#
# for random state 96,the training accuracy is {0.6246618184490542}
# for random state 96 ,the testing accuracy is {0.3666789076475402}
#
#
# for random state 97,the training accuracy is {0.6338636010275941}
# for random state 97 ,the testing accuracy is {0.39079115845565027}
#
#
# for random state 98,the training accuracy is {0.6162062613838748}
# for random state 98 ,the testing accuracy is {0.49012141955416844}
#
#
# for random state 99,the training accuracy is {0.6057204833541286}
# for random state 99 ,the testing accuracy is {0.4821457641807302}

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=30,test_size=.20)
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
pred_test=knn.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.5894107698812249

# %%
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred_test))
print('Mean squared error :',mean_squared_error(y_test,pred_test))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_test)))
# Out:
# error:
# Mean absolute error: 14765.600000000002
# Mean squared error : 380181536.57012665
# Root Mean Squared Error: 19498.244448414494

# %%
#cross validation

Train_accuracy=r2_score(y_train,pred_train)
testing_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(knn,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is {cv_mean} and the train accuracy score is {Train_accuracy} and test accuracy score is {testing_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is 0.3910331166859963 and the train accuracy score is -0.6208911412655802 and test accuracy score is -1.1322409494999666
#
#
# at cross fold 3 the cv score is 0.3561037137451261 and the train accuracy score is -0.6208911412655802 and test accuracy score is -1.1322409494999666
#
#
# at cross fold 4 the cv score is 0.37615575019551595 and the train accuracy score is -0.6208911412655802 and test accuracy score is -1.1322409494999666
#
#
# at cross fold 5 the cv score is 0.3342239876516308 and the train accuracy score is -0.6208911412655802 and test accuracy score is -1.1322409494999666
#
#
# at cross fold 6 the cv score is 0.36371920887320486 and the train accuracy score is -0.6208911412655802 and test accuracy score is -1.1322409494999666
#
#
# at cross fold 7 the cv score is 0.33826862211388736 and the train accuracy score is -0.6208911412655802 and test accuracy score is -1.1322409494999666
#
#
# at cross fold 8 the cv score is 0.3564481090526648 and the train accuracy score is -0.6208911412655802 and test accuracy score is -1.1322409494999666
#
#
# at cross fold 9 the cv score is 0.33727443692029313 and the train accuracy score is -0.6208911412655802 and test accuracy score is -1.1322409494999666

# %%
#grid search cv

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso

parameters={'alpha':[.0001, .001, .01, .1, 1, 10 ],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
#model training


ls=Lasso(alpha=10,random_state=0)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
ls_score_training*100
# Out:
# 42.497014874945

# %%
lss=r2_score(y_test,pred_ls)
lss*100
# Out:
# 41.29955842775811

# %%
cv_score=cross_val_score(lr,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# 36.138672712740984

# %%
#ENsemble technique

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['mse','mae' ],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'log2'}

# %%
rf=RandomForestRegressor(criterion='mae',max_features='sqrt')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_dec=rf.predict(x_test)

rfs=r2_score(y_test,pred_dec)
print('r2_score:',rfs*100)

rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print('cross val score',rfc*100)
# Out:
# r2_score: 29.630441179372568
# cross val score 28.637988530505353

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbreg = GradientBoostingRegressor(random_state=0)

clf = GradientBoostingRegressor(n_estimators=200,max_depth=5, random_state=0).fit(x_train, y_train)
gbreg.fit(x_train, y_train)

rf.score(x_train,y_train)
pred_dec=rf.predict(x_test)

rfs=r2_score(y_test,pred_dec)
print('r2_score:',rfs*100)

rfscore=cross_val_score(gbreg,x,y,cv=5)
rfc=rfscore.mean()
print('cross val score',rfc*100)
# Out:
# r2_score: 29.630441179372568
# cross val score 29.390654970666386

# %%
import pickle
filename='salaryreport.pkl'
pickle.dump(rf,open(filename,'wb'))

# %%
loadmodel=pickle.load(open('salaryreport.pkl','rb'))
result=loadmodel.score(x_test,y_test)
print(result*100)
# Out:
# 29.630441179372568

# %%
conclusion=pd.DataFrame([loadmodel.predict(x_test)[:],pred_dec[:]],index=['predicted','original'])
conclusion
# Out:
#                   0          1           2           3           4   \
# predicted  148637.97  80862.375  128705.235  138266.285  133175.245
# original   148637.97  80862.375  128705.235  138266.285  133175.245
#
#                    5          6           7           8         9   ...  \
# predicted  144531.225  155333.88  111115.755  145987.705  79084.94  ...
# original   144531.225  155333.88  111115.755  145987.705  79084.94  ...
#
#                   69          70          71        72          73  \
# predicted  78888.525  114828.355  124314.065  106731.6  162547.945
# original   78888.525  114828.355  124314.065  106731.6  162547.945
#
#                    74          75         76        77        78
# predicted  108274.615  108977.035  100910.23  92753.06  141335.6
# original   108274.615  108977.035  100910.23  92753.06  141335.6
#
# [2 rows x 79 columns]
