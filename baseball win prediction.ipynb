# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('baseball win prediction.csv')

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.sample()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO  SB   RA   ER   ERA  CG  SHO  \
# 21  83  703  5428  1363  265  13  177  539  1344  57  635  577  3.62   4   13
#
#     SV   E
# 21  41  90

# %%
df.value_counts()
# Out:
# W    R    AB    H     2B   3B  HR   BB   SO    SB   RA   ER   ERA   CG  SHO  SV  E
# 63   626  5529  1374  272  37  130  387  1274  88   809  749  4.69  1   7    35  117    1
# 64   640  5571  1382  257  27  167  496  1255  134  754  700  4.33  2   8    35  90     1
# 98   697  5631  1462  292  27  140  461  1322  98   596  532  3.21  0   13   54  122    1
# 97   689  5491  1341  272  30  171  567  1518  95   608  546  3.36  6   21   48  111    1
# 95   724  5575  1497  300  42  139  383  973   104  641  601  3.73  2   8    56  88     1
# 93   891  5509  1480  308  17  232  570  1151  88   670  609  3.80  7   10   34  88     1
# 92   667  5385  1346  263  26  187  563  1258  59   595  553  3.44  6   21   47  75     1
# 90   683  5527  1351  295  17  177  488  1290  51   613  557  3.43  1   14   50  88     1
# 88   751  5511  1419  279  32  172  503  1233  101  733  680  4.24  5   9    45  119    1
# 87   764  5567  1397  272  19  212  554  1227  63   698  652  4.03  3   4    48  93     1
# 86   729  5459  1363  278  26  230  486  1392  121  618  572  3.57  5   13   39  85     1
# 85   661  5417  1331  243  21  176  435  1150  52   675  630  3.94  2   12   46  93     1
# 84   696  5565  1486  288  39  136  457  1159  93   627  597  3.72  7   18   41  78     1
# 83   703  5428  1363  265  13  177  539  1344  57   635  577  3.62  4   13   41  90     1
#      696  5467  1349  277  44  156  439  1264  70   700  653  4.07  2   12   45  86     1
# 81   713  5485  1370  246  20  217  418  1331  44   693  646  4.05  0   10   43  77     1
#      669  5439  1395  303  29  141  533  1157  86   640  584  3.67  11  10   38  79     1
# 80   644  5485  1383  278  32  167  436  1310  87   642  604  3.74  1   12   60  95     1
# 79   720  5649  1494  289  48  154  490  1312  132  713  659  4.04  1   12   44  86     1
# 78   748  5640  1495  294  33  161  478  1148  71   753  694  4.31  3   10   40  97     1
# 76   656  5544  1379  262  22  198  478  1336  69   726  677  4.16  6   12   45  94     1
#      622  5533  1381  260  27  136  404  1231  68   701  643  3.98  7   9    37  101    1
# 74   689  5605  1515  289  49  151  455  1259  83   803  746  4.64  7   12   35  86     1
#      650  5457  1324  260  36  148  426  1327  82   731  655  4.09  1   6    41  92     1
# 71   613  5463  1420  236  40  120  375  1150  112  678  638  4.02  0   12   35  77     1
# 68   737  5572  1479  274  49  186  388  1283  97   844  799  5.04  4   4    36  95     1
#      694  5600  1405  277  46  146  475  1119  78   729  664  4.14  5   15   28  126    1
#      655  5480  1378  274  34  145  412  1299  84   737  682  4.28  1   7    40  116    1
# 67   573  5420  1361  251  18  100  471  1107  69   760  698  4.41  3   10   44  90     1
# 100  647  5484  1386  288  39  137  506  1267  69   525  478  2.94  1   15   62  96     1
# dtype: int64

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.isnull()
# Out:
#         W      R     AB      H     2B     3B     HR     BB     SO     SB  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False  False  False  False
# 12  False  False  False  False  False  False  False  False  False  False
# 13  False  False  False  False  False  False  False  False  False  False
# 14  False  False  False  False  False  False  False  False  False  False
# 15  False  False  False  False  False  False  False  False  False  False
# 16  False  False  False  False  False  False  False  False  False  False
# 17  False  False  False  False  False  False  False  False  False  False
# 18  False  False  False  False  False  False  False  False  False  False
# 19  False  False  False  False  False  False  False  False  False  False
# 20  False  False  False  False  False  False  False  False  False  False
# 21  False  False  False  False  False  False  False  False  False  False
# 22  False  False  False  False  False  False  False  False  False  False
# 23  False  False  False  False  False  False  False  False  False  False
# 24  False  False  False  False  False  False  False  False  False  False
# 25  False  False  False  False  False  False  False  False  False  False
# 26  False  False  False  False  False  False  False  False  False  False
# 27  False  False  False  False  False  False  False  False  False  False
# 28  False  False  False  False  False  False  False  False  False  False
# 29  False  False  False  False  False  False  False  False  False  False
#
#        RA     ER    ERA     CG    SHO     SV      E
# 0   False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False
# 12  False  False  False  False  False  False  False
# 13  False  False  False  False  False  False  False
# 14  False  False  False  False  False  False  False
# 15  False  False  False  False  False  False  False
# 16  False  False  False  False  False  False  False
# 17  False  False  False  False  False  False  False
# 18  False  False  False  False  False  False  False
# 19  False  False  False  False  False  False  False
# 20  False  False  False  False  False  False  False
# 21  False  False  False  False  False  False  False
# 22  False  False  False  False  False  False  False
# 23  False  False  False  False  False  False  False
# 24  False  False  False  False  False  False  False
# 25  False  False  False  False  False  False  False
# 26  False  False  False  False  False  False  False
# 27  False  False  False  False  False  False  False
# 28  False  False  False  False  False  False  False
# 29  False  False  False  False  False  False  False

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
#check null values in heatmap
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df['W'].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['ERA']=le.fit_transform(df['ERA'])

# %%
df['ERA'].value_counts()
# Out:
# 9     1
# 18    1
# 19    1
# 16    1
# 8     1
# 4     1
# 28    1
# 26    1
# 14    1
# 6     1
# 3     1
# 25    1
# 23    1
# 2     1
# 1     1
# 0     1
# 20    1
# 21    1
# 12    1
# 5     1
# 22    1
# 24    1
# 10    1
# 17    1
# 15    1
# 11    1
# 27    1
# 13    1
# 7     1
# 29    1
# Name: ERA, dtype: int64

# %%
df.dtypes
# Out:
# W      int64
# R      int64
# AB     int64
# H      int64
# 2B     int64
# 3B     int64
# HR     int64
# BB     int64
# SO     int64
# SB     int64
# RA     int64
# ER     int64
# ERA    int64
# CG     int64
# SHO    int64
# SV     int64
# E      int64
# dtype: object

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.821919 -0.102821  0.270814  0.186454 -0.259106  0.318347 -0.147641
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.821919  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.102821  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.270814 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.186454  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.259106  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.318347 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.147641  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.417040  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.184298 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.111508 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.969711 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.968428 -0.020221
# ERA -0.417040 -0.184298  0.111508  0.969711  0.968428  1.000000 -0.083627
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.083627  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.615567  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.549021 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.184921 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.615567 -0.549021  0.184921
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %%
df.corr()['W']
# Out:
# W      1.000000
# R      0.430751
# AB    -0.087947
# H      0.037612
# 2B     0.427797
# 3B    -0.251118
# HR     0.307407
# BB     0.484342
# SO     0.111850
# SB    -0.157234
# RA    -0.812952
# ER    -0.809435
# ERA   -0.821919
# CG     0.080533
# SHO    0.471805
# SV     0.666530
# E     -0.089485
# Name: W, dtype: float64

# %%
df.corr()['W'].sort_values()
# Out:
# ERA   -0.821919
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %%
plt.figure(figsize=(10,14))
sns.heatmap(df.corr(),annot=True,fmt='.2f',linewidth=2)
plt.title('correlation matrix')
plt.show()

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER  ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601    9   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653   18   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584    7  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643   13   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746   27   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609   11   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652   15   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646   17   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604   10   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694   24   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680   22   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572    5   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630   12   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677   21   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664   20   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478    0   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532    1   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546    2   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682   23   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700   25   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557    3   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577    6   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638   14   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698   26   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749   28   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553    4   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597    8   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659   16   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655   19   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799   29   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
sns.scatterplot(x='ERA',y="W",data=df)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %%
sns.scatterplot(x='AB',y="W",data=df)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %%
sns.scatterplot(x='2B',y="W",data=df)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %%
sns.scatterplot(x='3B',y="W",data=df)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %%
sns.scatterplot(x='HR',y="W",data=df)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %%
sns.scatterplot(x='BB',y="W",data=df)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='W'>

# %%
df.plot(kind='kde',subplots=True,layout=(5,7),figsize=(10,15))  #we see skewness present in some columns
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %%
df.boxplot(figsize=[20,25])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
df.plot(kind='box',subplots=True,layout=(5,5),figsize=(10,15))
# Out:
# W         AxesSubplot(0.125,0.747241;0.133621x0.132759)
# R      AxesSubplot(0.285345,0.747241;0.133621x0.132759)
# AB      AxesSubplot(0.44569,0.747241;0.133621x0.132759)
# H      AxesSubplot(0.606034,0.747241;0.133621x0.132759)
# 2B     AxesSubplot(0.766379,0.747241;0.133621x0.132759)
# 3B        AxesSubplot(0.125,0.587931;0.133621x0.132759)
# HR     AxesSubplot(0.285345,0.587931;0.133621x0.132759)
# BB      AxesSubplot(0.44569,0.587931;0.133621x0.132759)
# SO     AxesSubplot(0.606034,0.587931;0.133621x0.132759)
# SB     AxesSubplot(0.766379,0.587931;0.133621x0.132759)
# RA        AxesSubplot(0.125,0.428621;0.133621x0.132759)
# ER     AxesSubplot(0.285345,0.428621;0.133621x0.132759)
# ERA     AxesSubplot(0.44569,0.428621;0.133621x0.132759)
# CG     AxesSubplot(0.606034,0.428621;0.133621x0.132759)
# SHO    AxesSubplot(0.766379,0.428621;0.133621x0.132759)
# SV         AxesSubplot(0.125,0.26931;0.133621x0.132759)
# E       AxesSubplot(0.285345,0.26931;0.133621x0.132759)
# dtype: object

# %%
sns.distplot(df['W'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
sns.distplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
sns.distplot(df['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %%
sns.distplot(df['SV'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %%
sns.distplot(df['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %%
sns.distplot(df['SO'])
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %%
sns.boxplot(df['W'])
# Out:
# <AxesSubplot:xlabel='W'>

# %%
sns.boxplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R'>

# %%
sns.boxplot(df['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO'>

# %%
sns.boxplot(df['SV'])
# Out:
# <AxesSubplot:xlabel='SV'>

# %%
sns.boxplot(df['E'])
# Out:
# <AxesSubplot:xlabel='E'>

# %%
sns.boxplot(df['HR'])
# Out:
# <AxesSubplot:xlabel='HR'>

# %%
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='h')  #Outliers present in all columns
    plt.tight_layout()

# %%
#sns.pairplot(df)
#plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor  
X = df[[ 'W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER','ERA', 'CG', 'SHO', 'SV', 'E']]
  
# VIF dataframe                                       # to find multi colinearity
vif_df = pd.DataFrame()
vif_df["feature"] = X.columns
  
# calculating VIF for each feature
vif_df["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]                
print(vif_df)
# Out:
#    feature           VIF
# 0        W   1222.978702
# 1        R   2969.866481
# 2       AB   6415.739490
# 3        H   4335.428971
# 4       2B   1145.958470
# 5       3B     33.571354
# 6       HR    268.072094
# 7       BB    332.719183
# 8       SO    453.836620
# 9       SB     28.221722
# 10      RA  18807.334723
# 11      ER  16491.346021
# 12     ERA    111.022507
# 13      CG     10.796027
# 14     SHO     33.454001
# 15      SV    342.105176
# 16       E     91.265978

# %%
df=df.drop(['RA','ER'],axis=1)

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB  ERA  CG  SHO  SV    E
# 0    95  724  5575  1497  300  42  139  383   973  104    9   2    8  56   88
# 1    83  696  5467  1349  277  44  156  439  1264   70   18   2   12  45   86
# 2    81  669  5439  1395  303  29  141  533  1157   86    7  11   10  38   79
# 3    76  622  5533  1381  260  27  136  404  1231   68   13   7    9  37  101
# 4    74  689  5605  1515  289  49  151  455  1259   83   27   7   12  35   86
# 5    93  891  5509  1480  308  17  232  570  1151   88   11   7   10  34   88
# 6    87  764  5567  1397  272  19  212  554  1227   63   15   3    4  48   93
# 7    81  713  5485  1370  246  20  217  418  1331   44   17   0   10  43   77
# 8    80  644  5485  1383  278  32  167  436  1310   87   10   1   12  60   95
# 9    78  748  5640  1495  294  33  161  478  1148   71   24   3   10  40   97
# 10   88  751  5511  1419  279  32  172  503  1233  101   22   5    9  45  119
# 11   86  729  5459  1363  278  26  230  486  1392  121    5   5   13  39   85
# 12   85  661  5417  1331  243  21  176  435  1150   52   12   2   12  46   93
# 13   76  656  5544  1379  262  22  198  478  1336   69   21   6   12  45   94
# 14   68  694  5600  1405  277  46  146  475  1119   78   20   5   15  28  126
# 15  100  647  5484  1386  288  39  137  506  1267   69    0   1   15  62   96
# 16   98  697  5631  1462  292  27  140  461  1322   98    1   0   13  54  122
# 17   97  689  5491  1341  272  30  171  567  1518   95    2   6   21  48  111
# 18   68  655  5480  1378  274  34  145  412  1299   84   23   1    7  40  116
# 19   64  640  5571  1382  257  27  167  496  1255  134   25   2    8  35   90
# 20   90  683  5527  1351  295  17  177  488  1290   51    3   1   14  50   88
# 21   83  703  5428  1363  265  13  177  539  1344   57    6   4   13  41   90
# 22   71  613  5463  1420  236  40  120  375  1150  112   14   0   12  35   77
# 23   67  573  5420  1361  251  18  100  471  1107   69   26   3   10  44   90
# 24   63  626  5529  1374  272  37  130  387  1274   88   28   1    7  35  117
# 25   92  667  5385  1346  263  26  187  563  1258   59    4   6   21  47   75
# 26   84  696  5565  1486  288  39  136  457  1159   93    8   7   18  41   78
# 27   79  720  5649  1494  289  48  154  490  1312  132   16   1   12  44   86
# 28   74  650  5457  1324  260  36  148  426  1327   82   19   1    6  41   92
# 29   68  737  5572  1479  274  49  186  388  1283   97   29   4    4  36   95

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# ERA    0.000000
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
df.skew().sort_values()
# Out:
# 2B    -0.230650
# SO    -0.156065
# ERA    0.000000
# W      0.047089
# 3B     0.129502
# BB     0.158498
# AB     0.183437
# SB     0.479893
# HR     0.516441
# SHO    0.565790
# SV     0.657524
# H      0.670254
# CG     0.736845
# E      0.890132
# R      1.200786
# dtype: float64

# %%
df=df.drop(['ERA'],axis=1)

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB  CG  SHO  SV    E
# 0    95  724  5575  1497  300  42  139  383   973  104   2    8  56   88
# 1    83  696  5467  1349  277  44  156  439  1264   70   2   12  45   86
# 2    81  669  5439  1395  303  29  141  533  1157   86  11   10  38   79
# 3    76  622  5533  1381  260  27  136  404  1231   68   7    9  37  101
# 4    74  689  5605  1515  289  49  151  455  1259   83   7   12  35   86
# 5    93  891  5509  1480  308  17  232  570  1151   88   7   10  34   88
# 6    87  764  5567  1397  272  19  212  554  1227   63   3    4  48   93
# 7    81  713  5485  1370  246  20  217  418  1331   44   0   10  43   77
# 8    80  644  5485  1383  278  32  167  436  1310   87   1   12  60   95
# 9    78  748  5640  1495  294  33  161  478  1148   71   3   10  40   97
# 10   88  751  5511  1419  279  32  172  503  1233  101   5    9  45  119
# 11   86  729  5459  1363  278  26  230  486  1392  121   5   13  39   85
# 12   85  661  5417  1331  243  21  176  435  1150   52   2   12  46   93
# 13   76  656  5544  1379  262  22  198  478  1336   69   6   12  45   94
# 14   68  694  5600  1405  277  46  146  475  1119   78   5   15  28  126
# 15  100  647  5484  1386  288  39  137  506  1267   69   1   15  62   96
# 16   98  697  5631  1462  292  27  140  461  1322   98   0   13  54  122
# 17   97  689  5491  1341  272  30  171  567  1518   95   6   21  48  111
# 18   68  655  5480  1378  274  34  145  412  1299   84   1    7  40  116
# 19   64  640  5571  1382  257  27  167  496  1255  134   2    8  35   90
# 20   90  683  5527  1351  295  17  177  488  1290   51   1   14  50   88
# 21   83  703  5428  1363  265  13  177  539  1344   57   4   13  41   90
# 22   71  613  5463  1420  236  40  120  375  1150  112   0   12  35   77
# 23   67  573  5420  1361  251  18  100  471  1107   69   3   10  44   90
# 24   63  626  5529  1374  272  37  130  387  1274   88   1    7  35  117
# 25   92  667  5385  1346  263  26  187  563  1258   59   6   21  47   75
# 26   84  696  5565  1486  288  39  136  457  1159   93   7   18  41   78
# 27   79  720  5649  1494  289  48  154  490  1312  132   1   12  44   86
# 28   74  650  5457  1324  260  36  148  426  1327   82   1    6  41   92
# 29   68  737  5572  1479  274  49  186  388  1283   97   4    4  36   95

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z.shape
# Out:
# (30, 14)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 1

# %%
df_new=df[(z<3).all(axis=1)]
print('Old Dataframe',df.shape)
print('New DataFrame',df_new.shape)
# Out:
# Old Dataframe (30, 14)
# New DataFrame (29, 14)

# %%
dataloss=(30-29)/30*100
print('dataloss=',dataloss,' %')
# Out:
# dataloss= 3.3333333333333335  %

# %%
x=df_new.drop(['W'],axis=1)
y=df_new['W']

# %%
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB  CG  SHO  SV    E
# 0   724  5575  1497  300  42  139  383   973  104   2    8  56   88
# 1   696  5467  1349  277  44  156  439  1264   70   2   12  45   86
# 2   669  5439  1395  303  29  141  533  1157   86  11   10  38   79
# 3   622  5533  1381  260  27  136  404  1231   68   7    9  37  101
# 4   689  5605  1515  289  49  151  455  1259   83   7   12  35   86
# 6   764  5567  1397  272  19  212  554  1227   63   3    4  48   93
# 7   713  5485  1370  246  20  217  418  1331   44   0   10  43   77
# 8   644  5485  1383  278  32  167  436  1310   87   1   12  60   95
# 9   748  5640  1495  294  33  161  478  1148   71   3   10  40   97
# 10  751  5511  1419  279  32  172  503  1233  101   5    9  45  119
# 11  729  5459  1363  278  26  230  486  1392  121   5   13  39   85
# 12  661  5417  1331  243  21  176  435  1150   52   2   12  46   93
# 13  656  5544  1379  262  22  198  478  1336   69   6   12  45   94
# 14  694  5600  1405  277  46  146  475  1119   78   5   15  28  126
# 15  647  5484  1386  288  39  137  506  1267   69   1   15  62   96
# 16  697  5631  1462  292  27  140  461  1322   98   0   13  54  122
# 17  689  5491  1341  272  30  171  567  1518   95   6   21  48  111
# 18  655  5480  1378  274  34  145  412  1299   84   1    7  40  116
# 19  640  5571  1382  257  27  167  496  1255  134   2    8  35   90
# 20  683  5527  1351  295  17  177  488  1290   51   1   14  50   88
# 21  703  5428  1363  265  13  177  539  1344   57   4   13  41   90
# 22  613  5463  1420  236  40  120  375  1150  112   0   12  35   77
# 23  573  5420  1361  251  18  100  471  1107   69   3   10  44   90
# 24  626  5529  1374  272  37  130  387  1274   88   1    7  35  117
# 25  667  5385  1346  263  26  187  563  1258   59   6   21  47   75
# 26  696  5565  1486  288  39  136  457  1159   93   7   18  41   78
# 27  720  5649  1494  289  48  154  490  1312  132   1   12  44   86
# 28  650  5457  1324  260  36  148  426  1327   82   1    6  41   92
# 29  737  5572  1479  274  49  186  388  1283   97   4    4  36   95

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 9.62543504e-01,  0.00000000e+00,  0.00000000e+00,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -3.07098204e-01, -7.87002186e-01,  1.53275292e+00,
#         -3.48265262e-01],
#        [ 2.98863300e-01,  0.00000000e+00,  0.00000000e+00,
#          1.38197902e-01,  1.18522654e+00, -1.09958425e-01,
#         -4.62095966e-01,  9.36832915e-02, -5.16377335e-01,
#         -3.07098204e-01,  2.36736538e-01,  3.12020186e-01,
#         -5.40819806e-01],
#        [-3.12105130e-01,  0.00000000e+00,  0.00000000e+00,
#          1.90738550e+00, -2.28819392e-01, -6.64354121e-01,
#          1.23209786e+00, -9.35611465e-01,  2.25038365e-01,
#          2.01131531e+00, -2.52844176e-01, -6.64136739e-01,
#         -1.32612477e+00],
#        [-1.30829774e+00,  0.00000000e+00,  0.00000000e+00,
#         -8.37664770e-01, -4.32227907e-01, -8.60039342e-01,
#         -1.16272085e+00, -2.30682707e-01, -6.18421529e-01,
#          1.26446344e+00, -5.13554932e-01, -8.20688859e-01,
#          6.50818351e-01],
#        [ 1.37737301e-01,  0.00000000e+00,  0.00000000e+00,
#          9.11434794e-01,  1.62263592e+00, -2.89646675e-01,
#         -1.55685826e-01,  4.41433307e-02,  9.50377681e-02,
#          1.26446344e+00,  2.36736538e-01, -1.14916472e+00,
#         -5.40819806e-01],
#        [ 1.96420873e+00,  0.00000000e+00,  0.00000000e+00,
#         -1.63010220e-01, -1.29582738e+00,  1.63163749e+00,
#          1.57949358e+00, -2.69582692e-01, -8.84525554e-01,
#          1.21870592e-01, -2.06403920e+00,  6.77176215e-01,
#          8.28582419e-02],
#        [ 6.98145564e-01,  0.00000000e+00,  0.00000000e+00,
#         -1.54263548e+00, -1.18275843e+00,  1.76773356e+00,
#         -8.77216697e-01,  7.70980104e-01, -2.08284252e+00,
#         -1.73289617e+00, -2.52844176e-01,  5.23253489e-02,
#         -1.58819729e+00],
#        [-8.52595277e-01,  0.00000000e+00,  0.00000000e+00,
#          1.99896614e-01,  6.87034881e-02,  2.69125303e-01,
#         -5.20475583e-01,  5.56007529e-01,  2.67558365e-01,
#         -8.70681710e-01,  2.36736538e-01,  1.90813725e+00,
#          2.37592499e-01],
#        [ 1.55595108e+00,  0.00000000e+00,  0.00000000e+00,
#          1.25525640e+00,  1.66016920e-01,  6.50138601e-02,
#          2.70943885e-01, -1.01920973e+00, -4.66233050e-01,
#          1.21870592e-01, -2.52844176e-01, -3.65006331e-01,
#          3.83385575e-01],
#        [ 1.63172674e+00,  0.00000000e+00,  0.00000000e+00,
#          2.62085981e-01,  6.87034881e-02,  4.34619901e-01,
#          7.17575787e-01, -2.11198815e-01,  8.24915052e-01,
#          7.70648979e-01, -5.13554932e-01,  3.12020186e-01,
#          1.55426515e+00],
#        [ 1.08429715e+00,  0.00000000e+00,  0.00000000e+00,
#          1.99896614e-01, -5.35589865e-01,  2.10976140e+00,
#          4.15731318e-01,  1.40920289e+00,  1.52141342e+00,
#          7.70648979e-01,  4.68029391e-01, -5.12328248e-01,
#         -6.41925514e-01],
#        [-4.87692420e-01,  0.00000000e+00,  0.00000000e+00,
#         -1.68270914e+00, -1.07132315e+00,  5.64164281e-01,
#         -5.40002291e-01, -1.00067264e+00, -1.53576005e+00,
#         -3.07098204e-01,  2.36736538e-01,  4.36837705e-01,
#          8.28582419e-02],
#        [-5.96175935e-01,  0.00000000e+00,  0.00000000e+00,
#         -7.29846682e-01, -9.61425202e-01,  1.23584791e+00,
#          2.70943885e-01,  8.22523572e-01, -5.67101779e-01,
#          1.03166276e+00,  2.36736538e-01,  3.12020186e-01,
#          1.61388488e-01],
#        [ 2.52632115e-01,  0.00000000e+00,  0.00000000e+00,
#          1.38197902e-01,  1.36188686e+00, -4.74339591e-01,
#          2.16180612e-01, -1.28540143e+00, -1.30311671e-01,
#          7.70648979e-01,  9.08147185e-01, -2.49883997e+00,
#          1.81055287e+00],
#        [-7.89011402e-01,  0.00000000e+00,  0.00000000e+00,
#          8.44221534e-01,  7.32678154e-01, -8.20430695e-01,
#          7.70046367e-01,  1.23474558e-01, -5.67101779e-01,
#         -8.70681710e-01,  9.08147185e-01,  2.08491727e+00,
#          3.11562350e-01],
#        [ 3.22037487e-01,  0.00000000e+00,  0.00000000e+00,
#          1.11616810e+00, -4.32227907e-01, -7.03025726e-01,
#         -4.28617534e-02,  6.78550021e-01,  7.10994061e-01,
#         -1.73289617e+00,  4.68029391e-01,  1.33300631e+00,
#          1.66920917e+00],
#        [ 1.37737301e-01,  0.00000000e+00,  0.00000000e+00,
#         -1.63010220e-01, -1.28676161e-01,  4.01843420e-01,
#          1.78963187e+00,  2.79148702e+00,  5.94217890e-01,
#          1.03166276e+00,  2.09085582e+00,  6.77176215e-01,
#          1.20371501e+00],
#        [-6.17756609e-01,  0.00000000e+00,  0.00000000e+00,
#         -4.39755655e-02,  2.62459743e-01, -5.11906087e-01,
#         -9.98685266e-01,  4.44378919e-01,  1.38786720e-01,
#         -8.70681710e-01, -1.07533963e+00, -3.65006331e-01,
#          1.43081026e+00],
#        [-9.36834306e-01,  0.00000000e+00,  0.00000000e+00,
#         -9.96002506e-01, -4.32227907e-01,  2.69125303e-01,
#          5.94226550e-01,  4.61238853e-03,  1.92552808e+00,
#         -3.07098204e-01, -7.87002186e-01, -1.14916472e+00,
#         -1.67684998e-01],
#        [ 1.15032665e-03,  0.00000000e+00,  0.00000000e+00,
#          1.32558682e+00, -1.52730964e+00,  5.96168091e-01,
#          4.51648972e-01,  3.53547035e-01, -1.60029335e+00,
#         -8.70681710e-01,  6.91582693e-01,  9.06023678e-01,
#         -3.48265262e-01],
#        [ 4.61903563e-01,  0.00000000e+00,  0.00000000e+00,
#         -5.64688157e-01, -2.01564882e+00,  5.96168091e-01,
#          1.33238489e+00,  9.05280039e-01, -1.22726215e+00,
#          4.72300348e-01,  4.68029391e-01, -2.21933710e-01,
#         -1.67684998e-01],
#        [-1.48937178e+00,  0.00000000e+00,  0.00000000e+00,
#         -1.99504220e+00,  8.24510284e-01, -1.52911231e+00,
#         -1.77854272e+00, -1.00067264e+00,  1.22050964e+00,
#         -1.73289617e+00,  2.36736538e-01, -1.14916472e+00,
#         -1.58819729e+00],
#        [-2.25681725e+00,  0.00000000e+00,  0.00000000e+00,
#         -1.30068346e+00, -1.41063754e+00, -2.47829793e+00,
#          1.42758514e-01, -1.39412379e+00, -5.67101779e-01,
#          1.21870592e-01, -2.52844176e-01,  1.83903886e-01,
#         -1.67684998e-01],
#        [-1.22682499e+00,  0.00000000e+00,  0.00000000e+00,
#         -1.63010220e-01,  5.46877831e-01, -1.10289298e+00,
#         -1.51954034e+00,  1.93183556e-01,  3.09685564e-01,
#         -8.70681710e-01, -1.07533963e+00, -1.14916472e+00,
#          1.47295923e+00],
#        [-3.56234524e-01,  0.00000000e+00,  0.00000000e+00,
#         -6.75253462e-01, -5.35589865e-01,  9.08214214e-01,
#          1.72536184e+00,  3.42521724e-02, -1.10992538e+00,
#          1.03166276e+00,  2.09085582e+00,  5.58508906e-01,
#         -1.87019087e+00],
#        [ 2.98863300e-01,  0.00000000e+00,  0.00000000e+00,
#          8.44221534e-01,  7.32678154e-01, -8.60039342e-01,
#         -1.17954659e-01, -9.16970789e-01,  5.14700397e-01,
#          1.26446344e+00,  1.52182832e+00, -2.21933710e-01,
#         -1.45479212e+00],
#        [ 8.65848732e-01,  0.00000000e+00,  0.00000000e+00,
#          9.11434794e-01,  1.53626470e+00, -1.81252234e-01,
#          4.87456542e-01,  5.76375836e-01,  1.86548585e+00,
#         -8.70681710e-01,  2.36736538e-01,  1.83903886e-01,
#         -5.40819806e-01],
#        [-7.25080407e-01,  0.00000000e+00,  0.00000000e+00,
#         -8.37664770e-01,  4.52860860e-01, -3.99842255e-01,
#         -7.17272959e-01,  7.29844768e-01,  5.08613716e-02,
#         -8.70681710e-01, -1.38141238e+00, -2.21933710e-01,
#          1.90485434e-03],
#        [ 1.28115156e+00,  0.00000000e+00,  0.00000000e+00,
#         -4.39755655e-02,  1.62263592e+00,  8.77641898e-01,
#         -1.49822954e+00,  2.83212126e-01,  6.72393731e-01,
#          4.72300348e-01, -2.06403920e+00, -9.82263658e-01,
#          2.37592499e-01]])

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f'for random state {i},the training accuracy is',{r2_score(y_train,pred_train)})
    print(f'for random state {i} ,the testing accuracy is',{r2_score(y_test, pred_test)})
    print('\n')
# Out:
# for random state 0,the training accuracy is {0.8386083625003391}
# for random state 0 ,the testing accuracy is {0.7629568834270759}
#
#
# for random state 1,the training accuracy is {0.847376306373865}
# for random state 1 ,the testing accuracy is {0.6404307393224445}
#
#
# for random state 2,the training accuracy is {0.8495519367933648}
# for random state 2 ,the testing accuracy is {-1.251929220920399}
#
#
# for random state 3,the training accuracy is {0.833913373813791}
# for random state 3 ,the testing accuracy is {0.7256417771694266}
#
#
# for random state 4,the training accuracy is {0.861473065072064}
# for random state 4 ,the testing accuracy is {0.43597007798006193}
#
#
# for random state 5,the training accuracy is {0.8735090477115974}
# for random state 5 ,the testing accuracy is {0.21293323794350094}
#
#
# for random state 6,the training accuracy is {0.8501338894126035}
# for random state 6 ,the testing accuracy is {0.6672241189965572}
#
#
# for random state 7,the training accuracy is {0.8611027586957942}
# for random state 7 ,the testing accuracy is {0.14872867110177923}
#
#
# for random state 8,the training accuracy is {0.844586889547596}
# for random state 8 ,the testing accuracy is {0.7590669187173772}
#
#
# for random state 9,the training accuracy is {0.9020047864780902}
# for random state 9 ,the testing accuracy is {0.058913693442308346}
#
#
# for random state 10,the training accuracy is {0.9277666056872556}
# for random state 10 ,the testing accuracy is {-0.9448645954989427}
#
#
# for random state 11,the training accuracy is {0.9362848152266497}
# for random state 11 ,the testing accuracy is {-1.6726965189098313}
#
#
# for random state 12,the training accuracy is {0.8930787899565609}
# for random state 12 ,the testing accuracy is {0.09616919912529898}
#
#
# for random state 13,the training accuracy is {0.8660755626744367}
# for random state 13 ,the testing accuracy is {0.4954117378142555}
#
#
# for random state 14,the training accuracy is {0.8757673061835657}
# for random state 14 ,the testing accuracy is {-0.05472217512899924}
#
#
# for random state 15,the training accuracy is {0.8359920040224714}
# for random state 15 ,the testing accuracy is {0.6769925955984619}
#
#
# for random state 16,the training accuracy is {0.9148984587878023}
# for random state 16 ,the testing accuracy is {-0.44413845915221195}
#
#
# for random state 17,the training accuracy is {0.8533101842806528}
# for random state 17 ,the testing accuracy is {0.3051644514979307}
#
#
# for random state 18,the training accuracy is {0.8475351369820743}
# for random state 18 ,the testing accuracy is {0.5043232528346908}
#
#
# for random state 19,the training accuracy is {0.8155180103672891}
# for random state 19 ,the testing accuracy is {0.6868890844320703}
#
#
# for random state 20,the training accuracy is {0.836512206905391}
# for random state 20 ,the testing accuracy is {0.6871178320137423}
#
#
# for random state 21,the training accuracy is {0.8932430677445975}
# for random state 21 ,the testing accuracy is {0.0989565585399903}
#
#
# for random state 22,the training accuracy is {0.8277482313475923}
# for random state 22 ,the testing accuracy is {0.5600466245116515}
#
#
# for random state 23,the training accuracy is {0.8279851985733324}
# for random state 23 ,the testing accuracy is {0.6977517996420216}
#
#
# for random state 24,the training accuracy is {0.8743827659106754}
# for random state 24 ,the testing accuracy is {-0.5189173759159345}
#
#
# for random state 25,the training accuracy is {0.8576551046852986}
# for random state 25 ,the testing accuracy is {-0.23939732315913265}
#
#
# for random state 26,the training accuracy is {0.860655165758342}
# for random state 26 ,the testing accuracy is {0.5946897945018034}
#
#
# for random state 27,the training accuracy is {0.9224687149044164}
# for random state 27 ,the testing accuracy is {0.18947558864319447}
#
#
# for random state 28,the training accuracy is {0.8314656777248476}
# for random state 28 ,the testing accuracy is {0.8336603814512916}
#
#
# for random state 29,the training accuracy is {0.8975875238590593}
# for random state 29 ,the testing accuracy is {0.26847431971614333}
#
#
# for random state 30,the training accuracy is {0.8386061725943181}
# for random state 30 ,the testing accuracy is {0.6669965768861343}
#
#
# for random state 31,the training accuracy is {0.8961505347863205}
# for random state 31 ,the testing accuracy is {-0.483207607083175}
#
#
# for random state 32,the training accuracy is {0.8236370290602185}
# for random state 32 ,the testing accuracy is {0.5962524900119655}
#
#
# for random state 33,the training accuracy is {0.848819070798692}
# for random state 33 ,the testing accuracy is {0.44133331612965565}
#
#
# for random state 34,the training accuracy is {0.9055888112061558}
# for random state 34 ,the testing accuracy is {-0.13307230949585702}
#
#
# for random state 35,the training accuracy is {0.8548300079115351}
# for random state 35 ,the testing accuracy is {0.693629736319559}
#
#
# for random state 36,the training accuracy is {0.8768052946034285}
# for random state 36 ,the testing accuracy is {-0.7149260075083108}
#
#
# for random state 37,the training accuracy is {0.8950059280300569}
# for random state 37 ,the testing accuracy is {-0.5638773236419872}
#
#
# for random state 38,the training accuracy is {0.8557525274696136}
# for random state 38 ,the testing accuracy is {0.42304375355866763}
#
#
# for random state 39,the training accuracy is {0.9240051435616896}
# for random state 39 ,the testing accuracy is {-0.455194242017845}
#
#
# for random state 40,the training accuracy is {0.8637560725592917}
# for random state 40 ,the testing accuracy is {0.03002597784421479}
#
#
# for random state 41,the training accuracy is {0.9257726210977245}
# for random state 41 ,the testing accuracy is {-0.7168163828384739}
#
#
# for random state 42,the training accuracy is {0.8937036099541643}
# for random state 42 ,the testing accuracy is {0.39171033171349656}
#
#
# for random state 43,the training accuracy is {0.913029104407025}
# for random state 43 ,the testing accuracy is {-0.7859474001898892}
#
#
# for random state 44,the training accuracy is {0.9073535771396086}
# for random state 44 ,the testing accuracy is {-0.11510673998765308}
#
#
# for random state 45,the training accuracy is {0.8966294857572106}
# for random state 45 ,the testing accuracy is {0.06385109658733301}
#
#
# for random state 46,the training accuracy is {0.8556902566097951}
# for random state 46 ,the testing accuracy is {0.6751995659931902}
#
#
# for random state 47,the training accuracy is {0.8713832576787021}
# for random state 47 ,the testing accuracy is {0.42512206043021283}
#
#
# for random state 48,the training accuracy is {0.8909482370000086}
# for random state 48 ,the testing accuracy is {0.20625194245190182}
#
#
# for random state 49,the training accuracy is {0.8808332103605726}
# for random state 49 ,the testing accuracy is {-1.237336025261095}
#
#
# for random state 50,the training accuracy is {0.8276028585515531}
# for random state 50 ,the testing accuracy is {0.6708985532313245}
#
#
# for random state 51,the training accuracy is {0.9388200381355434}
# for random state 51 ,the testing accuracy is {0.15172089869815175}
#
#
# for random state 52,the training accuracy is {0.9210598769434177}
# for random state 52 ,the testing accuracy is {-0.3948786066133305}
#
#
# for random state 53,the training accuracy is {0.8472507842951509}
# for random state 53 ,the testing accuracy is {0.5065044495466409}
#
#
# for random state 54,the training accuracy is {0.8817143752558432}
# for random state 54 ,the testing accuracy is {-0.2996705810404341}
#
#
# for random state 55,the training accuracy is {0.8784822949045122}
# for random state 55 ,the testing accuracy is {-0.2914767316727702}
#
#
# for random state 56,the training accuracy is {0.89007940907565}
# for random state 56 ,the testing accuracy is {0.12027269421012787}
#
#
# for random state 57,the training accuracy is {0.8781371353866702}
# for random state 57 ,the testing accuracy is {0.6088118221449512}
#
#
# for random state 58,the training accuracy is {0.8669881926311225}
# for random state 58 ,the testing accuracy is {0.22676627442238662}
#
#
# for random state 59,the training accuracy is {0.885273921610988}
# for random state 59 ,the testing accuracy is {0.28617302228892105}
#
#
# for random state 60,the training accuracy is {0.8635774919540772}
# for random state 60 ,the testing accuracy is {0.5513701996641236}
#
#
# for random state 61,the training accuracy is {0.9182696635457749}
# for random state 61 ,the testing accuracy is {0.3306429832517799}
#
#
# for random state 62,the training accuracy is {0.9121994922425184}
# for random state 62 ,the testing accuracy is {-0.2804801646826214}
#
#
# for random state 63,the training accuracy is {0.9187511009571199}
# for random state 63 ,the testing accuracy is {0.12820525504531277}
#
#
# for random state 64,the training accuracy is {0.8792759373184384}
# for random state 64 ,the testing accuracy is {0.4333344864780083}
#
#
# for random state 65,the training accuracy is {0.8264620999489425}
# for random state 65 ,the testing accuracy is {0.7734981973043598}
#
#
# for random state 66,the training accuracy is {0.8386202610034562}
# for random state 66 ,the testing accuracy is {0.7794389105460618}
#
#
# for random state 67,the training accuracy is {0.8031811178547371}
# for random state 67 ,the testing accuracy is {0.833163205505691}
#
#
# for random state 68,the training accuracy is {0.8571606826757827}
# for random state 68 ,the testing accuracy is {0.47877866560671833}
#
#
# for random state 69,the training accuracy is {0.8725829160259885}
# for random state 69 ,the testing accuracy is {0.025301836462375937}
#
#
# for random state 70,the training accuracy is {0.8493146112548997}
# for random state 70 ,the testing accuracy is {0.5184777022572159}
#
#
# for random state 71,the training accuracy is {0.9502891613861447}
# for random state 71 ,the testing accuracy is {-5.886873404399896}
#
#
# for random state 72,the training accuracy is {0.9010793559513702}
# for random state 72 ,the testing accuracy is {-1.2343451304828452}
#
#
# for random state 73,the training accuracy is {0.8297929291342828}
# for random state 73 ,the testing accuracy is {0.731301696139633}
#
#
# for random state 74,the training accuracy is {0.8629159216424309}
# for random state 74 ,the testing accuracy is {-0.16947305127255174}
#
#
# for random state 75,the training accuracy is {0.8495053922248358}
# for random state 75 ,the testing accuracy is {0.7364389302262166}
#
#
# for random state 76,the training accuracy is {0.7873266601721007}
# for random state 76 ,the testing accuracy is {0.9034151414651963}
#
#
# for random state 77,the training accuracy is {0.8858359250184861}
# for random state 77 ,the testing accuracy is {0.13374601562341482}
#
#
# for random state 78,the training accuracy is {0.8475676582812829}
# for random state 78 ,the testing accuracy is {0.47466756050306613}
#
#
# for random state 79,the training accuracy is {0.9006900469863965}
# for random state 79 ,the testing accuracy is {0.517940178538369}
#
#
# for random state 80,the training accuracy is {0.8709870549656857}
# for random state 80 ,the testing accuracy is {0.39492041547788537}
#
#
# for random state 81,the training accuracy is {0.8849551042462152}
# for random state 81 ,the testing accuracy is {0.2959988532248986}
# for random state 82,the training accuracy is {0.8807517279109858}
# for random state 82 ,the testing accuracy is {-0.12441707844433347}
#
#
# for random state 83,the training accuracy is {0.8698765485215498}
# for random state 83 ,the testing accuracy is {0.3758047558626497}
#
#
# for random state 84,the training accuracy is {0.88332707372149}
# for random state 84 ,the testing accuracy is {-0.20036153582363858}
#
#
# for random state 85,the training accuracy is {0.8724624796481468}
# for random state 85 ,the testing accuracy is {0.5665156711548183}
#
#
# for random state 86,the training accuracy is {0.8486330156306368}
# for random state 86 ,the testing accuracy is {0.35691626167238844}
#
#
# for random state 87,the training accuracy is {0.8725377427704195}
# for random state 87 ,the testing accuracy is {-0.43220869512552973}
#
#
# for random state 88,the training accuracy is {0.9324616392375401}
# for random state 88 ,the testing accuracy is {-2.6063363636336576}
#
#
# for random state 89,the training accuracy is {0.8776034257213321}
# for random state 89 ,the testing accuracy is {0.34479920246430484}
#
#
# for random state 90,the training accuracy is {0.8515104779505144}
# for random state 90 ,the testing accuracy is {0.5512032484307674}
#
#
# for random state 91,the training accuracy is {0.9133000193183486}
# for random state 91 ,the testing accuracy is {0.05067662932486683}
#
#
# for random state 92,the training accuracy is {0.9190234092205756}
# for random state 92 ,the testing accuracy is {-0.39127507834076325}
#
#
# for random state 93,the training accuracy is {0.926555109828685}
# for random state 93 ,the testing accuracy is {-2.3092934615818574}
#
#
# for random state 94,the training accuracy is {0.8658756350775535}
# for random state 94 ,the testing accuracy is {0.37343714088686675}
#
#
# for random state 95,the training accuracy is {0.8421761641815991}
# for random state 95 ,the testing accuracy is {0.6551988236331434}
#
#
# for random state 96,the training accuracy is {0.8268147512673485}
# for random state 96 ,the testing accuracy is {0.5837300579523146}
#
#
# for random state 97,the training accuracy is {0.8245438144582204}
# for random state 97 ,the testing accuracy is {0.7421690792283381}
#
#
# for random state 98,the training accuracy is {0.8736983086087725}
# for random state 98 ,the testing accuracy is {0.26554376451786865}
#
#
# for random state 99,the training accuracy is {0.8634031327326297}
# for random state 99 ,the testing accuracy is {0.5294299375203146}

# %%
#standard scaler to fit the values
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_scaled=sc.fit_transform(x)



from sklearn.decomposition import PCA
pca = PCA(n_components=None)
pca.fit(X_scaled)

                                                                 # Get the eigenvalues
print("Eigenvalues:")
print(pca.explained_variance_)
print()

                                                                  # Get explained variances
print("Variances (Percentage):")
print(pca.explained_variance_ratio_ * 100)
print()
# Out:
# Eigenvalues:
# [2.67500385e+00 2.02468954e+00 1.53279062e+00 1.36148606e+00
#  1.21868063e+00 9.91924729e-01 5.70250513e-01 3.75100939e-01
#  3.05231560e-01 2.24721753e-01 1.12976954e-01 2.54986948e-32
#  5.40826525e-35]
#
# Variances (Percentage):
# [2.34796576e+01 1.77715696e+01 1.34539616e+01 1.19503479e+01
#  1.06968833e+01 8.70654934e+00 5.00533366e+00 3.29242204e+00
#  2.67914849e+00 1.97247933e+00 9.91647247e-01 2.23812995e-31
#  4.74706668e-34]

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_ * 100))
plt.xlabel("Number of components (Dimensions)")
plt.ylabel("Explained variance (%)")
# Out:
# Text(0, 0.5, 'Explained variance (%)')

# %%
#from the above graph we can take components = 6 as at 6 it covers 88% of data

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=6)
X_pca = pca.fit_transform(X_scaled)

                                   # Get the transformed dataset
X = pd.DataFrame(X_pca)
print(X.head())
print("\nSize: ")
print(X.shape)
# Out:
#           0         1         2         3         4         5
# 0  2.192050 -1.648496 -0.268564  1.657074 -2.594717  0.074035
# 1  0.354148 -0.236030 -0.026183  0.436067 -0.434513  0.799760
# 2 -0.259078 -1.536711  2.318512 -0.681293 -1.149373 -0.574268
# 3  1.191065  1.255686  0.662283 -1.173654  0.382560 -1.267892
# 4  0.728262 -1.602796  1.112019 -0.911947  0.008696  0.438115
#
# Size:
# (29, 6)

# %%
x=X

# %%
x
# Out:
#            0         1         2         3         4         5
# 0   2.192050 -1.648496 -0.268564  1.657074 -2.594717  0.074035
# 1   0.354148 -0.236030 -0.026183  0.436067 -0.434513  0.799760
# 2  -0.259078 -1.536711  2.318512 -0.681293 -1.149373 -0.574268
# 3   1.191065  1.255686  0.662283 -1.173654  0.382560 -1.267892
# 4   0.728262 -1.602796  1.112019 -0.911947  0.008696  0.438115
# 5  -2.270713 -0.352771 -2.008275 -0.857510 -1.712670 -1.080321
# 6  -1.589956  2.565358 -1.885774 -0.657219 -1.335289  1.548634
# 7  -0.088261  0.578947 -0.617907  1.923828  0.412570  0.474876
# 8  -0.118189 -1.501573 -0.266407 -0.073219 -1.326055 -0.849153
# 9  -0.539083 -1.839181 -0.944214 -0.230721  0.201617 -1.172320
# 10 -1.879029 -1.399749 -0.659521 -1.237622  0.841628  1.463364
# 11 -0.453257  2.337003 -0.140658 -0.299537 -0.892394 -0.476315
# 12 -1.638678  0.859116  0.007780 -0.716464  0.575155 -0.270328
# 13  1.369898 -1.353618  1.090400 -1.471822  0.727896 -1.398040
# 14 -0.286761  0.106174  0.640724  2.787007  0.171045 -0.153683
# 15  0.086540 -0.427260 -1.146364  2.607851  1.002602 -0.652464
# 16 -2.648054 -0.882365  0.607318  0.638055  3.122355  0.012820
# 17  1.529372  0.429845 -1.310623  0.214265  0.892334 -0.815563
# 18  0.706816  0.362418 -0.142154 -1.226848  1.145873  0.519466
# 19 -1.942326  0.741085 -0.104536  1.411332 -0.906241 -0.356443
# 20 -2.603566  1.003458  0.172760 -0.734410  0.121698 -0.661547
# 21  3.300568  2.067572  0.712444 -0.342935  0.184907  2.202381
# 22  1.355174  2.752818  1.969811  0.337055 -0.224057 -1.443364
# 23  2.629416  0.679578 -0.868235 -0.155276  1.169202 -0.845909
# 24 -2.727227  0.791253  2.243384 -0.208865 -0.433241  1.093808
# 25  0.366814 -1.252018  2.348943  0.031974 -0.757288  0.949097
# 26  0.535932 -1.987896 -0.302332  0.909990  0.597586  1.638683
# 27  1.240163  1.030956 -1.118320 -0.229966  0.530111  0.316754
# 28  1.457959 -1.540804 -2.076311 -1.745191 -0.321997  0.485816

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f'for random state {i},the training accuracy is',{r2_score(y_train,pred_train)})
    print(f'for random state {i} ,the testing accuracy is',{r2_score(y_test, pred_test)})
    print('\n')
# Out:
# for random state 0,the training accuracy is {0.7465266639158488}
# for random state 0 ,the testing accuracy is {0.7942292311631045}
#
#
# for random state 1,the training accuracy is {0.7421144581474035}
# for random state 1 ,the testing accuracy is {0.7209897420499738}
#
#
# for random state 2,the training accuracy is {0.7531987715576374}
# for random state 2 ,the testing accuracy is {-0.6988972438325032}
#
#
# for random state 3,the training accuracy is {0.7704435364944138}
# for random state 3 ,the testing accuracy is {0.6842849510372117}
#
#
# for random state 4,the training accuracy is {0.7882042295381466}
# for random state 4 ,the testing accuracy is {0.3663049134148386}
#
#
# for random state 5,the training accuracy is {0.8123686352994889}
# for random state 5 ,the testing accuracy is {0.2182602654072897}
#
#
# for random state 6,the training accuracy is {0.7768980609714256}
# for random state 6 ,the testing accuracy is {0.5606597429300124}
#
#
# for random state 7,the training accuracy is {0.7864888071560128}
# for random state 7 ,the testing accuracy is {0.41367128368269046}
#
#
# for random state 8,the training accuracy is {0.7728138974450818}
# for random state 8 ,the testing accuracy is {0.5977297126027797}
#
#
# for random state 9,the training accuracy is {0.8387505225275349}
# for random state 9 ,the testing accuracy is {0.04672413617756932}
#
#
# for random state 10,the training accuracy is {0.8075668385861673}
# for random state 10 ,the testing accuracy is {0.013639788392733387}
#
#
# for random state 11,the training accuracy is {0.8727783258672935}
# for random state 11 ,the testing accuracy is {-0.7238685819793282}
#
#
# for random state 12,the training accuracy is {0.8108649673618256}
# for random state 12 ,the testing accuracy is {0.31867318004607814}
#
#
# for random state 13,the training accuracy is {0.7806210233898412}
# for random state 13 ,the testing accuracy is {0.3764097119822032}
#
#
# for random state 14,the training accuracy is {0.8069814797083772}
# for random state 14 ,the testing accuracy is {0.3267169972955367}
#
#
# for random state 15,the training accuracy is {0.7397450986518075}
# for random state 15 ,the testing accuracy is {0.7482784508867176}
#
#
# for random state 16,the training accuracy is {0.8362090533939348}
# for random state 16 ,the testing accuracy is {-0.1272428527922913}
#
#
# for random state 17,the training accuracy is {0.8090313317612566}
# for random state 17 ,the testing accuracy is {0.3649841819752917}
#
#
# for random state 18,the training accuracy is {0.7903167207606532}
# for random state 18 ,the testing accuracy is {0.36089988058915956}
#
#
# for random state 19,the training accuracy is {0.733492328237484}
# for random state 19 ,the testing accuracy is {0.6153733029613915}
#
#
# for random state 20,the training accuracy is {0.7405655221622807}
# for random state 20 ,the testing accuracy is {0.8393825324975752}
#
#
# for random state 21,the training accuracy is {0.8194164799059459}
# for random state 21 ,the testing accuracy is {0.2777234722189893}
#
#
# for random state 22,the training accuracy is {0.7424939893407}
# for random state 22 ,the testing accuracy is {0.48233314065467237}
#
#
# for random state 23,the training accuracy is {0.7518385309120068}
# for random state 23 ,the testing accuracy is {0.625103703200118}
#
#
# for random state 24,the training accuracy is {0.8090295989044742}
# for random state 24 ,the testing accuracy is {-0.8059872494828291}
#
#
# for random state 25,the training accuracy is {0.7792445055486352}
# for random state 25 ,the testing accuracy is {0.37990073683949777}
#
#
# for random state 26,the training accuracy is {0.8242975593910243}
# for random state 26 ,the testing accuracy is {0.20821707415720736}
#
#
# for random state 27,the training accuracy is {0.8348637958114058}
# for random state 27 ,the testing accuracy is {0.30766256793546765}
#
#
# for random state 28,the training accuracy is {0.7495554274988767}
# for random state 28 ,the testing accuracy is {0.8080397185375089}
#
#
# for random state 29,the training accuracy is {0.8130086702307046}
# for random state 29 ,the testing accuracy is {0.5141030762398848}
#
#
# for random state 30,the training accuracy is {0.7499188803520168}
# for random state 30 ,the testing accuracy is {0.6377111247612797}
#
#
# for random state 31,the training accuracy is {0.8448704766835677}
# for random state 31 ,the testing accuracy is {-0.7028348597420899}
#
#
# for random state 32,the training accuracy is {0.7521716097948357}
# for random state 32 ,the testing accuracy is {0.6717529039485808}
#
#
# for random state 33,the training accuracy is {0.8068984420748688}
# for random state 33 ,the testing accuracy is {-0.01020464330444204}
#
#
# for random state 34,the training accuracy is {0.8033540626024797}
# for random state 34 ,the testing accuracy is {0.30480945977652507}
#
#
# for random state 35,the training accuracy is {0.7625067798358343}
# for random state 35 ,the testing accuracy is {0.6796752736080194}
#
#
# for random state 36,the training accuracy is {0.7762663627458799}
# for random state 36 ,the testing accuracy is {-0.6199593482287009}
#
#
# for random state 37,the training accuracy is {0.8254448319037302}
# for random state 37 ,the testing accuracy is {-0.35380154403317077}
#
#
# for random state 38,the training accuracy is {0.782441585129242}
# for random state 38 ,the testing accuracy is {0.10413918405116529}
#
#
# for random state 39,the training accuracy is {0.7971888935794086}
# for random state 39 ,the testing accuracy is {0.33846105190594333}
#
#
# for random state 40,the training accuracy is {0.7516417748693649}
# for random state 40 ,the testing accuracy is {-0.06524144127024933}
#
#
# for random state 41,the training accuracy is {0.7847245878184974}
# for random state 41 ,the testing accuracy is {0.405191910846632}
#
#
# for random state 42,the training accuracy is {0.8215173784485554}
# for random state 42 ,the testing accuracy is {0.2028744970406252}
#
#
# for random state 43,the training accuracy is {0.8047292023701945}
# for random state 43 ,the testing accuracy is {0.27892710967748047}
#
#
# for random state 44,the training accuracy is {0.8360255950323097}
# for random state 44 ,the testing accuracy is {-0.11347332828551959}
#
#
# for random state 45,the training accuracy is {0.8267832027923876}
# for random state 45 ,the testing accuracy is {-0.013276765714666627}
#
#
# for random state 46,the training accuracy is {0.781993694106688}
# for random state 46 ,the testing accuracy is {0.599786052784322}
#
#
# for random state 47,the training accuracy is {0.7621280839305586}
# for random state 47 ,the testing accuracy is {0.7556141536746126}
#
#
# for random state 48,the training accuracy is {0.8124264134880781}
# for random state 48 ,the testing accuracy is {0.3112952054890904}
#
#
# for random state 49,the training accuracy is {0.802142237799333}
# for random state 49 ,the testing accuracy is {-1.4745530319431248}
#
#
# for random state 50,the training accuracy is {0.7447688425525427}
# for random state 50 ,the testing accuracy is {0.5991624232396109}
#
#
# for random state 51,the training accuracy is {0.8436792801924567}
# for random state 51 ,the testing accuracy is {0.22294973811246444}
#
#
# for random state 52,the training accuracy is {0.8360498977714618}
# for random state 52 ,the testing accuracy is {-0.1942513941170414}
#
#
# for random state 53,the training accuracy is {0.7528432869675891}
# for random state 53 ,the testing accuracy is {0.687017149019209}
#
#
# for random state 54,the training accuracy is {0.8293588187046049}
# for random state 54 ,the testing accuracy is {-0.8328304445429868}
#
#
# for random state 55,the training accuracy is {0.7760291450262498}
# for random state 55 ,the testing accuracy is {0.5802955683414818}
#
#
# for random state 56,the training accuracy is {0.8182413327098146}
# for random state 56 ,the testing accuracy is {0.1957662454875324}
#
#
# for random state 57,the training accuracy is {0.7932794078631622}
# for random state 57 ,the testing accuracy is {0.6220197627774523}
#
#
# for random state 58,the training accuracy is {0.8022181714884995}
# for random state 58 ,the testing accuracy is {0.4164022005554392}
#
#
# for random state 59,the training accuracy is {0.8066313478789696}
# for random state 59 ,the testing accuracy is {0.014744618205157711}
#
#
# for random state 60,the training accuracy is {0.8098725177080034}
# for random state 60 ,the testing accuracy is {0.42123619557476355}
#
#
# for random state 61,the training accuracy is {0.81144529385137}
# for random state 61 ,the testing accuracy is {0.4365313923270673}
#
#
# for random state 62,the training accuracy is {0.8032936491309596}
# for random state 62 ,the testing accuracy is {0.1322384388429665}
#
#
# for random state 63,the training accuracy is {0.8382926378096545}
# for random state 63 ,the testing accuracy is {0.12204245826030835}
#
#
# for random state 64,the training accuracy is {0.8323428346510477}
# for random state 64 ,the testing accuracy is {0.34733274653574275}
#
#
# for random state 65,the training accuracy is {0.7671515529201653}
# for random state 65 ,the testing accuracy is {0.7034013578800686}
#
#
# for random state 66,the training accuracy is {0.7702824622496334}
# for random state 66 ,the testing accuracy is {0.6969882650205281}
#
#
# for random state 67,the training accuracy is {0.7591580432089671}
# for random state 67 ,the testing accuracy is {0.7061388610592826}
#
#
# for random state 68,the training accuracy is {0.7661038990040894}
# for random state 68 ,the testing accuracy is {0.6134307076891262}
#
#
# for random state 69,the training accuracy is {0.7017525761012349}
# for random state 69 ,the testing accuracy is {0.722540804582448}
# for random state 70,the training accuracy is {0.7911282340538811}
# for random state 70 ,the testing accuracy is {0.39649923311639157}
#
#
# for random state 71,the training accuracy is {0.8369275205633412}
# for random state 71 ,the testing accuracy is {-1.6183302910889807}
#
#
# for random state 72,the training accuracy is {0.8519504226795702}
# for random state 72 ,the testing accuracy is {-1.471871786744889}
#
#
# for random state 73,the training accuracy is {0.7907498039314677}
# for random state 73 ,the testing accuracy is {0.5566657005006271}
#
#
# for random state 74,the training accuracy is {0.8012107969794042}
# for random state 74 ,the testing accuracy is {-0.935065274763369}
#
#
# for random state 75,the training accuracy is {0.776381201388666}
# for random state 75 ,the testing accuracy is {0.6028985131911759}
#
#
# for random state 76,the training accuracy is {0.7476018120999843}
# for random state 76 ,the testing accuracy is {0.6406355176710152}
#
#
# for random state 77,the training accuracy is {0.8069783308619021}
# for random state 77 ,the testing accuracy is {0.22402133863203366}
#
#
# for random state 78,the training accuracy is {0.7665013991679245}
# for random state 78 ,the testing accuracy is {0.20475367512113485}
#
#
# for random state 79,the training accuracy is {0.8192391773157206}
# for random state 79 ,the testing accuracy is {0.5224290972309641}
#
#
# for random state 80,the training accuracy is {0.7442823506538379}
# for random state 80 ,the testing accuracy is {0.6695034189517695}
#
#
# for random state 81,the training accuracy is {0.7723563993411194}
# for random state 81 ,the testing accuracy is {0.6071055139847719}
#
#
# for random state 82,the training accuracy is {0.8112305120099785}
# for random state 82 ,the testing accuracy is {-0.08604961110239406}
#
#
# for random state 83,the training accuracy is {0.788798711004915}
# for random state 83 ,the testing accuracy is {0.5554451262016002}
#
#
# for random state 84,the training accuracy is {0.8084631474689457}
# for random state 84 ,the testing accuracy is {0.06323992838743964}
#
#
# for random state 85,the training accuracy is {0.8141406436253726}
# for random state 85 ,the testing accuracy is {0.3373099201035763}
#
#
# for random state 86,the training accuracy is {0.7622603152732749}
# for random state 86 ,the testing accuracy is {0.26319034731328406}
#
#
# for random state 87,the training accuracy is {0.7936933334343376}
# for random state 87 ,the testing accuracy is {0.041395758826049844}
#
#
# for random state 88,the training accuracy is {0.8469713340010891}
# for random state 88 ,the testing accuracy is {-0.6679533633241193}
#
#
# for random state 89,the training accuracy is {0.785650231143235}
# for random state 89 ,the testing accuracy is {0.44766950355765966}
#
#
# for random state 90,the training accuracy is {0.7471812527817698}
# for random state 90 ,the testing accuracy is {0.6771326761596963}
#
#
# for random state 91,the training accuracy is {0.8253777370297287}
# for random state 91 ,the testing accuracy is {0.2748830174713194}
#
#
# for random state 92,the training accuracy is {0.7739681414564801}
# for random state 92 ,the testing accuracy is {0.5554133847701469}
#
#
# for random state 93,the training accuracy is {0.8662132023362004}
# for random state 93 ,the testing accuracy is {-0.3298552410194213}
#
#
# for random state 94,the training accuracy is {0.779247197998204}
# for random state 94 ,the testing accuracy is {0.5198398812330018}
#
#
# for random state 95,the training accuracy is {0.7744115630574584}
# for random state 95 ,the testing accuracy is {0.6296749110192547}
#
#
# for random state 96,the training accuracy is {0.7518863231561264}
# for random state 96 ,the testing accuracy is {0.7129948121709448}
#
#
# for random state 97,the training accuracy is {0.7563153602331566}
# for random state 97 ,the testing accuracy is {0.6449470989852819}
#
#
# for random state 98,the training accuracy is {0.7974692745497873}
# for random state 98 ,the testing accuracy is {0.11530389801669128}
#
#
# for random state 99,the training accuracy is {0.7580198900550233}
# for random state 99 ,the testing accuracy is {0.6088677522718554}

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=86,test_size=0.20)

# %%
  lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.26319034731328406

# %%
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred_test))
print('Mean squared error :',mean_squared_error(y_test,pred_test))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred_test)))
# Out:
# error:
# Mean absolute error: 4.354500717011345
# Mean squared error : 28.34670469364171
# Root Mean Squared Error: 5.324162346664657

# %%
from sklearn.tree import DecisionTreeRegressor
dtc=DecisionTreeRegressor()


for i in range (0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.20)
    dtc.fit(x_train,y_train)
    pred_train=dtc.predict(x_train)
    pred_test=dtc.predict(x_test)
    print(f'for random state {i},the training accuracy is',{r2_score(y_train,pred_train)})
    print(f'for random state {i} ,the testing accuracy is',{r2_score(y_test, pred_test)})
    print('\n')
# Out:
# for random state 0,the training accuracy is {1.0}
# for random state 0 ,the testing accuracy is {0.5536253776435045}
#
#
# for random state 1,the training accuracy is {1.0}
# for random state 1 ,the testing accuracy is {0.3532219570405728}
#
#
# for random state 2,the training accuracy is {1.0}
# for random state 2 ,the testing accuracy is {-3.981949458483755}
#
#
# for random state 3,the training accuracy is {1.0}
# for random state 3 ,the testing accuracy is {0.5171632124352331}
#
#
# for random state 4,the training accuracy is {1.0}
# for random state 4 ,the testing accuracy is {0.8059654631083203}
#
#
# for random state 5,the training accuracy is {1.0}
# for random state 5 ,the testing accuracy is {0.5450676982591877}
#
#
# for random state 6,the training accuracy is {1.0}
# for random state 6 ,the testing accuracy is {-0.3650140318054256}
#
#
# for random state 7,the training accuracy is {1.0}
# for random state 7 ,the testing accuracy is {0.06343283582089554}
#
#
# for random state 8,the training accuracy is {1.0}
# for random state 8 ,the testing accuracy is {-1.6211461417871451}
#
#
# for random state 9,the training accuracy is {1.0}
# for random state 9 ,the testing accuracy is {0.7355509355509355}
#
#
# for random state 10,the training accuracy is {1.0}
# for random state 10 ,the testing accuracy is {-1.3645161290322583}
#
#
# for random state 11,the training accuracy is {1.0}
# for random state 11 ,the testing accuracy is {-0.034589571502323224}
#
#
# for random state 12,the training accuracy is {1.0}
# for random state 12 ,the testing accuracy is {-0.3271028037383177}
#
#
# for random state 13,the training accuracy is {1.0}
# for random state 13 ,the testing accuracy is {0.46060171919770765}
#
#
# for random state 14,the training accuracy is {1.0}
# for random state 14 ,the testing accuracy is {0.5}
#
#
# for random state 15,the training accuracy is {1.0}
# for random state 15 ,the testing accuracy is {0.2190669371196755}
#
#
# for random state 16,the training accuracy is {1.0}
# for random state 16 ,the testing accuracy is {-0.7347034096216722}
#
#
# for random state 17,the training accuracy is {1.0}
# for random state 17 ,the testing accuracy is {-0.6565566458519181}
#
#
# for random state 18,the training accuracy is {1.0}
# for random state 18 ,the testing accuracy is {-1.085253456221198}
#
#
# for random state 19,the training accuracy is {1.0}
# for random state 19 ,the testing accuracy is {0.6118530884808013}
#
#
# for random state 20,the training accuracy is {1.0}
# for random state 20 ,the testing accuracy is {-0.39940652818991107}
#
#
# for random state 21,the training accuracy is {1.0}
# for random state 21 ,the testing accuracy is {-0.036363636363636376}
#
#
# for random state 22,the training accuracy is {1.0}
# for random state 22 ,the testing accuracy is {0.2481040086673889}
#
#
# for random state 23,the training accuracy is {1.0}
# for random state 23 ,the testing accuracy is {0.4014778325123153}
#
#
# for random state 24,the training accuracy is {1.0}
# for random state 24 ,the testing accuracy is {-0.3872340425531915}
#
#
# for random state 25,the training accuracy is {1.0}
# for random state 25 ,the testing accuracy is {-0.46818181818181825}
#
#
# for random state 26,the training accuracy is {1.0}
# for random state 26 ,the testing accuracy is {0.360762234733651}
#
#
# for random state 27,the training accuracy is {1.0}
# for random state 27 ,the testing accuracy is {-0.03305004721435312}
#
#
# for random state 28,the training accuracy is {1.0}
# for random state 28 ,the testing accuracy is {0.3686502177068215}
#
#
# for random state 29,the training accuracy is {1.0}
# for random state 29 ,the testing accuracy is {0.7921771913289349}
#
#
# for random state 30,the training accuracy is {1.0}
# for random state 30 ,the testing accuracy is {-0.3626842513576416}
#
#
# for random state 31,the training accuracy is {1.0}
# for random state 31 ,the testing accuracy is {-3.1311475409836067}
#
#
# for random state 32,the training accuracy is {1.0}
# for random state 32 ,the testing accuracy is {-0.5993975903614457}
#
#
# for random state 33,the training accuracy is {1.0}
# for random state 33 ,the testing accuracy is {0.5987328405491024}
#
#
# for random state 34,the training accuracy is {1.0}
# for random state 34 ,the testing accuracy is {-0.5913154533844189}
#
#
# for random state 35,the training accuracy is {1.0}
# for random state 35 ,the testing accuracy is {0.3356990773598296}
#
#
# for random state 36,the training accuracy is {1.0}
# for random state 36 ,the testing accuracy is {-0.9335142469470827}
#
#
# for random state 37,the training accuracy is {1.0}
# for random state 37 ,the testing accuracy is {-2.6036923076923078}
#
#
# for random state 38,the training accuracy is {1.0}
# for random state 38 ,the testing accuracy is {-1.5090909090909093}
#
#
# for random state 39,the training accuracy is {1.0}
# for random state 39 ,the testing accuracy is {0.18380062305295952}
#
#
# for random state 40,the training accuracy is {1.0}
# for random state 40 ,the testing accuracy is {-0.2888601036269429}
#
#
# for random state 41,the training accuracy is {1.0}
# for random state 41 ,the testing accuracy is {-0.278391959798995}
#
#
# for random state 42,the training accuracy is {1.0}
# for random state 42 ,the testing accuracy is {0.7006920415224913}
#
#
# for random state 43,the training accuracy is {1.0}
# for random state 43 ,the testing accuracy is {-0.8993985784581737}
#
#
# for random state 44,the training accuracy is {1.0}
# for random state 44 ,the testing accuracy is {0.18666666666666665}
#
#
# for random state 45,the training accuracy is {1.0}
# for random state 45 ,the testing accuracy is {-0.6435018050541517}
#
#
# for random state 46,the training accuracy is {1.0}
# for random state 46 ,the testing accuracy is {0.33668341708542715}
#
#
# for random state 47,the training accuracy is {1.0}
# for random state 47 ,the testing accuracy is {-0.2900528169014085}
#
#
# for random state 48,the training accuracy is {1.0}
# for random state 48 ,the testing accuracy is {-0.22363150867823767}
#
#
# for random state 49,the training accuracy is {1.0}
# for random state 49 ,the testing accuracy is {-1.3965579060595195}
#
#
# for random state 50,the training accuracy is {1.0}
# for random state 50 ,the testing accuracy is {0.5463286713286714}
#
#
# for random state 51,the training accuracy is {1.0}
# for random state 51 ,the testing accuracy is {-0.08140703517587933}
#
#
# for random state 52,the training accuracy is {1.0}
# for random state 52 ,the testing accuracy is {-1.80812910938434}
#
#
# for random state 53,the training accuracy is {1.0}
# for random state 53 ,the testing accuracy is {0.02229199372056523}
#
#
# for random state 54,the training accuracy is {1.0}
# for random state 54 ,the testing accuracy is {-0.6654804270462633}
#
#
# for random state 55,the training accuracy is {1.0}
# for random state 55 ,the testing accuracy is {-1.7390808963159894}
#
#
# for random state 56,the training accuracy is {1.0}
# for random state 56 ,the testing accuracy is {-0.3357174787662047}
#
#
# for random state 57,the training accuracy is {1.0}
# for random state 57 ,the testing accuracy is {0.21749408983451535}
#
#
# for random state 58,the training accuracy is {1.0}
# for random state 58 ,the testing accuracy is {-0.24404015056461725}
#
#
# for random state 59,the training accuracy is {1.0}
# for random state 59 ,the testing accuracy is {-0.867012987012987}
#
#
# for random state 60,the training accuracy is {1.0}
# for random state 60 ,the testing accuracy is {-0.2601880877742948}
#
#
# for random state 61,the training accuracy is {1.0}
# for random state 61 ,the testing accuracy is {0.36300844205679206}
#
#
# for random state 62,the training accuracy is {1.0}
# for random state 62 ,the testing accuracy is {0.5423533921042545}
#
#
# for random state 63,the training accuracy is {1.0}
# for random state 63 ,the testing accuracy is {-0.06565809379727705}
#
#
# for random state 64,the training accuracy is {1.0}
# for random state 64 ,the testing accuracy is {0.0033269961977187013}
#
#
# for random state 65,the training accuracy is {1.0}
# for random state 65 ,the testing accuracy is {0.3633067440174039}
#
#
# for random state 66,the training accuracy is {1.0}
# for random state 66 ,the testing accuracy is {0.18446601941747576}
#
#
# for random state 67,the training accuracy is {1.0}
# for random state 67 ,the testing accuracy is {0.04668049792531115}
#
#
# for random state 68,the training accuracy is {1.0}
# for random state 68 ,the testing accuracy is {-1.2710843373493974}
#
#
# for random state 69,the training accuracy is {1.0}
# for random state 69 ,the testing accuracy is {0.4081958488557743}
#
#
# for random state 70,the training accuracy is {1.0}
# for random state 70 ,the testing accuracy is {0.49919354838709684}
#
#
# for random state 71,the training accuracy is {1.0}
# for random state 71 ,the testing accuracy is {-0.7488789237668161}
#
#
# for random state 72,the training accuracy is {1.0}
# for random state 72 ,the testing accuracy is {-0.146318732525629}
# for random state 73,the training accuracy is {1.0}
# for random state 73 ,the testing accuracy is {-0.19247648902821313}
#
#
# for random state 74,the training accuracy is {1.0}
# for random state 74 ,the testing accuracy is {-4.559726962457336}
#
#
# for random state 75,the training accuracy is {1.0}
# for random state 75 ,the testing accuracy is {0.4992805755395683}
#
#
# for random state 76,the training accuracy is {1.0}
# for random state 76 ,the testing accuracy is {0.5019260400616334}
#
#
# for random state 77,the training accuracy is {1.0}
# for random state 77 ,the testing accuracy is {-0.21130952380952372}
#
#
# for random state 78,the training accuracy is {1.0}
# for random state 78 ,the testing accuracy is {0.06875834445927897}
#
#
# for random state 79,the training accuracy is {1.0}
# for random state 79 ,the testing accuracy is {0.21943778601002384}
#
#
# for random state 80,the training accuracy is {1.0}
# for random state 80 ,the testing accuracy is {0.45494721335624855}
#
#
# for random state 81,the training accuracy is {1.0}
# for random state 81 ,the testing accuracy is {0.0485391140433552}
#
#
# for random state 82,the training accuracy is {1.0}
# for random state 82 ,the testing accuracy is {0.0064565134827191395}
#
#
# for random state 83,the training accuracy is {1.0}
# for random state 83 ,the testing accuracy is {0.6702649656526006}
#
#
# for random state 84,the training accuracy is {1.0}
# for random state 84 ,the testing accuracy is {0.388641425389755}
#
#
# for random state 85,the training accuracy is {1.0}
# for random state 85 ,the testing accuracy is {0.6584635138026964}
#
#
# for random state 86,the training accuracy is {1.0}
# for random state 86 ,the testing accuracy is {-3.8043321299638997}
#
#
# for random state 87,the training accuracy is {1.0}
# for random state 87 ,the testing accuracy is {-0.05140961857379778}
#
#
# for random state 88,the training accuracy is {1.0}
# for random state 88 ,the testing accuracy is {0.38899430740037955}
#
#
# for random state 89,the training accuracy is {1.0}
# for random state 89 ,the testing accuracy is {0.07377049180327866}
#
#
# for random state 90,the training accuracy is {1.0}
# for random state 90 ,the testing accuracy is {-0.2161797752808987}
#
#
# for random state 91,the training accuracy is {1.0}
# for random state 91 ,the testing accuracy is {-0.5504610017443308}
#
#
# for random state 92,the training accuracy is {1.0}
# for random state 92 ,the testing accuracy is {0.22923076923076935}
#
#
# for random state 93,the training accuracy is {1.0}
# for random state 93 ,the testing accuracy is {0.22986577181208057}
#
#
# for random state 94,the training accuracy is {1.0}
# for random state 94 ,the testing accuracy is {-0.753246753246753}
#
#
# for random state 95,the training accuracy is {1.0}
# for random state 95 ,the testing accuracy is {0.6939487975174554}
#
#
# for random state 96,the training accuracy is {1.0}
# for random state 96 ,the testing accuracy is {-0.8592493297587132}
#
#
# for random state 97,the training accuracy is {1.0}
# for random state 97 ,the testing accuracy is {0.4643116380353255}
#
#
# for random state 98,the training accuracy is {1.0}
# for random state 98 ,the testing accuracy is {-1.05045871559633}
#
#
# for random state 99,the training accuracy is {1.0}
# for random state 99 ,the testing accuracy is {0.666788055353241}

# %%
from sklearn.svm import SVR
svr=SVR()

for i in range (0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.20)
    svr.fit(x_train,y_train)
    pred_train=svr.predict(x_train)
    pred_test=svr.predict(x_test)
    print(f'for random state {i},the training accuracy is',{r2_score(y_train,pred_train)})
    print(f'for random state {i} ,the testing accuracy is',{r2_score(y_test, pred_test)})
    print('\n')
# Out:
# for random state 0,the training accuracy is {0.1833696416797651}
# for random state 0 ,the testing accuracy is {0.17633454590403752}
#
#
# for random state 1,the training accuracy is {0.20574771092854105}
# for random state 1 ,the testing accuracy is {0.11184226377224704}
#
#
# for random state 2,the training accuracy is {0.26292008440686254}
# for random state 2 ,the testing accuracy is {-3.2552472537166075}
#
#
# for random state 3,the training accuracy is {0.2348490646158763}
# for random state 3 ,the testing accuracy is {0.10956775092861304}
#
#
# for random state 4,the training accuracy is {0.22887776963224604}
# for random state 4 ,the testing accuracy is {-0.09694023598945622}
#
#
# for random state 5,the training accuracy is {0.23868961945141487}
# for random state 5 ,the testing accuracy is {0.10713272875475532}
#
#
# for random state 6,the training accuracy is {0.22446491735001162}
# for random state 6 ,the testing accuracy is {0.09410334443793467}
#
#
# for random state 7,the training accuracy is {0.22616248121596494}
# for random state 7 ,the testing accuracy is {-0.11162017455013484}
#
#
# for random state 8,the training accuracy is {0.24661506230610464}
# for random state 8 ,the testing accuracy is {0.01614669562775517}
#
#
# for random state 9,the training accuracy is {0.25235783871416484}
# for random state 9 ,the testing accuracy is {-0.19480490797767414}
#
#
# for random state 10,the training accuracy is {0.2140406668094592}
# for random state 10 ,the testing accuracy is {-0.608585268523967}
#
#
# for random state 11,the training accuracy is {0.2553849710700027}
# for random state 11 ,the testing accuracy is {-0.08023082503367207}
#
#
# for random state 12,the training accuracy is {0.26507484171940143}
# for random state 12 ,the testing accuracy is {-0.4276534637521823}
#
#
# for random state 13,the training accuracy is {0.2671033532053403}
# for random state 13 ,the testing accuracy is {-0.17978609398334178}
#
#
# for random state 14,the training accuracy is {0.20648629973818988}
# for random state 14 ,the testing accuracy is {0.17849952306078287}
#
#
# for random state 15,the training accuracy is {0.20251677867930695}
# for random state 15 ,the testing accuracy is {0.03268143217218422}
#
#
# for random state 16,the training accuracy is {0.2441030637668945}
# for random state 16 ,the testing accuracy is {0.0035990605655538133}
#
#
# for random state 17,the training accuracy is {0.2239513820546446}
# for random state 17 ,the testing accuracy is {0.054286798623455645}
#
#
# for random state 18,the training accuracy is {0.21710988317423674}
# for random state 18 ,the testing accuracy is {0.056417507373038966}
#
#
# for random state 19,the training accuracy is {0.17145081711514187}
# for random state 19 ,the testing accuracy is {-0.9505585116404578}
#
#
# for random state 20,the training accuracy is {0.2301489210235238}
# for random state 20 ,the testing accuracy is {-0.33378863842492756}
#
#
# for random state 21,the training accuracy is {0.23746236680202237}
# for random state 21 ,the testing accuracy is {0.15208899869534542}
#
#
# for random state 22,the training accuracy is {0.20147399032943503}
# for random state 22 ,the testing accuracy is {-0.4581099280770924}
#
#
# for random state 23,the training accuracy is {0.1656793670636897}
# for random state 23 ,the testing accuracy is {-0.4351935939054703}
#
#
# for random state 24,the training accuracy is {0.2372571563067043}
# for random state 24 ,the testing accuracy is {-0.6120304008419739}
#
#
# for random state 25,the training accuracy is {0.21208797640258503}
# for random state 25 ,the testing accuracy is {-0.8626156911818916}
#
#
# for random state 26,the training accuracy is {0.23212055652502017}
# for random state 26 ,the testing accuracy is {0.10806733066894392}
#
#
# for random state 27,the training accuracy is {0.28354993090738667}
# for random state 27 ,the testing accuracy is {-0.03626662775044576}
#
#
# for random state 28,the training accuracy is {0.20247976198985773}
# for random state 28 ,the testing accuracy is {0.15072201829924592}
#
#
# for random state 29,the training accuracy is {0.214885072213721}
# for random state 29 ,the testing accuracy is {0.022852305117604943}
#
#
# for random state 30,the training accuracy is {0.2254822297549639}
# for random state 30 ,the testing accuracy is {0.013876595197799602}
#
#
# for random state 31,the training accuracy is {0.27877303617246396}
# for random state 31 ,the testing accuracy is {-1.761475759925903}
#
#
# for random state 32,the training accuracy is {0.2389572685964323}
# for random state 32 ,the testing accuracy is {-0.32174825242161265}
#
#
# for random state 33,the training accuracy is {0.28352572661016207}
# for random state 33 ,the testing accuracy is {-0.5726876257272178}
#
#
# for random state 34,the training accuracy is {0.22055554142165712}
# for random state 34 ,the testing accuracy is {0.1707578051918789}
#
#
# for random state 35,the training accuracy is {0.24345463911900733}
# for random state 35 ,the testing accuracy is {0.10105776157633029}
#
#
# for random state 36,the training accuracy is {0.25557045299595793}
# for random state 36 ,the testing accuracy is {-1.4603591299706262}
#
#
# for random state 37,the training accuracy is {0.2501627437313717}
# for random state 37 ,the testing accuracy is {-0.5839795794350777}
#
#
# for random state 38,the training accuracy is {0.22710475220678528}
# for random state 38 ,the testing accuracy is {-0.351129839992806}
#
#
# for random state 39,the training accuracy is {0.22360816252351579}
# for random state 39 ,the testing accuracy is {0.08385554622564784}
#
#
# for random state 40,the training accuracy is {0.26912032544122766}
# for random state 40 ,the testing accuracy is {-0.6307876331681084}
#
#
# for random state 41,the training accuracy is {0.25617274277792557}
# for random state 41 ,the testing accuracy is {-0.26865866209052314}
#
#
# for random state 42,the training accuracy is {0.25452327954198495}
# for random state 42 ,the testing accuracy is {0.050726176771278775}
#
#
# for random state 43,the training accuracy is {0.2569692341266867}
# for random state 43 ,the testing accuracy is {0.0006421324302892106}
#
#
# for random state 44,the training accuracy is {0.2551333370206198}
# for random state 44 ,the testing accuracy is {0.10039143757031244}
#
#
# for random state 45,the training accuracy is {0.2560844080556166}
# for random state 45 ,the testing accuracy is {0.061247774856058146}
#
#
# for random state 46,the training accuracy is {0.22053385820920868}
# for random state 46 ,the testing accuracy is {0.15424019939223987}
#
#
# for random state 47,the training accuracy is {0.19784293774642348}
# for random state 47 ,the testing accuracy is {0.10081560775669562}
#
#
# for random state 48,the training accuracy is {0.24076202802699498}
# for random state 48 ,the testing accuracy is {0.06510325875641121}
#
#
# for random state 49,the training accuracy is {0.27041686018147804}
# for random state 49 ,the testing accuracy is {-1.7356687839313358}
#
#
# for random state 50,the training accuracy is {0.19665554466061752}
# for random state 50 ,the testing accuracy is {-0.9256099719024782}
#
#
# for random state 51,the training accuracy is {0.26593681912807443}
# for random state 51 ,the testing accuracy is {0.0147921717343249}
#
#
# for random state 52,the training accuracy is {0.2742896515034182}
# for random state 52 ,the testing accuracy is {-0.08798511602357229}
#
#
# for random state 53,the training accuracy is {0.249256426933944}
# for random state 53 ,the testing accuracy is {0.008893309209766831}
#
#
# for random state 54,the training accuracy is {0.2231079657684779}
# for random state 54 ,the testing accuracy is {0.1538707214583137}
#
#
# for random state 55,the training accuracy is {0.2186721483748567}
# for random state 55 ,the testing accuracy is {0.09182449514182989}
#
#
# for random state 56,the training accuracy is {0.2088628297348647}
# for random state 56 ,the testing accuracy is {-0.14076560599398036}
#
#
# for random state 57,the training accuracy is {0.20514093771662067}
# for random state 57 ,the testing accuracy is {0.1399924261540345}
#
#
# for random state 58,the training accuracy is {0.22998997642272434}
# for random state 58 ,the testing accuracy is {-0.3150093233053526}
#
#
# for random state 59,the training accuracy is {0.23786980226046373}
# for random state 59 ,the testing accuracy is {-0.7128079225970947}
#
#
# for random state 60,the training accuracy is {0.24255110892853837}
# for random state 60 ,the testing accuracy is {0.03552061433503728}
#
#
# for random state 61,the training accuracy is {0.20442780204788946}
# for random state 61 ,the testing accuracy is {0.035563942815207694}
#
#
# for random state 62,the training accuracy is {0.2730613514980422}
# for random state 62 ,the testing accuracy is {-0.5547413437744544}
#
#
# for random state 63,the training accuracy is {0.2752504724371412}
# for random state 63 ,the testing accuracy is {0.040247265014811906}
#
#
# for random state 64,the training accuracy is {0.23025493403408293}
# for random state 64 ,the testing accuracy is {0.029421587847651254}
#
#
# for random state 65,the training accuracy is {0.20704672560889448}
# for random state 65 ,the testing accuracy is {0.1338540206923633}
#
#
# for random state 66,the training accuracy is {0.22603624891555485}
# for random state 66 ,the testing accuracy is {0.1760056594030307}
#
#
# for random state 67,the training accuracy is {0.2268701425091555}
# for random state 67 ,the testing accuracy is {0.07050939707582826}
# for random state 68,the training accuracy is {0.21508193424963162}
# for random state 68 ,the testing accuracy is {0.02431384883001908}
#
#
# for random state 69,the training accuracy is {0.25037920485346443}
# for random state 69 ,the testing accuracy is {-0.18404510852855416}
#
#
# for random state 70,the training accuracy is {0.20281826026187044}
# for random state 70 ,the testing accuracy is {-0.16374542709184547}
#
#
# for random state 71,the training accuracy is {0.19782511199670638}
# for random state 71 ,the testing accuracy is {-0.285234172477973}
#
#
# for random state 72,the training accuracy is {0.20295284424750792}
# for random state 72 ,the testing accuracy is {-0.3035187689500387}
#
#
# for random state 73,the training accuracy is {0.21436168815317247}
# for random state 73 ,the testing accuracy is {0.1434841959452896}
#
#
# for random state 74,the training accuracy is {0.25940904792264485}
# for random state 74 ,the testing accuracy is {-0.7558359374346959}
#
#
# for random state 75,the training accuracy is {0.20456139629450942}
# for random state 75 ,the testing accuracy is {0.1341997177673988}
#
#
# for random state 76,the training accuracy is {0.20058935500001884}
# for random state 76 ,the testing accuracy is {0.10583993428829508}
#
#
# for random state 77,the training accuracy is {0.24358168050671847}
# for random state 77 ,the testing accuracy is {0.17707853918729455}
#
#
# for random state 78,the training accuracy is {0.2386233266553165}
# for random state 78 ,the testing accuracy is {-0.3729636433914245}
#
#
# for random state 79,the training accuracy is {0.2726470262507297}
# for random state 79 ,the testing accuracy is {-0.008047606454973488}
#
#
# for random state 80,the training accuracy is {0.20752961475590348}
# for random state 80 ,the testing accuracy is {0.1274388804641272}
#
#
# for random state 81,the training accuracy is {0.22006461674155497}
# for random state 81 ,the testing accuracy is {0.046904395008198096}
#
#
# for random state 82,the training accuracy is {0.20992950319776582}
# for random state 82 ,the testing accuracy is {-0.0008900415329349265}
#
#
# for random state 83,the training accuracy is {0.24788439247850225}
# for random state 83 ,the testing accuracy is {0.07291723568014152}
#
#
# for random state 84,the training accuracy is {0.23111509691153942}
# for random state 84 ,the testing accuracy is {-0.08023376755177192}
#
#
# for random state 85,the training accuracy is {0.2455508618261638}
# for random state 85 ,the testing accuracy is {0.10872598739790673}
#
#
# for random state 86,the training accuracy is {0.238636210733721}
# for random state 86 ,the testing accuracy is {-1.6934372505051738}
#
#
# for random state 87,the training accuracy is {0.21730804388278702}
# for random state 87 ,the testing accuracy is {-0.3391741547749052}
#
#
# for random state 88,the training accuracy is {0.17013102921404166}
# for random state 88 ,the testing accuracy is {-0.23445367477498835}
#
#
# for random state 89,the training accuracy is {0.24706761741060523}
# for random state 89 ,the testing accuracy is {-0.12297203778666366}
#
#
# for random state 90,the training accuracy is {0.21393339202785233}
# for random state 90 ,the testing accuracy is {-0.10495822108720865}
#
#
# for random state 91,the training accuracy is {0.300788564457114}
# for random state 91 ,the testing accuracy is {-0.15084054142710612}
#
#
# for random state 92,the training accuracy is {0.23708375420137595}
# for random state 92 ,the testing accuracy is {-0.10566914977471908}
#
#
# for random state 93,the training accuracy is {0.21771087113179377}
# for random state 93 ,the testing accuracy is {0.07469028051426485}
#
#
# for random state 94,the training accuracy is {0.26826852339345697}
# for random state 94 ,the testing accuracy is {-0.17124639827053212}
#
#
# for random state 95,the training accuracy is {0.25525893413889933}
# for random state 95 ,the testing accuracy is {-0.02542212217380202}
#
#
# for random state 96,the training accuracy is {0.25225850012527185}
# for random state 96 ,the testing accuracy is {-0.07251053372473848}
#
#
# for random state 97,the training accuracy is {0.2110204458611845}
# for random state 97 ,the testing accuracy is {-0.056595246054681914}
#
#
# for random state 98,the training accuracy is {0.30807906185522504}
# for random state 98 ,the testing accuracy is {-0.36203833907227834}
#
#
# for random state 99,the training accuracy is {0.218635068640203}
# for random state 99 ,the testing accuracy is {0.13056561939664435}

# %%
from sklearn.neighbors import KNeighborsRegressor
knn= KNeighborsRegressor()

for i in range (0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.20)
    knn.fit(x_train,y_train)
    pred_train=knn.predict(x_train)
    pred_test=knn.predict(x_test)
    print(f'for random state {i},the training accuracy is',{r2_score(y_train,pred_train)})
    print(f'for random state {i} ,the testing accuracy is',{r2_score(y_test, pred_test)})
    print('\n')
# Out:
# for random state 0,the training accuracy is {0.5428806011689395}
# for random state 0 ,the testing accuracy is {0.5073111782477343}
#
#
# for random state 1,the training accuracy is {0.4519754226737883}
# for random state 1 ,the testing accuracy is {0.3860143198090691}
#
#
# for random state 2,the training accuracy is {0.5994555217916164}
# for random state 2 ,the testing accuracy is {-2.3213574007220217}
#
#
# for random state 3,the training accuracy is {0.5022413567026528}
# for random state 3 ,the testing accuracy is {0.5761917098445595}
#
#
# for random state 4,the training accuracy is {0.5988980815780917}
# for random state 4 ,the testing accuracy is {0.4030518053375194}
#
#
# for random state 5,the training accuracy is {0.5839700198299331}
# for random state 5 ,the testing accuracy is {0.4371837524177947}
#
#
# for random state 6,the training accuracy is {0.5084341622334942}
# for random state 6 ,the testing accuracy is {0.348115996258185}
#
#
# for random state 7,the training accuracy is {0.6188797049847408}
# for random state 7 ,the testing accuracy is {0.09865671641791052}
#
#
# for random state 8,the training accuracy is {0.5014561558901682}
# for random state 8 ,the testing accuracy is {0.3230168960111477}
#
#
# for random state 9,the training accuracy is {0.6890498388976485}
# for random state 9 ,the testing accuracy is {-0.13912681912681912}
#
#
# for random state 10,the training accuracy is {0.581930420602025}
# for random state 10 ,the testing accuracy is {-0.07122580645161203}
#
#
# for random state 11,the training accuracy is {0.6095683194239896}
# for random state 11 ,the testing accuracy is {-0.002127000516262134}
#
#
# for random state 12,the training accuracy is {0.544636535242369}
# for random state 12 ,the testing accuracy is {-0.4519626168224302}
#
#
# for random state 13,the training accuracy is {0.6001557333333332}
# for random state 13 ,the testing accuracy is {-0.09057306590257874}
#
#
# for random state 14,the training accuracy is {0.59478775338657}
# for random state 14 ,the testing accuracy is {0.10695121951219488}
#
#
# for random state 15,the training accuracy is {0.460708819975836}
# for random state 15 ,the testing accuracy is {0.22405679513184584}
#
#
# for random state 16,the training accuracy is {0.5817362724918664}
# for random state 16 ,the testing accuracy is {0.26217655301261134}
#
#
# for random state 17,the training accuracy is {0.5569764023210833}
# for random state 17 ,the testing accuracy is {0.3464763603925063}
#
#
# for random state 18,the training accuracy is {0.5908582390953149}
# for random state 18 ,the testing accuracy is {0.12442396313364046}
#
#
# for random state 19,the training accuracy is {0.4120433674501396}
# for random state 19 ,the testing accuracy is {0.021268781302170914}
#
#
# for random state 20,the training accuracy is {0.6817012925492321}
# for random state 20 ,the testing accuracy is {0.059086053412462425}
#
#
# for random state 21,the training accuracy is {0.5120004046671611}
# for random state 21 ,the testing accuracy is {0.5036363636363637}
#
#
# for random state 22,the training accuracy is {0.446393749750867}
# for random state 22 ,the testing accuracy is {0.34127843986998896}
#
#
# for random state 23,the training accuracy is {0.43877797621309433}
# for random state 23 ,the testing accuracy is {0.24768472906403982}
#
#
# for random state 24,the training accuracy is {0.5568693465795846}
# for random state 24 ,the testing accuracy is {-0.1332765957446811}
#
#
# for random state 25,the training accuracy is {0.6307650398765958}
# for random state 25 ,the testing accuracy is {-0.6554545454545444}
#
#
# for random state 26,the training accuracy is {0.6501531393568147}
# for random state 26 ,the testing accuracy is {-0.23294932871372853}
#
#
# for random state 27,the training accuracy is {0.5931013038408535}
# for random state 27 ,the testing accuracy is {0.1012653446647781}
#
#
# for random state 28,the training accuracy is {0.6164374532853162}
# for random state 28 ,the testing accuracy is {0.339477503628447}
#
#
# for random state 29,the training accuracy is {0.5060451627871005}
# for random state 29 ,the testing accuracy is {0.5123656927426954}
#
#
# for random state 30,the training accuracy is {0.590749430995241}
# for random state 30 ,the testing accuracy is {0.3984173778122575}
#
#
# for random state 31,the training accuracy is {0.6209911292435527}
# for random state 31 ,the testing accuracy is {-0.9503900508762013}
#
#
# for random state 32,the training accuracy is {0.6098281505728314}
# for random state 32 ,the testing accuracy is {0.29749397590361426}
#
#
# for random state 33,the training accuracy is {0.6319929762949955}
# for random state 33 ,the testing accuracy is {0.029693769799365777}
#
#
# for random state 34,the training accuracy is {0.5650864263700923}
# for random state 34 ,the testing accuracy is {0.4718773946360161}
#
#
# for random state 35,the training accuracy is {0.49573802541544465}
# for random state 35 ,the testing accuracy is {0.474095102909865}
#
#
# for random state 36,the training accuracy is {0.6027200158659327}
# for random state 36 ,the testing accuracy is {-1.4117232021709651}
#
#
# for random state 37,the training accuracy is {0.6862023696215827}
# for random state 37 ,the testing accuracy is {-0.9406769230769232}
#
#
# for random state 38,the training accuracy is {0.6551690424913684}
# for random state 38 ,the testing accuracy is {0.015832167832167232}
#
#
# for random state 39,the training accuracy is {0.6379240827547314}
# for random state 39 ,the testing accuracy is {0.179730010384216}
#
#
# for random state 40,the training accuracy is {0.5622584424183772}
# for random state 40 ,the testing accuracy is {-0.5360103626943014}
#
#
# for random state 41,the training accuracy is {0.5713345150671056}
# for random state 41 ,the testing accuracy is {0.32124623115577877}
#
#
# for random state 42,the training accuracy is {0.6072770706314401}
# for random state 42 ,the testing accuracy is {0.5588235294117648}
#
#
# for random state 43,the training accuracy is {0.680364596753414}
# for random state 43 ,the testing accuracy is {0.1348715144887921}
#
#
# for random state 44,the training accuracy is {0.5677230828319039}
# for random state 44 ,the testing accuracy is {0.6708000000000003}
#
#
# for random state 45,the training accuracy is {0.64832400569593}
# for random state 45 ,the testing accuracy is {-0.06732851985559529}
#
#
# for random state 46,the training accuracy is {0.6410395909805979}
# for random state 46 ,the testing accuracy is {0.20522613065326556}
#
#
# for random state 47,the training accuracy is {0.5217827061278106}
# for random state 47 ,the testing accuracy is {0.4477464788732397}
#
#
# for random state 48,the training accuracy is {0.6108646499567849}
# for random state 48 ,the testing accuracy is {0.10568758344459284}
#
#
# for random state 49,the training accuracy is {0.6209442060085838}
# for random state 49 ,the testing accuracy is {-1.9634707780566512}
#
#
# for random state 50,the training accuracy is {0.5274846911092164}
# for random state 50 ,the testing accuracy is {0.04597902097902029}
#
#
# for random state 51,the training accuracy is {0.6087961653850134}
# for random state 51 ,the testing accuracy is {0.5601206030150753}
#
#
# for random state 52,the training accuracy is {0.6399327274491414}
# for random state 52 ,the testing accuracy is {0.32074118350268965}
#
#
# for random state 53,the training accuracy is {0.5912839480080311}
# for random state 53 ,the testing accuracy is {0.43982417582417566}
#
#
# for random state 54,the training accuracy is {0.599945227398609}
# for random state 54 ,the testing accuracy is {0.32398576512455535}
#
#
# for random state 55,the training accuracy is {0.6265668925068256}
# for random state 55 ,the testing accuracy is {0.5513558678313708}
#
#
# for random state 56,the training accuracy is {0.5996432545201669}
# for random state 56 ,the testing accuracy is {-0.023406347787215287}
#
#
# for random state 57,the training accuracy is {0.533893148252764}
# for random state 57 ,the testing accuracy is {0.4447754137115839}
#
#
# for random state 58,the training accuracy is {0.6126606814169265}
# for random state 58 ,the testing accuracy is {0.23001254705144347}
#
#
# for random state 59,the training accuracy is {0.567237697963801}
# for random state 59 ,the testing accuracy is {-0.3433766233766229}
#
#
# for random state 60,the training accuracy is {0.58942052138552}
# for random state 60 ,the testing accuracy is {0.5032430891992017}
#
#
# for random state 61,the training accuracy is {0.5545730027548208}
# for random state 61 ,the testing accuracy is {0.539401381427475}
#
#
# for random state 62,the training accuracy is {0.6303381819514161}
# for random state 62 ,the testing accuracy is {0.27742430049827516}
#
#
# for random state 63,the training accuracy is {0.6570563961485556}
# for random state 63 ,the testing accuracy is {0.4237821482602113}
#
#
# for random state 64,the training accuracy is {0.5743241697487322}
# for random state 64 ,the testing accuracy is {0.3431368821292774}
#
#
# for random state 65,the training accuracy is {0.5992026354209559}
# for random state 65 ,the testing accuracy is {0.46645395213923113}
#
#
# for random state 66,the training accuracy is {0.6408900681825815}
# for random state 66 ,the testing accuracy is {0.2103883495145633}
#
#
# for random state 67,the training accuracy is {0.5939595770083574}
# for random state 67 ,the testing accuracy is {0.41597510373443947}
#
#
# for random state 68,the training accuracy is {0.60166117108049}
# for random state 68 ,the testing accuracy is {0.4122891566265059}
# for random state 69,the training accuracy is {0.5616556291390729}
# for random state 69 ,the testing accuracy is {-0.12855774348057514}
#
#
# for random state 70,the training accuracy is {0.604387795346169}
# for random state 70 ,the testing accuracy is {0.17732258064516115}
#
#
# for random state 71,the training accuracy is {0.6905654329946782}
# for random state 71 ,the testing accuracy is {-1.057399103139013}
#
#
# for random state 72,the training accuracy is {0.5978128011439584}
# for random state 72 ,the testing accuracy is {-0.7681267474370921}
#
#
# for random state 73,the training accuracy is {0.5891753427886692}
# for random state 73 ,the testing accuracy is {0.3960125391849527}
#
#
# for random state 74,the training accuracy is {0.649248182105596}
# for random state 74 ,the testing accuracy is {-0.7838225255972695}
#
#
# for random state 75,the training accuracy is {0.4289461450577158}
# for random state 75 ,the testing accuracy is {0.5188160328879754}
#
#
# for random state 76,the training accuracy is {0.5411669785818256}
# for random state 76 ,the testing accuracy is {0.4724345146379043}
#
#
# for random state 77,the training accuracy is {0.6458328710803668}
# for random state 77 ,the testing accuracy is {0.07821428571428546}
#
#
# for random state 78,the training accuracy is {0.5957418651154336}
# for random state 78 ,the testing accuracy is {0.22192256341789063}
#
#
# for random state 79,the training accuracy is {0.6453745288944726}
# for random state 79 ,the testing accuracy is {0.3590237524515143}
#
#
# for random state 80,the training accuracy is {0.5143540883546093}
# for random state 80 ,the testing accuracy is {0.4137589000736559}
#
#
# for random state 81,the training accuracy is {0.605171649208655}
# for random state 81 ,the testing accuracy is {0.4740245051837889}
#
#
# for random state 82,the training accuracy is {0.5585479962066663}
# for random state 82 ,the testing accuracy is {0.6933687808583366}
#
#
# for random state 83,the training accuracy is {0.563192701545336}
# for random state 83 ,the testing accuracy is {0.4607065750736018}
#
#
# for random state 84,the training accuracy is {0.6459563899103282}
# for random state 84 ,the testing accuracy is {0.3379955456570163}
#
#
# for random state 85,the training accuracy is {0.5919717154354025}
# for random state 85 ,the testing accuracy is {0.41029745345602375}
#
#
# for random state 86,the training accuracy is {0.5966143959766703}
# for random state 86 ,the testing accuracy is {-0.5848664259927803}
#
#
# for random state 87,the training accuracy is {0.48649467846932803}
# for random state 87 ,the testing accuracy is {0.40829187396351574}
#
#
# for random state 88,the training accuracy is {0.6179825129533679}
# for random state 88 ,the testing accuracy is {0.4635294117647063}
#
#
# for random state 89,the training accuracy is {0.671754993528527}
# for random state 89 ,the testing accuracy is {-0.2017213114754095}
#
#
# for random state 90,the training accuracy is {0.6352936638732072}
# for random state 90 ,the testing accuracy is {0.1950022471910109}
#
#
# for random state 91,the training accuracy is {0.6833547041557237}
# for random state 91 ,the testing accuracy is {0.08688761525043598}
#
#
# for random state 92,the training accuracy is {0.6227670367873994}
# for random state 92 ,the testing accuracy is {0.4789230769230768}
#
#
# for random state 93,the training accuracy is {0.5599179086902396}
# for random state 93 ,the testing accuracy is {0.29036912751677835}
#
#
# for random state 94,the training accuracy is {0.6587558081230152}
# for random state 94 ,the testing accuracy is {0.05736549165120597}
#
#
# for random state 95,the training accuracy is {0.49991523268627636}
# for random state 95 ,the testing accuracy is {0.3414895267649338}
#
#
# for random state 96,the training accuracy is {0.6234364918150317}
# for random state 96 ,the testing accuracy is {0.34289544235924907}
#
#
# for random state 97,the training accuracy is {0.5751091436421918}
# for random state 97 ,the testing accuracy is {0.4558916041616259}
#
#
# for random state 98,the training accuracy is {0.6603902076462118}
# for random state 98 ,the testing accuracy is {-0.3582819015846539}
#
#
# for random state 99,the training accuracy is {0.5583801707701235}
# for random state 99 ,the testing accuracy is {0.7407720320466132}

# %%
#cross validation

Train_accuracy=r2_score(y_train,pred_train)
testing_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is {cv_mean} and the train accuracy score is {Train_accuracy} and test accuracy score is {testing_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is 0.30636052562663185 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 3 the cv score is 0.26290373450015064 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 4 the cv score is 0.4628427803818804 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 5 the cv score is -0.19587487608289983 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 6 the cv score is 0.12755625755374006 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 7 the cv score is -0.3113281565104787 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 8 the cv score is -0.16078568494328788 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 9 the cv score is -18.78722767375742 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132

# %%
#cross validation

Train_accuracy=r2_score(y_train,pred_train)
testing_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(dtc,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is {cv_mean} and the train accuracy score is {Train_accuracy} and test accuracy score is {testing_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is -0.06541145967815215 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 3 the cv score is -0.23352187370245617 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 4 the cv score is -0.1967339969607586 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 5 the cv score is -0.965686433328113 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 6 the cv score is -0.24148836353858685 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 7 the cv score is -1.5654818274633393 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 8 the cv score is -0.5836466000641444 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 9 the cv score is -14.83282432558675 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132

# %%
#cross validation

Train_accuracy=r2_score(y_train,pred_train)
testing_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(svr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is {cv_mean} and the train accuracy score is {Train_accuracy} and test accuracy score is {testing_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is -0.17113163073550086 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 3 the cv score is -0.2543618877722642 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 4 the cv score is -0.11607664687474303 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 5 the cv score is -0.3382564095861678 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 6 the cv score is -0.1719070844998545 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 7 the cv score is -0.31662921952834966 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 8 the cv score is -0.617372500517931 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 9 the cv score is -24.75808262150081 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132

# %%
#cross validation

Train_accuracy=r2_score(y_train,pred_train)
testing_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(knn,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'at cross fold {j} the cv score is {cv_mean} and the train accuracy score is {Train_accuracy} and test accuracy score is {testing_accuracy}')
    print('\n')
# Out:
# at cross fold 2 the cv score is 0.05051541714839752 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 3 the cv score is 0.017427108511460638 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 4 the cv score is 0.26247431022674683 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 5 the cv score is -0.5384336999189708 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 6 the cv score is -0.05871551509828756 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 7 the cv score is -0.4238961145242623 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 8 the cv score is -0.3848627818699529 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132
#
#
# at cross fold 9 the cv score is -20.882169214513656 and the train accuracy score is 0.5583801707701235 and test accuracy score is 0.7407720320466132

# %%
#grid search cv

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso

parameters={'alpha':[.0001, .001, .01, .1, 1, 10 ],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
#model training


ls=Lasso(alpha=.001,random_state=0)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
ls_score_training*100
# Out:
# 75.80198491963408

# %%
lss=r2_score(y_test,pred_ls)
lss*100
# Out:
# 60.88630813432327

# %%
cv_score=cross_val_score(lr,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# -19.587487608289983

# %%
cv_score=cross_val_score(dtc,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# -66.06194120347105

# %%
cv_score=cross_val_score(knn,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# -53.843369991897085

# %%
cv_score=cross_val_score(svr,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# -33.82564095861678

# %%
#ENsemble technique

from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['mse','mae' ],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion='mse',max_features='auto')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_dec=rf.predict(x_test)

rfs=r2_score(y_test,pred_dec)
print('r2_score:',rfs*100)

rfscore=cross_val_score(rf,x,y,cv=5)
rfc=rfscore.mean()
print('cross val score',rfc*100)
# Out:
# r2_score: 59.58793517844136
# cross val score -25.228928779515247

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbreg = GradientBoostingRegressor(random_state=0)

clf = GradientBoostingRegressor(n_estimators=200,max_depth=5, random_state=0).fit(x_train, y_train)
gbreg.fit(x_train, y_train)

rf.score(x_train,y_train)
pred_dec=rf.predict(x_test)

rfs=r2_score(y_test,pred_dec)
print('r2_score:',rfs*100)

rfscore=cross_val_score(gbreg,x,y,cv=5)
rfc=rfscore.mean()
print('cross val score',rfc*100)
# Out:
# r2_score: 59.58793517844136
# cross val score -71.29864952386642

# %%
import pickle
filename='baseball win prediction.pkl'
pickle.dump(rf,open(filename,'wb'))

# %%
loadmodel=pickle.load(open('baseball win prediction.pkl','rb'))
result=loadmodel.score(x_test,y_test)
print(result*100)
# Out:
# 59.58793517844136

# %%
conclusion=pd.DataFrame([loadmodel.predict(x_test)[:],pred_dec[:]],index=['predicted','original'])
conclusion
# Out:
#                0      1      2      3      4      5
# predicted  73.78  70.67  84.96  84.41  85.25  85.34
# original   73.78  70.67  84.96  84.41  85.25  85.34
